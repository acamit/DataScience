# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
matplotlib.is_interactive()
# Out:
# True

# %%
# matplotlib.interactive(True)

# %%
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
# matplotlib.use('nbagg')

# %%
# turn on interactive mode
plt.ion()

# %%
matplotlib.is_interactive()
# Out:
# True

# %%
# line plot

plt.plot([2,4,6,8], [4,8,12,16], color='Red')
plt.title('Interactive plot')
plt.xlabel('x', fontsize=15, color='green')
plt.ylabel('2*x', fontsize=15, color='green')
# Out:
# Text(0, 0.5, '2*x')

# %%
x= np.linspace(start=0, stop=10, num=50)
x
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
plt.plot(x, np.sin(x))

plt.xlabel('x', fontsize=15, color='green')
plt.ylabel('sin(x)', fontsize=15, color='green')
plt.tick_params(axis='y', color='red', labelcolor='blue')

# %%
plt.tick_params(axis='y', color='red', labelcolor='blue', labelsize='xx-large')

# %%
plt.tick_params(axis='x', bottom=False,labelbottom=False)

# %%
plt.plot(x, np.sin(x) ,label='sine curve')
plt.legend()

# %%
plt.plot(x, np.sin(x) ,label='sine curve')
plt.legend()
plt.title('playing with plot')
# Out:
# Text(0.5, 1.0, 'playing with plot')

# %%
plt.plot(x, np.sin(x) ,label='sine curve')
plt.legend()
plt.title('playing with plot')

plt.xlim(1,5) # limit  range of x values
plt.ylim(-1, 0.5)
# Out:
# (-1, 0.5)

# %%
plt.plot(x, np.sin(x) ,label='sine curve')
plt.legend()
plt.title('playing with plot')

plt.xlim(1,5) # limit  range of x values
plt.ylim(-1, 0.5) # limit  range of y values
# Out:
# (-1, 0.5)

# %%
# by inverting x params we can invert a plot along y axis
plt.plot(x, np.sin(x) ,label='sine curve')
plt.legend()
plt.title('playing with plot')

plt.xlim(5,1) # limit  range of x values


# same can be done for y limits
# Out:
# (5, 1)

# %% [markdown]
# ### ploting multiple curves in a diagram

# %% [markdown]
# We can just specify both in one cell and we will have both the curves on same graphs

# %%
plt.plot(x, np.sin(x), label='sine curve')
plt.plot(x, np.cos(x), label='cosine curve')
plt.legend()
plt.title('Playing with plots')

plt.show()

# %%
plt.plot(x, np.sin(x), label='sine curve', color='green')
plt.plot(x, np.cos(x), label='cosine curve', color='m') # m is for magenta
plt.legend()
plt.title('Playing with plots')

plt.show()

# %% [markdown]
# ## more plots

# %%
random_array= np.random.randn(20) # generate random 20 numbers

# %%
plt.plot(random_array, color='green') # default line to connect is solid

# %%
plt.plot(random_array, color='green', linestyle='None', marker='d')

# %%
plt.plot(random_array, color='green', linestyle=':', linewidth=3) ## colon (:) is for a dotted line

# %% [markdown]
# ### line styles
#  - default = solid
#  - colon(:) = dotted
#  - double dash(--)  = dashed
#  - 'None' (with quotes as string) = no line only markers. Do specify marker property

# %% [markdown]
# ## Highlighting the data points
#
# #### using marker property
# - 'd' - diamond shaped markers
#
# #### marker size - size of markers (defualt = 6)

# %%
plt.plot(random_array, color='green', marker='d')

# %% [markdown]
# # Scatter plots for bivariate plotting

# %%
plt.scatter(range(0,20), random_array, color='green', marker='d') ## marker is optional

# %% [markdown]
# # working with figures

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
#param1 - where in the figure left of the axes will lie. 0 is for extreme left, 1 for extreme right
#param2 - where in the figure bottom of the axes will lie. 0 is for bottom, 1 for top
#param 3 - the width of axes in terms of fraction of figure
#param 4- the height of axes in terms of fraction of figure

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0.6,1,0.4])
ax2 = fig.add_axes([0,0,0.8,0.4])

x = np.linspace(0, 10, 50)
ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x))

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.5,0.5,0.4,0.4])

x = np.linspace(0, 10, 50)
ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x))
