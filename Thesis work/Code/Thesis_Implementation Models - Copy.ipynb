# %% [markdown]
# # Libraries import

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# import os
# os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Colab Notebooks"
# %cd /content/gdrive/My Drive/Colab Notebooks

# %%
# # uncomment this cell for first run to install the packages.
# !pip install quandl
# !pip install ta 
# !pip install git+https://github.com/ourownstory/neural_prophet.git
# !pip install -U prophet
# !pip install -U statsmodels
# !pip install -U sklearn
# !pip install -U scikit-learn
# !pip install -U pmdarima

# %%
import os
import numpy as np
import pandas as pd
import re
from math import sqrt
import quandl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, r2_score, mean_absolute_error
# for mean_squared_error set squared = False for RMSE, (y_true, y_pred)
from sklearn.model_selection import train_test_split

# stats models
from statsmodels.tsa.arima_model import ARMA, ARIMA, ARMAResults, ARIMAResults
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.statespace.varmax import VARMAX, VARMAXResults
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.tools import diff
from statsmodels.tools.eval_measures import rmse
import statsmodels.graphics.tsaplots as sgt

from pmdarima import auto_arima
from fbprophet import Prophet
import copy
import random
import sys
import itertools
import warnings

warnings.filterwarnings('ignore')

# %%
path = './Outputs/'
if(not os.path.isdir(path)):
    os.mkdir(path)

# %%
pd.set_option('display.max_columns', None)

# %%
quandl.ApiConfig.api_key = "2At3atzXCrMx_BXfkyz7"
# 6b7jcHuxwW7Wot1kyFNS

# %% [markdown]
# # Data to be used

# %%
metadata = pd.read_csv('BSE_metadata.csv')
metadata.head()
# Out:
#         code                                              name  \
# 0  BOM500002                      ABB India Limited EOD Prices
# 1  BOM500003                   AEGIS LOGISTICS LTD. EOD Prices
# 2  BOM500008              AMARA RAJA BATTERIES LTD. EOD Prices
# 3  BOM500009      AMBALAL SARABHAI ENTERPRISES LTD. EOD Prices
# 4  BOM500010  HOUSING DEVELOPMENT FINANCE CORP.LTD. EOD Prices
#
#                                          description     refreshed_at  \
# 0  End of Day prices and additional trading infor...  1/19/2021 14:15
# 1  End of Day prices and additional trading infor...  1/19/2021 14:15
# 2  End of Day prices and additional trading infor...  1/19/2021 14:15
# 3  End of Day prices and additional trading infor...  1/19/2021 14:15
# 4  End of Day prices and additional trading infor...  1/19/2021 14:15
#
#   from_date    to_date
# 0  3/2/1992  1/18/2021
# 1  3/2/1992  1/18/2021
# 2  3/2/1992  1/18/2021
# 3  3/2/1992  1/18/2021
# 4  1/3/1992  1/18/2021

# %% [markdown]
# ## Utility variables and functions

# %%
### Codes of selected stocks
healthcare = ['BOM524715','BOM532488','BOM500124']
banking = ['BOM500180','BOM532174','BOM500247']
metals = ['BOM500470','BOM500228','BOM500440']
auto = ['BOM532977','BOM500570','BOM532500']
it = ['BOM500209','BOM532540','BOM507685']
BSE_HEALTHCARE = 'SI0800'
BSE_Information_Technology = 'SI1000'
BSE_BANKEX = 'SIBANK'
BSE_METAL = 'SI1200'
BSE_AUTO = 'SI1900'
SENSEX = 'SENSEX'

stocks = healthcare+banking+metals + auto+it
indices = [BSE_HEALTHCARE, BSE_Information_Technology, BSE_BANKEX, BSE_METAL, BSE_AUTO, SENSEX]
allSymbols = stocks + indices
ScriptWiseData = {}

# %%
# Global Variables
RSIColumn = 'RSI'
ATRColumns = ['TR', 'ATR']
MACDColumns = ['FastAverage', 'SlowAverage','MACD','Signal']
BollBandColumns = ['BB_up',"BB_dn","MA","BB_width"]
ADXColumns = ['pos_directional_indicator', 'neg_directional_indicator', 'adx']
OnBalanceVolume = 'OBV'
TechnicalIndicators = ['RSI', 'ATR', 'MACD', 'adx', 'OBV'] #exogenous variables

AllIndicatorColumns = [RSIColumn]+ATRColumns+MACDColumns+BollBandColumns+ADXColumns+[OnBalanceVolume]

# %%
start_date = '2020-03-02'
end_date = '2021-03-23'

# %%
# get null values of all the stocks
def getNullValuesForSetOfStocks(stockCodeList = allSymbols):
    nullCounts = pd.DataFrame(ScriptWiseData[stockCodeList[0]].isnull().sum(), columns= [getStockNameFromStockCode(stockCodeList[0])])
    for symbol in stockCodeList[1:]:
        currNull = pd.DataFrame(ScriptWiseData[symbol].isnull().sum(), columns= [getStockNameFromStockCode(symbol)])
        nullCounts = nullCounts.merge(currNull, left_index=True, right_index = True, how='outer')
    return nullCounts

# %%
def adf_test(series, title = ''):
    """
    Pass in a time series and an optional title
    """
    result = sts.adfuller(series.dropna(), autolag = 'AIC')
    label = ['ADF test statistic', 'p-value', '# lags used', '#observations']
#     print(result)
    out = pd.Series(result[0:4], index=label)
    out['Stock Name'] = getStockNameFromStockCode(title)
    out['Stock Code'] = title
    for key, val in result[4].items():
        out[f'critical value ({key})'] = val
        
#     print(out)
    if(result[1]<0.05):
        return out, 'Stationary'
    else:
        return out, 'Non-Stationary'

# %%
stockMetadata = metadata[metadata['code'].isin(allSymbols)]
stockMetadata.head()
# Out:
#           code                                     name  \
# 70   BOM500124  DR.REDDY'S LABORATORIES LTD. EOD Prices
# 104  BOM500180                 HDFC Bank Ltd EOD Prices
# 121  BOM500209                  INFOSYS LTD. EOD Prices
# 133  BOM500228                JSW STEEL LTD. EOD Prices
# 146  BOM500247      KOTAK MAHINDRA BANK LTD. EOD Prices
#
#                                            description     refreshed_at  \
# 70   End of Day prices and additional trading infor...  1/19/2021 14:15
# 104  End of Day prices and additional trading infor...  1/19/2021 14:15
# 121  End of Day prices and additional trading infor...  1/19/2021 14:15
# 133  End of Day prices and additional trading infor...  1/19/2021 14:15
# 146  End of Day prices and additional trading infor...  1/19/2021 14:15
#
#      from_date    to_date
# 70    3/2/1992  1/18/2021
# 104  5/26/1995  1/18/2021
# 121   5/2/1995  1/18/2021
# 133   5/2/1995  1/18/2021
# 146   5/2/1995  1/18/2021

# %%
print(stockMetadata.shape)
print(stockMetadata[stockMetadata['code'].isin(stocks)].shape)
print(stockMetadata[stockMetadata['code'].isin(indices)].shape)
# Out:
# (21, 6)
# (15, 6)
# (6, 6)

# %% [markdown]
# ## Map Index to  stocks

# %%
stockMetadata.loc[:, 'isStock'] = 0
stockMetadata.loc[:, 'Index'] = ''

stockMetadata.loc[stockMetadata['code'].isin(stocks), 'isStock'] = 1
stockMetadata.reset_index(inplace=True)

# %%
stockMetadata.loc[stockMetadata['code'].isin(healthcare), 'Index'] = BSE_HEALTHCARE
stockMetadata.loc[stockMetadata['code'].isin(banking), 'Index'] = BSE_BANKEX
stockMetadata.loc[stockMetadata['code'].isin(metals), 'Index'] = BSE_METAL
stockMetadata.loc[stockMetadata['code'].isin(auto), 'Index'] = BSE_AUTO
stockMetadata.loc[stockMetadata['code'].isin(it), 'Index'] = BSE_Information_Technology

# %%
stockMetadata.head()
# Out:
#    index       code                                     name  \
# 0     70  BOM500124  DR.REDDY'S LABORATORIES LTD. EOD Prices
# 1    104  BOM500180                 HDFC Bank Ltd EOD Prices
# 2    121  BOM500209                  INFOSYS LTD. EOD Prices
# 3    133  BOM500228                JSW STEEL LTD. EOD Prices
# 4    146  BOM500247      KOTAK MAHINDRA BANK LTD. EOD Prices
#
#                                          description     refreshed_at  \
# 0  End of Day prices and additional trading infor...  1/19/2021 14:15
# 1  End of Day prices and additional trading infor...  1/19/2021 14:15
# 2  End of Day prices and additional trading infor...  1/19/2021 14:15
# 3  End of Day prices and additional trading infor...  1/19/2021 14:15
# 4  End of Day prices and additional trading infor...  1/19/2021 14:15
#
#    from_date    to_date  isStock   Index
# 0   3/2/1992  1/18/2021        1  SI0800
# 1  5/26/1995  1/18/2021        1  SIBANK
# 2   5/2/1995  1/18/2021        1  SI1000
# 3   5/2/1995  1/18/2021        1  SI1200
# 4   5/2/1995  1/18/2021        1  SIBANK

# %%
stockMetadata['isStock'].value_counts()
# Out:
# 1    15
# 0     6
# Name: isStock, dtype: int64

# %% [markdown]
# # Code to download the data from quandl.

# %%
# # download the required data - needed only 1 time
# i=0
# code = f'BSE/{stockMetadata.loc[i, "code"]}'
# dataset = quandl.get(code, start_date='2000-01-01', end_date='2021-03-23').sort_values(by='Date', ascending=True)
# dataset['StockName']=stockMetadata.loc[i, 'name']
# dataset['code'] = stockMetadata.loc[i, "code"]
# dataset['isStock'] = stockMetadata.loc[i, "isStock"]
# dataset['Index'] = stockMetadata.loc[i, "Index"]
# for i in range(1, len(stockMetadata)):
#     code = f'BSE/{stockMetadata.loc[i, "code"]}'
#     temp = quandl.get(code, start_date='2000-01-01', end_date='2021-03-23').sort_values(by='Date', ascending=True)
#     temp['StockName']=stockMetadata.loc[i, 'name']
#     temp['code'] = stockMetadata.loc[i, "code"]
#     temp['isStock'] = stockMetadata.loc[i, "isStock"]
#     temp['Index'] = stockMetadata.loc[i, "Index"]
# #     print( stockMetadata.loc[i, "Index"])
#     dataset = dataset.append(temp)
# dataset.to_csv('data.csv')
# dataset.head()

# %%
dataset = pd.read_csv('data.csv')
dataset.head()
# Out:
#          Date    Open     High      Low    Close          WAP  No. of Shares  \
# 0  2000-01-03  1500.0  1557.35  1500.00  1557.35  1544.195154        82330.0
# 1  2000-01-04  1601.0  1681.00  1527.00  1647.25  1621.040930       210676.0
# 2  2000-01-05  1600.0  1648.00  1515.50  1559.00  1590.903923       205669.0
# 3  2000-01-06  1582.0  1683.70  1560.00  1683.70  1623.244182       161085.0
# 4  2000-01-07  1718.0  1718.00  1549.05  1549.05  1593.853264       120952.0
#
#    No. of Trades  Total Turnover  Deliverable Quantity  \
# 0          945.0     127133587.0                   NaN
# 1         3308.0     341514419.0                   NaN
# 2         2707.0     327199619.0                   NaN
# 3         2559.0     261480289.0                   NaN
# 4         1955.0     192779740.0                   NaN
#
#    % Deli. Qty to Traded Qty  Spread H-L  Spread C-O  \
# 0                        NaN       57.35       57.35
# 1                        NaN      154.00       46.25
# 2                        NaN      132.50      -41.00
# 3                        NaN      123.70      101.70
# 4                        NaN      168.95     -168.95
#
#                                  StockName       code  isStock   Index
# 0  DR.REDDY'S LABORATORIES LTD. EOD Prices  BOM500124        1  SI0800
# 1  DR.REDDY'S LABORATORIES LTD. EOD Prices  BOM500124        1  SI0800
# 2  DR.REDDY'S LABORATORIES LTD. EOD Prices  BOM500124        1  SI0800
# 3  DR.REDDY'S LABORATORIES LTD. EOD Prices  BOM500124        1  SI0800
# 4  DR.REDDY'S LABORATORIES LTD. EOD Prices  BOM500124        1  SI0800

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105449 entries, 0 to 105448
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Date                       105449 non-null  object
#  1   Open                       95130 non-null   float64
#  2   High                       95130 non-null   float64
#  3   Low                        95130 non-null   float64
#  4   Close                      105449 non-null  float64
#  5   WAP                        74255 non-null   float64
#  6   No. of Shares              74255 non-null   float64
#  7   No. of Trades              74255 non-null   float64
#  8   Total Turnover             74255 non-null   float64
#  9   Deliverable Quantity       68110 non-null   float64
#  10  % Deli. Qty to Traded Qty  68110 non-null   float64
#  11  Spread H-L                 74255 non-null   float64
#  12  Spread C-O                 74255 non-null   float64
#  13  StockName                  105449 non-null  object
#  14  code                       105449 non-null  object
#  15  isStock                    105449 non-null  int64
#  16  Index                      74255 non-null   object
# dtypes: float64(12), int64(1), object(4)
# memory usage: 13.7+ MB

# %% [markdown]
# ### Verify the min and max of dates of all selected stocks and indices

# %%
dateRanges = dataset.groupby(['code', 'StockName']).agg({'Date': ['min', 'max']}).reset_index()
dateRanges.columns = ['Stock Code', 'Stock Name', 'First Date', 'Last Date']
dateRanges
# Out:
#    Stock Code                                     Stock Name  First Date  \
# 0   BOM500124        DR.REDDY'S LABORATORIES LTD. EOD Prices  2000-01-03
# 1   BOM500180                       HDFC Bank Ltd EOD Prices  2000-01-03
# 2   BOM500209                        INFOSYS LTD. EOD Prices  2000-01-03
# 3   BOM500228                      JSW STEEL LTD. EOD Prices  2000-01-03
# 4   BOM500247            KOTAK MAHINDRA BANK LTD. EOD Prices  2000-01-03
# 5   BOM500440            HINDALCO INDUSTRIES LTD. EOD Prices  2000-01-03
# 6   BOM500470                     TATA STEEL LTD. EOD Prices  2000-01-03
# 7   BOM500570                    TATA MOTORS LTD. EOD Prices  2000-01-03
# 8   BOM507685                          WIPRO LTD. EOD Prices  2000-01-03
# 9   BOM524715  SUN PHARMACEUTICAL INDUSTRIES LTD. EOD Prices  2000-01-03
# 10  BOM532174                     ICICI BANK LTD. EOD Prices  2000-01-03
# 11  BOM532488            DIVI'S LABORATORIES LTD. EOD Prices  2003-03-12
# 12  BOM532500            MARUTI SUZUKI INDIA LTD. EOD Prices  2003-07-09
# 13  BOM532540      TATA CONSULTANCY SERVICES LTD. EOD Prices  2004-08-25
# 14  BOM532977                     BAJAJ AUTO LTD. EOD Prices  2008-05-26
# 15     SENSEX                                     BSE SENSEX  2000-01-03
# 16     SI0800                                 BSE Healthcare  2000-01-03
# 17     SI1000                     BSE Information Technology  2000-01-03
# 18     SI1200                                      BSE METAL  2000-01-03
# 19     SI1900                                       BSE AUTO  2000-01-03
# 20     SIBANK                                     BSE BANKEX  2002-01-01
#
#      Last Date
# 0   2021-03-23
# 1   2021-03-23
# 2   2021-03-23
# 3   2021-03-23
# 4   2021-03-23
# 5   2021-03-23
# 6   2021-03-23
# 7   2021-03-23
# 8   2021-03-23
# 9   2021-03-23
# 10  2021-03-23
# 11  2021-03-23
# 12  2021-03-23
# 13  2021-03-23
# 14  2021-03-23
# 15  2021-03-23
# 16  2021-03-23
# 17  2021-03-23
# 18  2021-03-23
# 19  2021-03-23
# 20  2021-03-23

# %%
# use above ranges to get stockName
def getStockNameFromStockCode(stockCode):
    return dateRanges.loc[dateRanges['Stock Code']==stockCode, 'Stock Name'].values[0].replace('EOD Prices', '');

# %%
data = dataset.set_index('Date')
data.head()
# Out:
#               Open     High      Low    Close          WAP  No. of Shares  \
# Date
# 2000-01-03  1500.0  1557.35  1500.00  1557.35  1544.195154        82330.0
# 2000-01-04  1601.0  1681.00  1527.00  1647.25  1621.040930       210676.0
# 2000-01-05  1600.0  1648.00  1515.50  1559.00  1590.903923       205669.0
# 2000-01-06  1582.0  1683.70  1560.00  1683.70  1623.244182       161085.0
# 2000-01-07  1718.0  1718.00  1549.05  1549.05  1593.853264       120952.0
#
#             No. of Trades  Total Turnover  Deliverable Quantity  \
# Date
# 2000-01-03          945.0     127133587.0                   NaN
# 2000-01-04         3308.0     341514419.0                   NaN
# 2000-01-05         2707.0     327199619.0                   NaN
# 2000-01-06         2559.0     261480289.0                   NaN
# 2000-01-07         1955.0     192779740.0                   NaN
#
#             % Deli. Qty to Traded Qty  Spread H-L  Spread C-O  \
# Date
# 2000-01-03                        NaN       57.35       57.35
# 2000-01-04                        NaN      154.00       46.25
# 2000-01-05                        NaN      132.50      -41.00
# 2000-01-06                        NaN      123.70      101.70
# 2000-01-07                        NaN      168.95     -168.95
#
#                                           StockName       code  isStock  \
# Date
# 2000-01-03  DR.REDDY'S LABORATORIES LTD. EOD Prices  BOM500124        1
# 2000-01-04  DR.REDDY'S LABORATORIES LTD. EOD Prices  BOM500124        1
# 2000-01-05  DR.REDDY'S LABORATORIES LTD. EOD Prices  BOM500124        1
# 2000-01-06  DR.REDDY'S LABORATORIES LTD. EOD Prices  BOM500124        1
# 2000-01-07  DR.REDDY'S LABORATORIES LTD. EOD Prices  BOM500124        1
#
#              Index
# Date
# 2000-01-03  SI0800
# 2000-01-04  SI0800
# 2000-01-05  SI0800
# 2000-01-06  SI0800
# 2000-01-07  SI0800

# %% [markdown]
# ### Populate dictionary to hold individual Stock Data

# %%
# ScriptWiseData = {'Symbol1': <DatqaFrame>, 'Suymbol 2':Dataframe2}
for symbol in allSymbols:
    ScriptWiseData[symbol] = data.loc[data.code==symbol]

# %% [markdown]
# ### View null values in the data

# %%
getNullValuesForSetOfStocks()
# Out:
#                            SUN PHARMACEUTICAL INDUSTRIES LTD.   \
# Open                                                         0
# High                                                         0
# Low                                                          0
# Close                                                        0
# WAP                                                          0
# No. of Shares                                                0
# No. of Trades                                                0
# Total Turnover                                               0
# Deliverable Quantity                                       548
# % Deli. Qty to Traded Qty                                  548
# Spread H-L                                                   0
# Spread C-O                                                   0
# StockName                                                    0
# code                                                         0
# isStock                                                      0
# Index                                                        0
#
#                            DIVI'S LABORATORIES LTD.   \
# Open                                               0
# High                                               0
# Low                                                0
# Close                                              0
# WAP                                                0
# No. of Shares                                      0
# No. of Trades                                      0
# Total Turnover                                     0
# Deliverable Quantity                              57
# % Deli. Qty to Traded Qty                         57
# Spread H-L                                         0
# Spread C-O                                         0
# StockName                                          0
# code                                               0
# isStock                                            0
# Index                                              0
#
#                            DR.REDDY'S LABORATORIES LTD.   HDFC Bank Ltd   \
# Open                                                   0               0
# High                                                   0               0
# Low                                                    0               0
# Close                                                  0               0
# WAP                                                    0               0
# No. of Shares                                          0               0
# No. of Trades                                          0               0
# Total Turnover                                         0               0
# Deliverable Quantity                                 538             538
# % Deli. Qty to Traded Qty                            538             538
# Spread H-L                                             0               0
# Spread C-O                                             0               0
# StockName                                              0               0
# code                                                   0               0
# isStock                                                0               0
# Index                                                  0               0
#
#                            ICICI BANK LTD.   KOTAK MAHINDRA BANK LTD.   \
# Open                                      0                          0
# High                                      0                          0
# Low                                       0                          0
# Close                                     0                          0
# WAP                                       0                          0
# No. of Shares                             0                          0
# No. of Trades                             0                          0
# Total Turnover                            0                          0
# Deliverable Quantity                    544                        537
# % Deli. Qty to Traded Qty               544                        537
# Spread H-L                                0                          0
# Spread C-O                                0                          0
# StockName                                 0                          0
# code                                      0                          0
# isStock                                   0                          0
# Index                                     0                          0
#
#                            TATA STEEL LTD.   JSW STEEL LTD.   \
# Open                                      0                0
# High                                      0                0
# Low                                       0                0
# Close                                     0                0
# WAP                                       0                0
# No. of Shares                             0                0
# No. of Trades                             0                0
# Total Turnover                            0                0
# Deliverable Quantity                    545              580
# % Deli. Qty to Traded Qty               545              580
# Spread H-L                                0                0
# Spread C-O                                0                0
# StockName                                 0                0
# code                                      0                0
# isStock                                   0                0
# Index                                     0                0
#
#                            HINDALCO INDUSTRIES LTD.   BAJAJ AUTO LTD.   \
# Open                                               0                 0
# High                                               0                 0
# Low                                                0                 0
# Close                                              0                 0
# WAP                                                0                 0
# No. of Shares                                      0                 0
# No. of Trades                                      0                 0
# Total Turnover                                     0                 0
# Deliverable Quantity                             555                 1
# % Deli. Qty to Traded Qty                        555                 1
# Spread H-L                                         0                 0
# Spread C-O                                         0                 0
# StockName                                          0                 0
# code                                               0                 0
# isStock                                            0                 0
# Index                                              0                 0
#
#                            TATA MOTORS LTD.   MARUTI SUZUKI INDIA LTD.   \
# Open                                       0                          0
# High                                       0                          0
# Low                                        0                          0
# Close                                      0                          0
# WAP                                        0                          0
# No. of Shares                              0                          0
# No. of Trades                              0                          0
# Total Turnover                             0                          0
# Deliverable Quantity                     542                         81
# % Deli. Qty to Traded Qty                542                         81
# Spread H-L                                 0                          0
# Spread C-O                                 0                          0
# StockName                                  0                          0
# code                                       0                          0
# isStock                                    0                          0
# Index                                      0                          0
#
#                            INFOSYS LTD.   TATA CONSULTANCY SERVICES LTD.   \
# Open                                   0                                0
# High                                   0                                0
# Low                                    0                                0
# Close                                  0                                0
# WAP                                    0                                0
# No. of Shares                          0                                0
# No. of Trades                          0                                0
# Total Turnover                         0                                0
# Deliverable Quantity                 539                                2
# % Deli. Qty to Traded Qty            539                                2
# Spread H-L                             0                                0
# Spread C-O                             0                                0
# StockName                              0                                0
# code                                   0                                0
# isStock                                0                                0
# Index                                  0                                0
#
#                            WIPRO LTD.   BSE Healthcare  \
# Open                                 0            3810
# High                                 0            3810
# Low                                  0            3810
# Close                                0               0
# WAP                                  0            5282
# No. of Shares                        0            5282
# No. of Trades                        0            5282
# Total Turnover                       0            5282
# Deliverable Quantity               538            5282
# % Deli. Qty to Traded Qty          538            5282
# Spread H-L                           0            5282
# Spread C-O                           0            5282
# StockName                            0               0
# code                                 0               0
# isStock                              0               0
# Index                                0            5282
#
#                            BSE Information Technology  BSE BANKEX  BSE METAL  \
# Open                                             3810         369       1165
# High                                             3810         369       1165
# Low                                              3810         369       1165
# Close                                               0           0          0
# WAP                                              5282        4784       5282
# No. of Shares                                    5282        4784       5282
# No. of Trades                                    5282        4784       5282
# Total Turnover                                   5282        4784       5282
# Deliverable Quantity                             5282        4784       5282
# % Deli. Qty to Traded Qty                        5282        4784       5282
# Spread H-L                                       5282        4784       5282
# Spread C-O                                       5282        4784       5282
# StockName                                           0           0          0
# code                                                0           0          0
# isStock                                             0           0          0
# Index                                            5282        4784       5282
#
#                            BSE AUTO  BSE SENSEX
# Open                           1165           0
# High                           1165           0
# Low                            1165           0
# Close                             0           0
# WAP                            5282        5282
# No. of Shares                  5282        5282
# No. of Trades                  5282        5282
# Total Turnover                 5282        5282
# Deliverable Quantity           5282        5282
# % Deli. Qty to Traded Qty      5282        5282
# Spread H-L                     5282        5282
# Spread C-O                     5282        5282
# StockName                         0           0
# code                              0           0
# isStock                           0           0
# Index                          5282        5282

# %% [markdown]
# # Deriving Technical indicators

# %% [markdown]
# ### MACD

# %%
# function to create data MACD signal and data. 
def MACD(df, span1 = 12, span2= 26, span3 = 9):
    stockData = df.copy()
    stockData['FastAverage'] = stockData['Close'].ewm(span = span1, min_periods = span1).mean()
    stockData['SlowAverage'] = stockData['Close'].ewm(span = span2, min_periods = span2).mean()
    stockData['MACD'] = stockData['FastAverage'] - stockData['SlowAverage']
    stockData['Signal'] = stockData['MACD'].ewm(span=span3, min_periods = span3).mean()
    return stockData[MACDColumns]

# %%
# create stock code based dataframes with MACD signal
for symbol in allSymbols:
    macd = MACD(ScriptWiseData[symbol])
    ScriptWiseData[symbol] = ScriptWiseData[symbol].merge(macd, left_index=True, right_index = True, how='left')

# %% [markdown]
# ### RSI - Relative Strength Index

# %%
# Calculating RSI without using loop
def RSI(DF, n=14):
    df =  DF.copy()
    "function to calculate RSI"
    delta = df['Close'].diff().dropna()
    u = delta * 0
    d = u.copy()
    u[delta > 0] = delta[delta > 0]
    d[delta < 0] = -delta[delta < 0]
    u[u.index[n-1]] = np.mean( u[:n]) # first value is average of gains
    u = u.drop(u.index[:(n-1)])
    d[d.index[n-1]] = np.mean( d[:n]) # first value is average of losses
    d = d.drop(d.index[:(n-1)])
    rs = u.ewm(com=n,min_periods=n).mean()/d.ewm(com=n,min_periods=n).mean()
    rsi = 100 - 100 / (1+rs);
    return pd.DataFrame(rs).rename(columns={'Close':'RSI'})

# %%
#RSI 
for symbol in allSymbols:   
    rsi = RSI(data.loc[data.code==symbol])
    ScriptWiseData[symbol] = ScriptWiseData[symbol].merge(rsi, left_index=True, right_index = True, how='left')

# %% [markdown]
# ### ATR

# %%
def ATR(DF,n=20):
    "function to calculate True Range and Average True Range"
    df = DF.copy()
    df['H-L']=abs(df['High']-df['Low'])
    df['H-PC']=abs(df['High']-df['Close'].shift(1))
    df['L-PC']=abs(df['Low']-df['Close'].shift(1))
    df['TR']=df[['H-L','H-PC','L-PC']].max(axis=1,skipna=False)
    df['ATR'] = df['TR'].rolling(n).mean()
    #df['ATR'] = df['TR'].ewm(span=n,adjust=False,min_periods=n).mean()
    df2 = df.drop(['H-L','H-PC','L-PC'],axis=1)
    return df2[ATRColumns]

# %%
#ATR 
for symbol in allSymbols:
    ScriptWiseData[symbol][ATRColumns] = ATR(data.loc[data.code==symbol])

# %% [markdown]
# ### Bollinger band

# %%
def BollBnd(DF,n=14):
    "function to calculate Bollinger Band"
    df = DF.copy()
    df["MA"] = df['Close'].rolling(n).mean()
    df["BB_up"] = df["MA"] + 2*df['Close'].rolling(n).std(ddof=0) #ddof=0 is required since we want to take the standard deviation of the population and not sample
    df["BB_dn"] = df["MA"] - 2*df['Close'].rolling(n).std(ddof=0) #ddof=0 is required since we want to take the standard deviation of the population and not sample
    df["BB_width"] = df["BB_up"] - df["BB_dn"]
#     df.dropna(inplace=True)
    return df[BollBandColumns]

# %%
#Boll band
for symbol in allSymbols:
    ScriptWiseData[symbol][BollBandColumns] = BollBnd(data.loc[data.code==symbol])

# %% [markdown]
# ### OBV

# %%
def OBV(DF):
    """function to calculate On Balance Volume"""
    df = DF.copy()
    df['daily_ret'] = df['Close'].pct_change()
    df['direction'] = np.where(df['daily_ret']>=0,1,-1)
    df['direction'][0] = 0
    df['vol_adj'] = df['No. of Shares'] * df['direction']
    df['obv'] = df['vol_adj'].cumsum()
    return df['obv']

# %%
#OBV
for symbol in allSymbols:
    ScriptWiseData[symbol]['OBV'] = OBV(data.loc[data.code==symbol])

# %% [markdown]
# ### ADX

# %%
from ta.trend import ADXIndicator
def ADX(DF):
    df = DF.copy()
    adxI = ADXIndicator(df['High'],df['Low'],df['Close'],14,False)
    df['pos_directional_indicator'] = adxI.adx_pos()
    df['neg_directional_indicator'] = adxI.adx_neg()
    df['adx'] = adxI.adx()
    return df[ADXColumns]

# %%
# ADX
for symbol in allSymbols:
    ScriptWiseData[symbol][ADXColumns] = ADX(data.loc[data.code==symbol])

# %%
getNullValuesForSetOfStocks()
# Out:
#                            SUN PHARMACEUTICAL INDUSTRIES LTD.   \
# Open                                                         0
# High                                                         0
# Low                                                          0
# Close                                                        0
# WAP                                                          0
# No. of Shares                                                0
# No. of Trades                                                0
# Total Turnover                                               0
# Deliverable Quantity                                       548
# % Deli. Qty to Traded Qty                                  548
# Spread H-L                                                   0
# Spread C-O                                                   0
# StockName                                                    0
# code                                                         0
# isStock                                                      0
# Index                                                        0
# FastAverage                                                 11
# SlowAverage                                                 25
# MACD                                                        25
# Signal                                                      33
# RSI                                                         27
# TR                                                           1
# ATR                                                         20
# BB_up                                                       13
# BB_dn                                                       13
# MA                                                          13
# BB_width                                                    13
# OBV                                                          0
# pos_directional_indicator                                    0
# neg_directional_indicator                                    0
# adx                                                          0
#
#                            DIVI'S LABORATORIES LTD.   \
# Open                                               0
# High                                               0
# Low                                                0
# Close                                              0
# WAP                                                0
# No. of Shares                                      0
# No. of Trades                                      0
# Total Turnover                                     0
# Deliverable Quantity                              57
# % Deli. Qty to Traded Qty                         57
# Spread H-L                                         0
# Spread C-O                                         0
# StockName                                          0
# code                                               0
# isStock                                            0
# Index                                              0
# FastAverage                                       11
# SlowAverage                                       25
# MACD                                              25
# Signal                                            33
# RSI                                               27
# TR                                                 1
# ATR                                               20
# BB_up                                             13
# BB_dn                                             13
# MA                                                13
# BB_width                                          13
# OBV                                                0
# pos_directional_indicator                          0
# neg_directional_indicator                          0
# adx                                                0
#
#                            DR.REDDY'S LABORATORIES LTD.   HDFC Bank Ltd   \
# Open                                                   0               0
# High                                                   0               0
# Low                                                    0               0
# Close                                                  0               0
# WAP                                                    0               0
# No. of Shares                                          0               0
# No. of Trades                                          0               0
# Total Turnover                                         0               0
# Deliverable Quantity                                 538             538
# % Deli. Qty to Traded Qty                            538             538
# Spread H-L                                             0               0
# Spread C-O                                             0               0
# StockName                                              0               0
# code                                                   0               0
# isStock                                                0               0
# Index                                                  0               0
# FastAverage                                           11              11
# SlowAverage                                           25              25
# MACD                                                  25              25
# Signal                                                33              33
# RSI                                                   27              27
# TR                                                     1               1
# ATR                                                   20              20
# BB_up                                                 13              13
# BB_dn                                                 13              13
# MA                                                    13              13
# BB_width                                              13              13
# OBV                                                    0               0
# pos_directional_indicator                              0               0
# neg_directional_indicator                              0               0
# adx                                                    0               0
#
#                            ICICI BANK LTD.   KOTAK MAHINDRA BANK LTD.   \
# Open                                      0                          0
# High                                      0                          0
# Low                                       0                          0
# Close                                     0                          0
# WAP                                       0                          0
# No. of Shares                             0                          0
# No. of Trades                             0                          0
# Total Turnover                            0                          0
# Deliverable Quantity                    544                        537
# % Deli. Qty to Traded Qty               544                        537
# Spread H-L                                0                          0
# Spread C-O                                0                          0
# StockName                                 0                          0
# code                                      0                          0
# isStock                                   0                          0
# Index                                     0                          0
# FastAverage                              11                         11
# SlowAverage                              25                         25
# MACD                                     25                         25
# Signal                                   33                         33
# RSI                                      27                         27
# TR                                        1                          1
# ATR                                      20                         20
# BB_up                                    13                         13
# BB_dn                                    13                         13
# MA                                       13                         13
# BB_width                                 13                         13
# OBV                                       0                          0
# pos_directional_indicator                 0                          0
# neg_directional_indicator                 0                          0
# adx                                       0                          0
#
#                            TATA STEEL LTD.   JSW STEEL LTD.   \
# Open                                      0                0
# High                                      0                0
# Low                                       0                0
# Close                                     0                0
# WAP                                       0                0
# No. of Shares                             0                0
# No. of Trades                             0                0
# Total Turnover                            0                0
# Deliverable Quantity                    545              580
# % Deli. Qty to Traded Qty               545              580
# Spread H-L                                0                0
# Spread C-O                                0                0
# StockName                                 0                0
# code                                      0                0
# isStock                                   0                0
# Index                                     0                0
# FastAverage                              11               11
# SlowAverage                              25               25
# MACD                                     25               25
# Signal                                   33               33
# RSI                                      27               27
# TR                                        1                1
# ATR                                      20               20
# BB_up                                    13               13
# BB_dn                                    13               13
# MA                                       13               13
# BB_width                                 13               13
# OBV                                       0                0
# pos_directional_indicator                 0                0
# neg_directional_indicator                 0                0
# adx                                       0                0
#
#                            HINDALCO INDUSTRIES LTD.   BAJAJ AUTO LTD.   \
# Open                                               0                 0
# High                                               0                 0
# Low                                                0                 0
# Close                                              0                 0
# WAP                                                0                 0
# No. of Shares                                      0                 0
# No. of Trades                                      0                 0
# Total Turnover                                     0                 0
# Deliverable Quantity                             555                 1
# % Deli. Qty to Traded Qty                        555                 1
# Spread H-L                                         0                 0
# Spread C-O                                         0                 0
# StockName                                          0                 0
# code                                               0                 0
# isStock                                            0                 0
# Index                                              0                 0
# FastAverage                                       11                11
# SlowAverage                                       25                25
# MACD                                              25                25
# Signal                                            33                33
# RSI                                               27                27
# TR                                                 1                 1
# ATR                                               20                20
# BB_up                                             13                13
# BB_dn                                             13                13
# MA                                                13                13
# BB_width                                          13                13
# OBV                                                0                 0
# pos_directional_indicator                          0                 0
# neg_directional_indicator                          0                 0
# adx                                                0                 0
#
#                            TATA MOTORS LTD.   MARUTI SUZUKI INDIA LTD.   \
# Open                                       0                          0
# High                                       0                          0
# Low                                        0                          0
# Close                                      0                          0
# WAP                                        0                          0
# No. of Shares                              0                          0
# No. of Trades                              0                          0
# Total Turnover                             0                          0
# Deliverable Quantity                     542                         81
# % Deli. Qty to Traded Qty                542                         81
# Spread H-L                                 0                          0
# Spread C-O                                 0                          0
# StockName                                  0                          0
# code                                       0                          0
# isStock                                    0                          0
# Index                                      0                          0
# FastAverage                               11                         11
# SlowAverage                               25                         25
# MACD                                      25                         25
# Signal                                    33                         33
# RSI                                       27                         27
# TR                                         1                          1
# ATR                                       20                         20
# BB_up                                     13                         13
# BB_dn                                     13                         13
# MA                                        13                         13
# BB_width                                  13                         13
# OBV                                        0                          0
# pos_directional_indicator                  0                          0
# neg_directional_indicator                  0                          0
# adx                                        0                          0
#
#                            INFOSYS LTD.   TATA CONSULTANCY SERVICES LTD.   \
# Open                                   0                                0
# High                                   0                                0
# Low                                    0                                0
# Close                                  0                                0
# WAP                                    0                                0
# No. of Shares                          0                                0
# No. of Trades                          0                                0
# Total Turnover                         0                                0
# Deliverable Quantity                 539                                2
# % Deli. Qty to Traded Qty            539                                2
# Spread H-L                             0                                0
# Spread C-O                             0                                0
# StockName                              0                                0
# code                                   0                                0
# isStock                                0                                0
# Index                                  0                                0
# FastAverage                           11                               11
# SlowAverage                           25                               25
# MACD                                  25                               25
# Signal                                33                               33
# RSI                                   27                               27
# TR                                     1                                1
# ATR                                   20                               20
# BB_up                                 13                               13
# BB_dn                                 13                               13
# MA                                    13                               13
# BB_width                              13                               13
# OBV                                    0                                0
# pos_directional_indicator              0                                0
# neg_directional_indicator              0                                0
# adx                                    0                                0
#
#                            WIPRO LTD.   BSE Healthcare  \
# Open                                 0            3810
# High                                 0            3810
# Low                                  0            3810
# Close                                0               0
# WAP                                  0            5282
# No. of Shares                        0            5282
# No. of Trades                        0            5282
# Total Turnover                       0            5282
# Deliverable Quantity               538            5282
# % Deli. Qty to Traded Qty          538            5282
# Spread H-L                           0            5282
# Spread C-O                           0            5282
# StockName                            0               0
# code                                 0               0
# isStock                              0               0
# Index                                0            5282
# FastAverage                         11              11
# SlowAverage                         25              25
# MACD                                25              25
# Signal                              33              33
# RSI                                 27              27
# TR                                   1            3810
# ATR                                 20            3829
# BB_up                               13              13
# BB_dn                               13              13
# MA                                  13              13
# BB_width                            13              13
# OBV                                  0            5282
# pos_directional_indicator            0            5267
# neg_directional_indicator            0            5267
# adx                                  0            5255
#
#                            BSE Information Technology  BSE BANKEX  BSE METAL  \
# Open                                             3810         369       1165
# High                                             3810         369       1165
# Low                                              3810         369       1165
# Close                                               0           0          0
# WAP                                              5282        4784       5282
# No. of Shares                                    5282        4784       5282
# No. of Trades                                    5282        4784       5282
# Total Turnover                                   5282        4784       5282
# Deliverable Quantity                             5282        4784       5282
# % Deli. Qty to Traded Qty                        5282        4784       5282
# Spread H-L                                       5282        4784       5282
# Spread C-O                                       5282        4784       5282
# StockName                                           0           0          0
# code                                                0           0          0
# isStock                                             0           0          0
# Index                                            5282        4784       5282
# FastAverage                                        11          11         11
# SlowAverage                                        25          25         25
# MACD                                               25          25         25
# Signal                                             33          33         33
# RSI                                                27          27         27
# TR                                               3810         369       1165
# ATR                                              3829         388       1184
# BB_up                                              13          13         13
# BB_dn                                              13          13         13
# MA                                                 13          13         13
# BB_width                                           13          13         13
# OBV                                              5282        4784       5282
# pos_directional_indicator                        5267        4769       5267
# neg_directional_indicator                        5267        4769       5267
# adx                                              5255        4757       5255
#
#                            BSE AUTO  BSE SENSEX
# Open                           1165           0
# High                           1165           0
# Low                            1165           0
# Close                             0           0
# WAP                            5282        5282
# No. of Shares                  5282        5282
# No. of Trades                  5282        5282
# Total Turnover                 5282        5282
# Deliverable Quantity           5282        5282
# % Deli. Qty to Traded Qty      5282        5282
# Spread H-L                     5282        5282
# Spread C-O                     5282        5282
# StockName                         0           0
# code                              0           0
# isStock                           0           0
# Index                          5282        5282
# FastAverage                      11          11
# SlowAverage                      25          25
# MACD                             25          25
# Signal                           33          33
# RSI                              27          27
# TR                             1165           1
# ATR                            1184          20
# BB_up                            13          13
# BB_dn                            13          13
# MA                               13          13
# BB_width                         13          13
# OBV                            5282        5282
# pos_directional_indicator      5267           0
# neg_directional_indicator      5267           0
# adx                            5255           0

# %% [markdown]
# # Removing Extra Columms

# %%
OriginalScriptWiseData = ScriptWiseData
for symbol in allSymbols:
    ScriptWiseData[symbol] = ScriptWiseData[symbol][['Close']+TechnicalIndicators]

# %% [markdown]
# ## Dropping null values

# %%
# drop rows from the stock whose technical indicator values are null. 
for stock in stocks:
#     ScriptWiseData[stock] = ScriptWiseData[stock].dropna(subset=AllIndicatorColumns)
    ScriptWiseData[stock] = ScriptWiseData[stock].dropna()

# %%
# ScriptWiseData['BOM500180'][ScriptWiseData['BOM500180']['MACD'].isna()]
getNullValuesForSetOfStocks()
# Out:
#        SUN PHARMACEUTICAL INDUSTRIES LTD.   DIVI'S LABORATORIES LTD.   \
# Close                                    0                          0
# RSI                                      0                          0
# ATR                                      0                          0
# MACD                                     0                          0
# adx                                      0                          0
# OBV                                      0                          0
#
#        DR.REDDY'S LABORATORIES LTD.   HDFC Bank Ltd   ICICI BANK LTD.   \
# Close                              0               0                 0
# RSI                                0               0                 0
# ATR                                0               0                 0
# MACD                               0               0                 0
# adx                                0               0                 0
# OBV                                0               0                 0
#
#        KOTAK MAHINDRA BANK LTD.   TATA STEEL LTD.   JSW STEEL LTD.   \
# Close                          0                 0                0
# RSI                            0                 0                0
# ATR                            0                 0                0
# MACD                           0                 0                0
# adx                            0                 0                0
# OBV                            0                 0                0
#
#        HINDALCO INDUSTRIES LTD.   BAJAJ AUTO LTD.   TATA MOTORS LTD.   \
# Close                          0                 0                  0
# RSI                            0                 0                  0
# ATR                            0                 0                  0
# MACD                           0                 0                  0
# adx                            0                 0                  0
# OBV                            0                 0                  0
#
#        MARUTI SUZUKI INDIA LTD.   INFOSYS LTD.   \
# Close                          0              0
# RSI                            0              0
# ATR                            0              0
# MACD                           0              0
# adx                            0              0
# OBV                            0              0
#
#        TATA CONSULTANCY SERVICES LTD.   WIPRO LTD.   BSE Healthcare  \
# Close                                0            0               0
# RSI                                  0            0              27
# ATR                                  0            0            3829
# MACD                                 0            0              25
# adx                                  0            0            5255
# OBV                                  0            0            5282
#
#        BSE Information Technology  BSE BANKEX  BSE METAL  BSE AUTO  BSE SENSEX
# Close                           0           0          0         0           0
# RSI                            27          27         27        27          27
# ATR                          3829         388       1184      1184          20
# MACD                           25          25         25        25          25
# adx                          5255        4757       5255      5255           0
# OBV                          5282        4784       5282      5282        5282

# %%
finalDateRanges =pd.DataFrame(columns = ['Stock Code', 'Stock Name', 'First Date', 'Last Date']) 
for s in stocks:
    r = [s, getStockNameFromStockCode(s), ScriptWiseData[s].index.min(),  ScriptWiseData[s].index.max()]
    finalDateRanges.loc[len(finalDateRanges)] = r
finalDateRanges
# Out:
#    Stock Code                           Stock Name  First Date   Last Date
# 0   BOM524715  SUN PHARMACEUTICAL INDUSTRIES LTD.   2000-02-10  2021-03-23
# 1   BOM532488            DIVI'S LABORATORIES LTD.   2003-04-23  2021-03-23
# 2   BOM500124        DR.REDDY'S LABORATORIES LTD.   2000-02-10  2021-03-23
# 3   BOM500180                       HDFC Bank Ltd   2000-02-10  2021-03-23
# 4   BOM532174                     ICICI BANK LTD.   2000-02-10  2021-03-23
# 5   BOM500247            KOTAK MAHINDRA BANK LTD.   2000-02-10  2021-03-23
# 6   BOM500470                     TATA STEEL LTD.   2000-02-10  2021-03-23
# 7   BOM500228                      JSW STEEL LTD.   2000-02-10  2021-03-23
# 8   BOM500440            HINDALCO INDUSTRIES LTD.   2000-02-10  2021-03-23
# 9   BOM532977                     BAJAJ AUTO LTD.   2008-07-02  2021-03-23
# 10  BOM500570                    TATA MOTORS LTD.   2000-02-10  2021-03-23
# 11  BOM532500            MARUTI SUZUKI INDIA LTD.   2003-08-18  2021-03-23
# 12  BOM500209                        INFOSYS LTD.   2000-02-10  2021-03-23
# 13  BOM532540      TATA CONSULTANCY SERVICES LTD.   2004-10-01  2021-03-23
# 14  BOM507685                          WIPRO LTD.   2000-02-10  2021-03-23

# %% [markdown]
# # ADF Test for closing price

# %%
stock = stocks[0]
adf_testResult = pd.DataFrame(adf_test(ScriptWiseData[stocks[0]].Close, stocks[0])[0], columns = ['Value']).transpose().set_index(['Stock Name', 'Stock Code'])
for i in range(1, len(stocks)):
    res = pd.DataFrame(adf_test(ScriptWiseData[stocks[i]].Close, stocks[i])[0], columns = ['Value']).transpose().set_index(['Stock Name', 'Stock Code'])
    adf_testResult = adf_testResult.append(res)
adf_testResult['Result'] = adf_testResult['p-value'].apply(lambda x: 'Stationary' if x<0.05 else 'Non-Stationary')
# adf_testResult.to_csv('Outputs/adfTest.csv')
adf_testResult.head()
# Out:
#                                                ADF test statistic   p-value  \
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715           -5.025755   0.00002
# DIVI'S LABORATORIES LTD.            BOM532488           -3.571373  0.006333
# DR.REDDY'S LABORATORIES LTD.        BOM500124           -0.081726  0.951229
# HDFC Bank Ltd                       BOM500180           -2.223959  0.197665
# ICICI BANK LTD.                     BOM532174           -2.658944  0.081416
#
#                                                # lags used #observations  \
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715          0.0        5253.0
# DIVI'S LABORATORIES LTD.            BOM532488         32.0        4424.0
# DR.REDDY'S LABORATORIES LTD.        BOM500124         28.0        5226.0
# HDFC Bank Ltd                       BOM500180          0.0        5254.0
# ICICI BANK LTD.                     BOM532174          1.0        5252.0
#
#                                                critical value (1%)  \
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715            -3.431595
# DIVI'S LABORATORIES LTD.            BOM532488            -3.431829
# DR.REDDY'S LABORATORIES LTD.        BOM500124            -3.431602
# HDFC Bank Ltd                       BOM500180            -3.431595
# ICICI BANK LTD.                     BOM532174            -3.431596
#
#                                                critical value (5%)  \
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715             -2.86209
# DIVI'S LABORATORIES LTD.            BOM532488            -2.862194
# DR.REDDY'S LABORATORIES LTD.        BOM500124            -2.862093
# HDFC Bank Ltd                       BOM500180             -2.86209
# ICICI BANK LTD.                     BOM532174             -2.86209
#
#                                                critical value (10%)  \
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715             -2.567063
# DIVI'S LABORATORIES LTD.            BOM532488             -2.567118
# DR.REDDY'S LABORATORIES LTD.        BOM500124             -2.567064
# HDFC Bank Ltd                       BOM500180             -2.567063
# ICICI BANK LTD.                     BOM532174             -2.567063
#
#                                                         Result
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715       Stationary
# DIVI'S LABORATORIES LTD.            BOM532488       Stationary
# DR.REDDY'S LABORATORIES LTD.        BOM500124   Non-Stationary
# HDFC Bank Ltd                       BOM500180   Non-Stationary
# ICICI BANK LTD.                     BOM532174   Non-Stationary

# %% [markdown]
# # Train test and validation split

# %%
def TrainTestSplitByDateRange(df,test_start_date = '2020-03-02',test_end_date = '2021-03-23'):
    train = df.loc[:test_start_date]
    test = df.loc[test_start_date:test_end_date]
    return train, test[1:]

# %% [markdown]
# # Code Addition Tavish -----------------------------------------------

# %% [markdown]
# #ARIMA

# %% [markdown]
# ### AutoARIMA DataFrame

# %%
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima

# %%
AutoArimaResults = pd.DataFrame(columns=['p Closing Values', 'd Closing Values', 'q Closing Values','p N Closing Values', 'd N Closing Values', 'q N Closing Values','p Closing Percentage', 'd Closing Percentage', 'q Closing Percentage'], index = stocks)
#AutoArimaResults = pd.read_csv('Outputs/AutoArimaResults.csv',index_col='Unnamed: 0')

# %%
# AutoArimaResults.to_csv('Outputs/AutoArimaResults.csv')

# %%
def CalculateAutoArima(stockcode, data, parameter ,p ,d,q):
    if(AutoArimaResults.loc[:, [p, d, q]].isnull().sum(axis=1)[stockcode] > 0):
        params = auto_arima(data[parameter], maxiter = 1000)
        AutoArimaResults.loc[stockcode, [p,d,q]] = params.order
        return params.order
    else:
        return tuple(AutoArimaResults.loc[stockcode, [p, d, q]])

# %% [markdown]
# ### Common Functions

# %%
def errorEvaluation(actual, pred):
    RMSE = mean_squared_error(actual, pred, squared=False)
    MAPE = mean_absolute_percentage_error(actual,pred)
    R2 = r2_score(actual,pred)
    Noise = float(pred.diff().abs().mean())
    return [RMSE, MAPE, R2, Noise]

# %%
def modified_prediction_frame(_df_pred, index):
    _df_pred = _df_pred.to_frame()
    _df_pred['Date'] = index
    pd.to_datetime(_df_pred['Date'])
    _df_pred.set_index('Date', inplace=True)
    _df_pred.rename(columns={0 : 'Predicted'}, inplace=True)
    return _df_pred

# %% [markdown]
# ## ARIMA for Closing Values

# %% [markdown]
# # Tavish - Fix this one too.

# %% [markdown]
# ### Generic Function For ARIMA Closing Prices

# %%
def ARIMA_Model_Generic(StockCode, data, feature, Results, Order, train_data, test_data):
    print("Modeling for the Stock: {}".format(StockCode))

    start = len(train_data)
    end = len(train_data) + len(test_data) - 1

    print("ADF Test for the given series.")
    adf, Stationarity = adf_test(train_data[feature], title=StockCode)
    print(adf)
    print('----------------------------------------------------------------------------')
    Results.loc[StockCode,'Stationarity'] = Stationarity
    model = ARIMA(train_data[feature], order = Order)

    results = model.fit()
    print(results.params)
    print("Order: " + str(Order) )
    print('---------------------------------------------------------------------------')
    Results.loc[StockCode, 'Order'] = str(Order)

    predictions = results.predict(start = start, end = end, typ ='levels')
    predictions = modified_prediction_frame(predictions, test_data[feature].index)

    errorEval = errorEvaluation(test_data[feature], predictions)
    RMSE, MAPE, R2, Noise = errorEval
    Results.loc[StockCode, ['RMSE', 'MAPE', 'R2', 'Noise']] = errorEval
    print("RMSE: {0} \nMape: {1} \nR2: {2} \nNoise: {3}".format(RMSE, MAPE, R2, Noise))
    print('---------------------------------------------------------------------------')

    print('Description of the Predicted Data')
    print(predictions.describe())
    pred_mean = predictions.mean(numeric_only=True)
    Results.loc[StockCode, 'Predictions Mean'] = str(float(pred_mean))
    Results.loc[StockCode, 'Model'] = model
    print('---------------------------------------------------------------------------')

    print('Description of the Actual Data')
    print(test_data[feature].describe())
    Results.loc[StockCode, 'Actual Mean'] = str(test_data[feature].mean())
    return predictions

# %%
try:
    ArimaModelPricesResults = pd.read_csv('./Outputs/ArimaModelPricesResults.csv')
except FileNotFoundError:
    ArimaModelPricesResults = pd.DataFrame(columns=['Stationarity', 'Order', 'RMSE', 'MAPE', 'R2', 'Noise', 'Predictions Mean', 'Actual Mean', 'Model'], index = stocks)

# %%
feature = 'Close'
for stock in stocks:
    print("Working for Stock - {}".format(stock))
    try:
        train_data, test_data = TrainTestSplitByDateRange(ScriptWiseData[stock])
        Order = CalculateAutoArima(stock, train_data, feature,  p= 'p Closing Values',d = 'd Closing Values', q = 'q Closing Values')
        ARIMA_Model_Generic(StockCode = stock, data = ScriptWiseData, feature = feature, Results=ArimaModelPricesResults, Order=Order, train_data=train_data, test_data=test_data)
    except Exception as ex:
        pass
# Out:
# Working for Stock - BOM524715
# Modeling for the Stock: BOM524715
# ADF Test for the given series.
# ADF test statistic                                -4.874453
# p-value                                            0.000039
# # lags used                                             0.0
# #observations                                        4989.0
# Stock Name              SUN PHARMACEUTICAL INDUSTRIES LTD.
# Stock Code                                        BOM524715
# critical value (1%)                               -3.431661
# critical value (5%)                                -2.86212
# critical value (10%)                              -2.567078
# dtype: object
# ----------------------------------------------------------------------------
# const           -0.356600
# ma.L1.D.Close    0.048973
# dtype: float64
# Order: (0, 1, 1)
# ---------------------------------------------------------------------------
# RMSE: 212.88049529842894
# Mape: 0.35827202842248984
# R2: -8.61615470259654
# Noise: 0.3566004015639237
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   321.455060
# std     27.228023
# min    274.562108
# 25%    298.008584
# 50%    321.455060
# 75%    344.901537
# max    368.348013
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     512.652841
# std       68.779536
# min      324.000000
# 25%      475.437500
# 50%      507.100000
# 75%      570.187500
# max      643.500000
# Name: Close, dtype: float64
# Working for Stock - BOM532488
# Modeling for the Stock: BOM532488
# ADF Test for the given series.
# ADF test statistic                      -4.472039
# p-value                                  0.000221
# # lags used                                  27.0
# #observations                              4165.0
# Stock Name              DIVI'S LABORATORIES LTD.
# Stock Code                              BOM532488
# critical value (1%)                     -3.431921
# critical value (5%)                     -2.862234
# critical value (10%)                     -2.56714
# dtype: object
# ----------------------------------------------------------------------------
# Working for Stock - BOM500124
# Modeling for the Stock: BOM500124
# ADF Test for the given series.
# ADF test statistic                          -1.341356
# p-value                                      0.610046
# # lags used                                       1.0
# #observations                                  4989.0
# Stock Name              DR.REDDY'S LABORATORIES LTD.
# Stock Code                                  BOM500124
# critical value (1%)                         -3.431661
# critical value (5%)                          -2.86212
# critical value (10%)                        -2.567078
# dtype: object
# ----------------------------------------------------------------------------
# const            0.304722
# ar.L1.D.Close    1.174155
# ar.L2.D.Close   -0.225783
# ma.L1.D.Close   -1.119207
# ma.L2.D.Close    0.161346
# dtype: float64
# Order: (2, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 1543.2637085993422
# Mape: 0.3089561841407168
# R2: -4.838022613956811
# Noise: 0.4953263215512092
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#          Predicted
# count   264.000000
# mean   2982.825247
# std      28.548138
# min    2895.482389
# 25%    2965.148919
# 50%    2985.677403
# 75%    3005.717666
# max    3025.753212
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count     264.000000
# mean     4398.125758
# std       639.928343
# min      2622.750000
# 25%      3982.500000
# 50%      4474.125000
# 75%      4927.125000
# max      5416.600000
# Name: Close, dtype: float64
# Working for Stock - BOM500180
# Modeling for the Stock: BOM500180
# ADF Test for the given series.
# ADF test statistic           -2.206299
# p-value                       0.203967
# # lags used                        0.0
# #observations                   4990.0
# Stock Name              HDFC Bank Ltd
# Stock Code                   BOM500180
# critical value (1%)          -3.431661
# critical value (5%)          -2.862119
# critical value (10%)         -2.567078
# dtype: object
# ----------------------------------------------------------------------------
# const    0.186603
# dtype: float64
# Order: (0, 1, 0)
# ---------------------------------------------------------------------------
# RMSE: 215.873438593641
# Mape: 0.16718927419986196
# R2: 0.1074205059594665
# Noise: 0.18660320641288308
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#          Predicted
# count   264.000000
# mean   1206.874925
# std      14.247983
# min    1182.336603
# 25%    1194.605764
# 50%    1206.874925
# 75%    1219.144086
# max    1231.413246
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count     264.000000
# mean     1191.321023
# std       228.928491
# min       765.450000
# 25%      1028.837500
# 50%      1118.250000
# 75%      1408.275000
# max      1626.600000
# Name: Close, dtype: float64
# Working for Stock - BOM532174
# Modeling for the Stock: BOM532174
# ADF Test for the given series.
# ADF test statistic              -2.58983
# p-value                         0.095118
# # lags used                          1.0
# #observations                     4988.0
# Stock Name              ICICI BANK LTD.
# Stock Code                     BOM532174
# critical value (1%)            -3.431662
# critical value (5%)             -2.86212
# critical value (10%)           -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const            0.067646
# ar.L1.D.Close    0.838973
# ar.L2.D.Close   -0.043838
# ma.L1.D.Close   -0.809885
# dtype: float64
# Order: (2, 1, 1)
# ---------------------------------------------------------------------------
# RMSE: 129.37418451164956
# Mape: 0.3038965505476325
# R2: -0.6323427901664598
# Noise: 0.07467714828209722
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   517.379718
# std      5.221439
# min    506.666905
# 25%    512.963905
# 50%    517.411602
# 75%    521.859299
# max    526.306995
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     431.724053
# std      101.453266
# min      283.900000
# 25%      351.850000
# 50%      384.575000
# 75%      512.600000
# max      674.000000
# Name: Close, dtype: float64
# Working for Stock - BOM500247
# Modeling for the Stock: BOM500247
# ADF Test for the given series.
# ADF test statistic                      -0.837502
# p-value                                  0.807857
# # lags used                                   5.0
# #observations                              4984.0
# Stock Name              KOTAK MAHINDRA BANK LTD.
# Stock Code                              BOM500247
# critical value (1%)                     -3.431663
# critical value (5%)                      -2.86212
# critical value (10%)                    -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const            0.286724
# ar.L1.D.Close   -0.277888
# ma.L1.D.Close    0.301695
# ma.L2.D.Close   -0.014915
# dtype: float64
# Order: (1, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 290.1923657416588
# Mape: 0.1915783832395045
# R2: -0.02582612390137773
# Noise: 0.2866723257058114
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#          Predicted
# count   264.000000
# mean   1638.341748
# std      21.892559
# min    1600.651057
# 25%    1619.489623
# 50%    1638.341708
# 75%    1657.193793
# max    1676.045878
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count     264.00000
# mean     1528.21875
# std       287.06034
# min      1100.35000
# 25%      1307.87500
# 50%      1380.50000
# 75%      1846.66250
# max      2021.65000
# Name: Close, dtype: float64
# Working for Stock - BOM500470
# Modeling for the Stock: BOM500470
# ADF Test for the given series.
# ADF test statistic             -2.627445
# p-value                         0.087457
# # lags used                          9.0
# #observations                     4981.0
# Stock Name              TATA STEEL LTD.
# Stock Code                     BOM500470
# critical value (1%)            -3.431664
# critical value (5%)             -2.86212
# critical value (10%)           -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const            0.044890
# ar.L1.D.Close    1.303208
# ar.L2.D.Close   -0.837643
# ma.L1.D.Close   -1.264871
# ma.L2.D.Close    0.796480
# dtype: float64
# Order: (2, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 174.74806565713232
# Mape: 0.24724915397231928
# R2: -0.22433390957361032
# Noise: 0.07034459453211661
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   370.911658
# std      3.442962
# min    363.514544
# 25%    367.962501
# 50%    370.917719
# 75%    373.869251
# max    376.820782
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     452.076326
# std      158.229162
# min      253.850000
# 25%      323.887500
# 50%      403.350000
# 75%      621.875000
# max      776.700000
# Name: Close, dtype: float64
# Working for Stock - BOM500228
# Modeling for the Stock: BOM500228
# ADF Test for the given series.
# ADF test statistic            -2.235173
# p-value                        0.193728
# # lags used                         8.0
# #observations                    4960.0
# Stock Name              JSW STEEL LTD.
# Stock Code                    BOM500228
# critical value (1%)           -3.431669
# critical value (5%)           -2.862123
# critical value (10%)           -2.56708
# dtype: object
# ----------------------------------------------------------------------------
# const    0.046186
# dtype: float64
# Order: (0, 1, 0)
# ---------------------------------------------------------------------------
# RMSE: 95.5917297483236
# Mape: 0.2863398101078803
# R2: -0.13032561073682003
# Noise: 0.04618558776166992
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   241.069590
# std      3.526475
# min    234.996186
# 25%    238.032888
# 50%    241.069590
# 75%    244.106293
# max    247.142995
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     281.715341
# std       90.082955
# min      140.000000
# 25%      193.375000
# 50%      285.125000
# 75%      366.200000
# max      445.650000
# Name: Close, dtype: float64
# Working for Stock - BOM500440
# Modeling for the Stock: BOM500440
# ADF Test for the given series.
# ADF test statistic                      -2.203395
# p-value                                  0.205015
# # lags used                                   0.0
# #observations                              4989.0
# Stock Name              HINDALCO INDUSTRIES LTD.
# Stock Code                              BOM500440
# critical value (1%)                     -3.431661
# critical value (5%)                      -2.86212
# critical value (10%)                    -2.567078
# dtype: object
# ----------------------------------------------------------------------------
# const   -0.137332
# dtype: float64
# Order: (0, 1, 0)
# ---------------------------------------------------------------------------
# RMSE: 96.70127527930536
# Mape: 0.33621562387203596
# R2: -1.180995565087469
# Noise: 0.13733213068751982
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   131.653493
# std     10.485917
# min    113.594317
# 25%    122.623905
# 50%    131.653493
# 75%    140.683080
# max    149.712668
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     192.293750
# std       65.603785
# min       87.950000
# 25%      146.887500
# 50%      176.725000
# 75%      238.525000
# max      359.350000
# Name: Close, dtype: float64
# Working for Stock - BOM532977
# Modeling for the Stock: BOM532977
# ADF Test for the given series.
# ADF test statistic             -2.338397
# p-value                         0.159883
# # lags used                          2.0
# #observations                     2884.0
# Stock Name              BAJAJ AUTO LTD.
# Stock Code                     BOM532977
# critical value (1%)            -3.432619
# critical value (5%)            -2.862543
# critical value (10%)           -2.567304
# dtype: object
# ----------------------------------------------------------------------------
# Working for Stock - BOM500570
# Modeling for the Stock: BOM500570
# ADF Test for the given series.
# ADF test statistic               -2.21147
# p-value                          0.202109
# # lags used                          22.0
# #observations                      4967.0
# Stock Name              TATA MOTORS LTD.
# Stock Code                      BOM500570
# critical value (1%)             -3.431667
# critical value (5%)             -2.862122
# critical value (10%)             -2.56708
# dtype: object
# ----------------------------------------------------------------------------
# Working for Stock - BOM532500
# Modeling for the Stock: BOM532500
# ADF Test for the given series.
# ADF test statistic                      -0.588969
# p-value                                  0.873455
# # lags used                                  29.0
# #observations                              4082.0
# Stock Name              MARUTI SUZUKI INDIA LTD.
# Stock Code                              BOM532500
# critical value (1%)                     -3.431953
# critical value (5%)                     -2.862248
# critical value (10%)                    -2.567147
# dtype: object
# ----------------------------------------------------------------------------
# const            1.474546
# ar.L1.D.Close   -0.897252
# ar.L2.D.Close   -0.799624
# ma.L1.D.Close    0.947830
# ma.L2.D.Close    0.821216
# dtype: float64
# Order: (2, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 881.6736874052285
# Mape: 0.12355726873411636
# R2: 0.18413465976418608
# Noise: 1.587953110898179
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#          Predicted
# count   264.000000
# mean   6474.623891
# std     112.597100
# min    6276.366886
# 25%    6377.677938
# 50%    6474.628059
# 75%    6571.579447
# max    6668.530836
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count     264.000000
# mean     6530.981818
# std       977.963683
# min      4011.650000
# 25%      5759.375000
# 50%      6859.425000
# 75%      7190.487500
# max      8236.050000
# Name: Close, dtype: float64
# Working for Stock - BOM500209
# Modeling for the Stock: BOM500209
# ADF Test for the given series.
# ADF test statistic          -4.729905
# p-value                      0.000074
# # lags used                      32.0
# #observations                  4958.0
# Stock Name              INFOSYS LTD.
# Stock Code                  BOM500209
# critical value (1%)          -3.43167
# critical value (5%)         -2.862123
# critical value (10%)         -2.56708
# dtype: object
# ----------------------------------------------------------------------------
# const           -1.886870
# ar.L1.D.Close    1.712731
# ar.L2.D.Close   -0.983228
# ma.L1.D.Close   -1.668015
# ma.L2.D.Close    0.925370
# dtype: float64
# Order: (2, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 620.3783393224403
# Mape: 0.4482279512013305
# R2: -5.224318041784149
# Noise: 1.8862368945705836
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   498.928757
# std    144.115822
# min    250.778784
# 25%    375.033426
# 50%    498.344926
# 75%    624.398612
# max    744.798617
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count     264.000000
# mean      981.074811
# std       249.135048
# min       526.700000
# 25%       714.112500
# 50%       972.275000
# 75%      1169.412500
# max      1387.700000
# Name: Close, dtype: float64
# Working for Stock - BOM532540
# Modeling for the Stock: BOM532540
# ADF Test for the given series.
# ADF test statistic                            -1.981595
# p-value                                        0.294701
# # lags used                                         0.0
# #observations                                    3823.0
# Stock Name              TATA CONSULTANCY SERVICES LTD.
# Stock Code                                    BOM532540
# critical value (1%)                           -3.432062
# critical value (5%)                           -2.862296
# critical value (10%)                          -2.567173
# dtype: object
# ----------------------------------------------------------------------------
# const            0.249135
# ar.L1.D.Close    0.241147
# ar.L2.D.Close    0.701390
# ma.L1.D.Close   -0.233018
# ma.L2.D.Close   -0.734857
# dtype: float64
# Order: (2, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 569.6074769752083
# Mape: 0.16728376661836108
# R2: -0.48346918622342616
# Noise: 0.5098078398179752
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#          Predicted
# count   264.000000
# mean   2098.166083
# std      31.373850
# min    2004.739697
# 25%    2082.189941
# 50%    2105.258562
# 75%    2122.360679
# max    2138.819158
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count     264.000000
# mean     2459.927273
# std       468.554923
# min      1636.100000
# 25%      2047.575000
# 50%      2361.325000
# 75%      2827.037500
# max      3308.200000
# Name: Close, dtype: float64
# Working for Stock - BOM507685
# Modeling for the Stock: BOM507685
# ADF Test for the given series.
# ADF test statistic        -9.271014
# p-value                         0.0
# # lags used                    32.0
# #observations                4958.0
# Stock Name              WIPRO LTD.
# Stock Code                BOM507685
# critical value (1%)        -3.43167
# critical value (5%)       -2.862123
# critical value (10%)       -2.56708
# dtype: object
# ----------------------------------------------------------------------------
# const           -1.199063
# ar.L1.D.Close    0.911510
# ar.L2.D.Close    0.761551
# ar.L3.D.Close   -1.160562
# ar.L4.D.Close    0.050631
# ar.L5.D.Close    0.107394
# ma.L1.D.Close   -0.775720
# ma.L2.D.Close   -0.818392
# ma.L3.D.Close    0.947032
# dtype: float64
# Order: (5, 1, 3)
# ---------------------------------------------------------------------------
# RMSE: 297.74191785005837
# Mape: 0.6889773344945247
# R2: -10.356811187235506
# Noise: 1.2442422178777772
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean    64.231263
# std     91.624322
# min    -93.766495
# 25%    -15.123733
# 50%     63.388109
# 75%    141.773123
# max    222.256650
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     302.515152
# std       88.518871
# min      161.950000
# 25%      218.275000
# 50%      298.825000
# 75%      363.737500
# max      458.750000
# Name: Close, dtype: float64

# %%
ArimaModelPricesResults.to_csv('./Outputs/ArimaModelPricesResults.csv')

# %% [markdown]
# ## ARIMA for Normalized Closing Price

# %% [markdown]
# ### Normalizing the Values  - Normalized_Prices

# %% [markdown]
# # TAVISH  - CREATE A COPY HERE

# %%
normalized_columns = ['Normalized Closing', 'Normalized RSI', 'Normalized ATR', 'Normalized MACD', 'Normalized ADX', 'Normalized OBV']
normalized_TechnicalIndicators = ['Normalized RSI', 'Normalized ATR', 'Normalized MACD', 'Normalized ADX', 'Normalized OBV']

# %%
cols = list(ScriptWiseData[stock].columns)
cols
# Out:
# ['Close', 'RSI', 'ATR', 'MACD', 'adx', 'OBV']

# %%
# first value normalization
for stock in stocks:
    cols = list(ScriptWiseData[stock].columns)
    for count in range(len(cols)):
        benchmark_prices = ScriptWiseData[stock][cols[count]].iloc[0]
        ScriptWiseData[stock][normalized_columns[count]] = ScriptWiseData[stock][cols[count]].div(benchmark_prices).mul(100)

# %% [markdown]
# ###  ARIMA Normalized Closing Prices

# %%
try:
    ArimaModelPricesResults_Norm = pd.read_csv('./Outputs/ArimaModelPricesResults_Norm.csv')
except FileNotFoundError:
    ArimaModelPricesResults_Norm = pd.DataFrame(columns=['Stationarity', 'Order', 'RMSE', 'MAPE', 'R2','Noise', 'Predictions Mean', 'Actual Mean'], index = stocks)

# %%
for stock in stocks:
    print("Working for Stock {}".format(stock))
    train_data, test_data = TrainTestSplitByDateRange(ScriptWiseData[stock])
    feature = 'Normalized Closing'
    Order = CalculateAutoArima(stock, train_data, feature,'p N Closing Values', 'd N Closing Values', 'q N Closing Values')
    ARIMA_Model_Generic(StockCode= stock, data = ScriptWiseData, feature = feature, Results=ArimaModelPricesResults_Norm, Order=Order, train_data=train_data, test_data=test_data)
# Out:
# Working for Stock BOM524715
# Modeling for the Stock: BOM524715
# ADF Test for the given series.
# ADF test statistic                                -4.874453
# p-value                                            0.000039
# # lags used                                             0.0
# #observations                                        4989.0
# Stock Name              SUN PHARMACEUTICAL INDUSTRIES LTD.
# Stock Code                                        BOM524715
# critical value (1%)                               -3.431661
# critical value (5%)                                -2.86212
# critical value (10%)                              -2.567078
# dtype: object
# ----------------------------------------------------------------------------
# const                        -0.016625
# ma.L1.D.Normalized Closing    0.048973
# dtype: float64
# Order: (0, 1, 1)
# ---------------------------------------------------------------------------
# RMSE: 9.92416207259835
# Mape: 0.35827635698993954
# R2: -8.616399111548606
# Noise: 0.016624790312915277
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean    14.985440
# std      1.269376
# min     12.799280
# 25%     13.892360
# 50%     14.985440
# 75%     16.078520
# max     17.171600
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean      23.898785
# std        3.206356
# min       15.104191
# 25%       22.163885
# 50%       23.639924
# 75%       26.580929
# max       29.998601
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM532488
# Modeling for the Stock: BOM532488
# ADF Test for the given series.
# ADF test statistic                      -4.472039
# p-value                                  0.000221
# # lags used                                  27.0
# #observations                              4165.0
# Stock Name              DIVI'S LABORATORIES LTD.
# Stock Code                              BOM532488
# critical value (1%)                     -3.431921
# critical value (5%)                     -2.862234
# critical value (10%)                     -2.56714
# dtype: object
# ----------------------------------------------------------------------------
# const                         0.168388
# ar.L1.D.Normalized Closing   -0.917101
# ma.L1.D.Normalized Closing    0.937231
# ma.L2.D.Normalized Closing    0.075050
# ma.L3.D.Normalized Closing    0.074510
# dtype: float64
# Order: (1, 1, 3)
# ---------------------------------------------------------------------------
# RMSE: 378.59532077231387
# Mape: 0.25118653174054106
# R2: -1.629552880274416
# Noise: 0.17423023834384413
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   828.402267
# std     12.856892
# min    806.194651
# 25%    817.330159
# 50%    828.402068
# 75%    839.473591
# max    850.545115
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count     264.000000
# mean     1135.271147
# std       233.915164
# min       693.449866
# 25%       899.169228
# 50%      1203.255859
# 75%      1342.335766
# max      1489.396850
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM500124
# Modeling for the Stock: BOM500124
# ADF Test for the given series.
# ADF test statistic                          -1.341356
# p-value                                      0.610046
# # lags used                                       1.0
# #observations                                  4989.0
# Stock Name              DR.REDDY'S LABORATORIES LTD.
# Stock Code                                  BOM500124
# critical value (1%)                         -3.431661
# critical value (5%)                          -2.86212
# critical value (10%)                        -2.567078
# dtype: object
# ----------------------------------------------------------------------------
# const                         0.020928
# ar.L1.D.Normalized Closing    0.056532
# dtype: float64
# Order: (1, 1, 0)
# ---------------------------------------------------------------------------
# RMSE: 112.4568153449006
# Mape: 0.3195650147489792
# R2: -5.206831091809985
# Noise: 0.020900748865716877
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   207.291177
# std      1.597924
# min    204.546332
# 25%    205.915108
# 50%    207.291148
# 75%    208.667188
# max    210.043229
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     310.821608
# std       45.224618
# min      185.353357
# 25%      281.448763
# 50%      316.192580
# 75%      348.206714
# max      382.798587
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM500180
# Modeling for the Stock: BOM500180
# ADF Test for the given series.
# ADF test statistic           -2.206299
# p-value                       0.203967
# # lags used                        0.0
# #observations                   4990.0
# Stock Name              HDFC Bank Ltd
# Stock Code                   BOM500180
# critical value (1%)          -3.431661
# critical value (5%)          -2.862119
# critical value (10%)         -2.567078
# dtype: object
# ----------------------------------------------------------------------------
# const    0.074344
# dtype: float64
# Order: (0, 1, 0)
# ---------------------------------------------------------------------------
# RMSE: 86.00537207878017
# Mape: 0.16718928429182817
# R2: 0.10742013115315141
# Noise: 0.07434360875811308
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   480.826624
# std      5.676464
# min    471.050439
# 25%    475.938532
# 50%    480.826624
# 75%    485.714716
# max    490.602808
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     474.629890
# std       91.206570
# min      304.960159
# 25%      409.895418
# 50%      445.517928
# 75%      561.065737
# max      648.047809
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM532174
# Modeling for the Stock: BOM532174
# ADF Test for the given series.
# ADF test statistic              -2.58983
# p-value                         0.095118
# # lags used                          1.0
# #observations                     4988.0
# Stock Name              ICICI BANK LTD.
# Stock Code                     BOM532174
# critical value (1%)            -3.431662
# critical value (5%)             -2.86212
# critical value (10%)           -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const                         0.039681
# ar.L1.D.Normalized Closing    0.838987
# ar.L2.D.Normalized Closing   -0.043838
# ma.L1.D.Normalized Closing   -0.809899
# dtype: float64
# Order: (2, 1, 1)
# ---------------------------------------------------------------------------
# RMSE: 75.90136505604141
# Mape: 0.3038956804728921
# R2: -0.6323350236794234
# Noise: 0.04380625149751087
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   303.536835
# std      3.062883
# min    297.252497
# 25%    300.946545
# 50%    303.555544
# 75%    306.164543
# max    308.773542
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     253.284865
# std       59.520837
# min      166.559108
# 25%      206.424171
# 50%      225.623350
# 75%      300.733353
# max      395.423878
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM500247
# Modeling for the Stock: BOM500247
# ADF Test for the given series.
# ADF test statistic                      -0.837502
# p-value                                  0.807857
# # lags used                                   5.0
# #observations                              4984.0
# Stock Name              KOTAK MAHINDRA BANK LTD.
# Stock Code                              BOM500247
# critical value (1%)                     -3.431663
# critical value (5%)                      -2.86212
# critical value (10%)                    -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const                         0.168616
# ar.L1.D.Normalized Closing   -0.277993
# ma.L1.D.Normalized Closing    0.301800
# ma.L2.D.Normalized Closing   -0.014911
# dtype: float64
# Order: (1, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 170.65112787877953
# Mape: 0.19157833047536177
# R2: -0.025825255823427318
# Noise: 0.16858597314443183
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   963.447649
# std     12.874576
# min    941.282583
# 25%    952.361091
# 50%    963.447625
# 75%    974.534160
# max    985.620694
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count     264.000000
# mean      898.687886
# std       168.809374
# min       647.074390
# 25%       769.112026
# 50%       811.820053
# 75%      1085.952661
# max      1188.856219
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM500470
# Modeling for the Stock: BOM500470
# ADF Test for the given series.
# ADF test statistic             -2.627445
# p-value                         0.087457
# # lags used                          9.0
# #observations                     4981.0
# Stock Name              TATA STEEL LTD.
# Stock Code                     BOM500470
# critical value (1%)            -3.431664
# critical value (5%)             -2.86212
# critical value (10%)           -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const                         0.031725
# ar.L1.D.Normalized Closing    1.303203
# ar.L2.D.Normalized Closing   -0.837640
# ma.L1.D.Normalized Closing   -1.264866
# ma.L2.D.Normalized Closing    0.796477
# dtype: float64
# Order: (2, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 123.49677554073227
# Mape: 0.24724903432766834
# R2: -0.22433211222524285
# Noise: 0.04971427775019868
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   262.128475
# std      2.433246
# min    256.900718
# 25%    260.044218
# 50%    262.132759
# 75%    264.218696
# max    266.304632
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     319.488569
# std      111.822729
# min      179.399293
# 25%      228.895760
# 50%      285.053004
# 75%      439.487633
# max      548.904594
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM500228
# Modeling for the Stock: BOM500228
# ADF Test for the given series.
# ADF test statistic            -2.235173
# p-value                        0.193728
# # lags used                         8.0
# #observations                    4960.0
# Stock Name              JSW STEEL LTD.
# Stock Code                    BOM500228
# critical value (1%)           -3.431669
# critical value (5%)           -2.862123
# critical value (10%)           -2.56708
# dtype: object
# ----------------------------------------------------------------------------
# const    0.839738
# dtype: float64
# Order: (0, 1, 0)
# ---------------------------------------------------------------------------
# RMSE: 1738.0314499694794
# Mape: 0.28633981010787657
# R2: -0.13032561073676696
# Noise: 0.8397379593034202
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#          Predicted
# count   264.000000
# mean   4383.083461
# std      64.117719
# min    4272.657920
# 25%    4327.870691
# 50%    4383.083461
# 75%    4438.296232
# max    4493.509003
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count     264.000000
# mean     5122.097107
# std      1637.871915
# min      2545.454545
# 25%      3515.909091
# 50%      5184.090909
# 75%      6658.181818
# max      8102.727273
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM500440
# Modeling for the Stock: BOM500440
# ADF Test for the given series.
# ADF test statistic                      -2.203395
# p-value                                  0.205015
# # lags used                                   0.0
# #observations                              4989.0
# Stock Name              HINDALCO INDUSTRIES LTD.
# Stock Code                              BOM500440
# critical value (1%)                     -3.431661
# critical value (5%)                      -2.86212
# critical value (10%)                    -2.567078
# dtype: object
# ----------------------------------------------------------------------------
# const   -0.016447
# dtype: float64
# Order: (0, 1, 0)
# ---------------------------------------------------------------------------
# RMSE: 11.580989887742806
# Mape: 0.3362155876941496
# R2: -1.180995126789715
# Noise: 0.016446953411822562
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean    15.766886
# std      1.255798
# min     13.604112
# 25%     14.685499
# 50%     15.766886
# 75%     16.848274
# max     17.929661
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean      23.029192
# std        7.856741
# min       10.532934
# 25%       17.591317
# 50%       21.164671
# 75%       28.565868
# max       43.035928
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM532977
# Modeling for the Stock: BOM532977
# ADF Test for the given series.
# ADF test statistic             -2.338397
# p-value                         0.159883
# # lags used                          2.0
# #observations                     2884.0
# Stock Name              BAJAJ AUTO LTD.
# Stock Code                     BOM532977
# critical value (1%)            -3.432619
# critical value (5%)            -2.862543
# critical value (10%)           -2.567304
# dtype: object
# ----------------------------------------------------------------------------
# const                         0.182451
# ar.L1.D.Normalized Closing    0.854175
# ma.L1.D.Normalized Closing   -0.822648
# ma.L2.D.Normalized Closing   -0.053418
# dtype: float64
# Order: (1, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 104.61042466004655
# Mape: 0.10786120906931379
# R2: 0.1663472879720933
# Noise: 0.21780307909651295
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   651.231611
# std     14.364660
# min    618.183254
# 25%    639.476653
# 50%    651.473119
# 75%    663.469291
# max    675.465464
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     675.040438
# std      114.790638
# min      426.926474
# 25%      614.385074
# 50%      661.039965
# 75%      731.781298
# max      935.769486
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM500570
# Modeling for the Stock: BOM500570
# ADF Test for the given series.
# ADF test statistic               -2.21147
# p-value                          0.202109
# # lags used                          22.0
# #observations                      4967.0
# Stock Name              TATA MOTORS LTD.
# Stock Code                      BOM500570
# critical value (1%)             -3.431667
# critical value (5%)             -2.862122
# critical value (10%)             -2.56708
# dtype: object
# ----------------------------------------------------------------------------
# const                        -0.005790
# ar.L1.D.Normalized Closing    1.286093
# ar.L2.D.Normalized Closing   -0.591802
# ma.L1.D.Normalized Closing   -1.247612
# ma.L2.D.Normalized Closing    0.538352
# dtype: float64
# Order: (2, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 47.69215560763755
# Mape: 0.3382848899326516
# R2: -0.17205436344749048
# Noise: 0.010807299832694444
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean    69.727919
# std      0.440870
# min     68.970107
# 25%     69.350816
# 50%     69.725734
# 75%     70.100653
# max     70.688234
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean      87.025147
# std       44.136426
# min       36.277778
# 25%       56.812500
# 50%       73.805556
# 75%      101.076389
# max      193.611111
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM532500
# Modeling for the Stock: BOM532500
# ADF Test for the given series.
# ADF test statistic                      -0.588969
# p-value                                  0.873455
# # lags used                                  29.0
# #observations                              4082.0
# Stock Name              MARUTI SUZUKI INDIA LTD.
# Stock Code                              BOM532500
# critical value (1%)                     -3.431953
# critical value (5%)                     -2.862248
# critical value (10%)                    -2.567147
# dtype: object
# ----------------------------------------------------------------------------
# const                         0.679097
# ar.L1.D.Normalized Closing   -0.897258
# ar.L2.D.Normalized Closing   -0.799629
# ma.L1.D.Normalized Closing    0.947836
# ma.L2.D.Normalized Closing    0.821221
# dtype: float64
# Order: (2, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 406.0167903063617
# Mape: 0.12355597168634051
# R2: 0.18414988603428706
# Noise: 0.7313235349090839
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#          Predicted
# count   264.000000
# mean   2981.643473
# std      51.856229
# min    2890.336978
# 25%    2936.995329
# 50%    2981.645393
# 75%    3026.296040
# max    3070.946687
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count     264.000000
# mean     3007.590061
# std       450.363197
# min      1847.409625
# 25%      2652.256505
# 50%      3158.841814
# 75%      3311.299793
# max      3792.793000
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM500209
# Modeling for the Stock: BOM500209
# ADF Test for the given series.
# ADF test statistic          -4.729905
# p-value                      0.000074
# # lags used                      32.0
# #observations                  4958.0
# Stock Name              INFOSYS LTD.
# Stock Code                  BOM500209
# critical value (1%)          -3.43167
# critical value (5%)         -2.862123
# critical value (10%)         -2.56708
# dtype: object
# ----------------------------------------------------------------------------
# const                        -0.019919
# ar.L1.D.Normalized Closing    1.712742
# ar.L2.D.Normalized Closing   -0.983242
# ma.L1.D.Normalized Closing   -1.668026
# ma.L2.D.Normalized Closing    0.925385
# dtype: float64
# Order: (2, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 6.644465979511862
# Mape: 0.4426878762763063
# R2: -5.07619128771304
# Noise: 0.01994322230356117
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     5.479368
# std      1.521428
# min      2.859676
# 25%      4.171475
# 50%      5.473020
# 75%      6.804380
# max      8.076022
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean      10.634957
# std        2.700651
# min        5.709485
# 25%        7.741057
# 50%       10.539566
# 75%       12.676558
# max       15.042818
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM532540
# Modeling for the Stock: BOM532540
# ADF Test for the given series.
# ADF test statistic                            -1.981595
# p-value                                        0.294701
# # lags used                                         0.0
# #observations                                    3823.0
# Stock Name              TATA CONSULTANCY SERVICES LTD.
# Stock Code                                    BOM532540
# critical value (1%)                           -3.432062
# critical value (5%)                           -2.862296
# critical value (10%)                          -2.567173
# dtype: object
# ----------------------------------------------------------------------------
# const                         0.023769
# ar.L1.D.Normalized Closing    0.241140
# ar.L2.D.Normalized Closing    0.701404
# ma.L1.D.Normalized Closing   -0.233011
# ma.L2.D.Normalized Closing   -0.734869
# dtype: float64
# Order: (2, 1, 2)
# ---------------------------------------------------------------------------
# RMSE: 54.33823714518555
# Mape: 0.16728168682614256
# R2: -0.48343321434439646
# Noise: 0.04863846448573832
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean   200.159569
# std      2.993326
# min    191.246316
# 25%    198.635222
# 50%    200.836267
# 75%    202.467967
# max    204.038232
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean     234.669904
# std       44.698776
# min      156.079180
# 25%      195.332697
# 50%      225.263534
# 75%      269.691152
# max      315.592654
# Name: Normalized Closing, dtype: float64
# Working for Stock BOM507685
# Modeling for the Stock: BOM507685
# ADF Test for the given series.
# ADF test statistic        -9.271014
# p-value                         0.0
# # lags used                    32.0
# #observations                4958.0
# Stock Name              WIPRO LTD.
# Stock Code                BOM507685
# critical value (1%)        -3.43167
# critical value (5%)       -2.862123
# critical value (10%)       -2.56708
# dtype: object
# ----------------------------------------------------------------------------
# const                        -0.021660
# ar.L1.D.Normalized Closing    1.768609
# ar.L2.D.Normalized Closing   -0.989769
# ma.L1.D.Normalized Closing   -1.640547
# ma.L2.D.Normalized Closing    0.824323
# ma.L3.D.Normalized Closing   -0.058249
# ma.L4.D.Normalized Closing    0.098128
# dtype: float64
# Order: (2, 1, 4)
# ---------------------------------------------------------------------------
# RMSE: 5.33742170528177
# Mape: 0.6936177254319335
# R2: -10.510281430018408
# Noise: 0.022664083600313908
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     1.116625
# std      1.655168
# min     -1.748450
# 25%     -0.328304
# 50%      1.091351
# 75%      2.516829
# max      3.964578
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       5.386714
# std        1.576205
# min        2.883751
# 25%        3.886698
# 50%        5.321005
# 75%        6.476865
# max        8.168698
# Name: Normalized Closing, dtype: float64

# %%
ArimaModelPricesResults_Norm.to_csv('./Outputs/ArimaModelPricesResults_Norm.csv')

# %% [markdown]
# ## ARIMA Model For Returns

# %% [markdown]
# ### Convert Closing price to percentage change

# %% [markdown]
# > revisit normalization for this section - consider normalizing in range -1 and 1 --- Not done yet

# %%
for s in stocks:
    ScriptWiseData[s]['Stock_Returns'] = ScriptWiseData[s]['Close'].pct_change(1).mul(100) 
    ScriptWiseData[s] = ScriptWiseData[s][1:] # Because of NAN first value

# %%
stock = stocks[0]
adf_testResult = pd.DataFrame(adf_test(ScriptWiseData[stocks[0]].Stock_Returns, stocks[0])[0], columns = ['Value']).transpose().set_index(['Stock Name', 'Stock Code'])
for i in range(1, len(stocks)):
    res = pd.DataFrame(adf_test(ScriptWiseData[stocks[i]].Stock_Returns, stocks[i])[0], columns = ['Value']).transpose().set_index(['Stock Name', 'Stock Code'])
    adf_testResult = adf_testResult.append(res)
adf_testResult['Result'] = adf_testResult['p-value'].apply(lambda x: 'Stationary' if x<0.05 else 'Non-Stationary')
# adf_testResult.to_csv('Outputs/adfTestReturns.csv')
adf_testResult.to_csv('Outputs/adfTestReturns.csv')
adf_testResult.head()
# Out:
#                                                ADF test statistic p-value  \
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715          -51.489152     0.0
# DIVI'S LABORATORIES LTD.            BOM532488          -13.923122     0.0
# DR.REDDY'S LABORATORIES LTD.        BOM500124          -71.618449     0.0
# HDFC Bank Ltd                       BOM500180          -54.580752     0.0
# ICICI BANK LTD.                     BOM532174          -32.126798     0.0
#
#                                                # lags used #observations  \
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715          1.0        5251.0
# DIVI'S LABORATORIES LTD.            BOM532488         23.0        4432.0
# DR.REDDY'S LABORATORIES LTD.        BOM500124          0.0        5253.0
# HDFC Bank Ltd                       BOM500180          1.0        5252.0
# ICICI BANK LTD.                     BOM532174          5.0        5247.0
#
#                                                critical value (1%)  \
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715            -3.431596
# DIVI'S LABORATORIES LTD.            BOM532488            -3.431826
# DR.REDDY'S LABORATORIES LTD.        BOM500124            -3.431595
# HDFC Bank Ltd                       BOM500180            -3.431596
# ICICI BANK LTD.                     BOM532174            -3.431597
#
#                                                critical value (5%)  \
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715            -2.862091
# DIVI'S LABORATORIES LTD.            BOM532488            -2.862192
# DR.REDDY'S LABORATORIES LTD.        BOM500124             -2.86209
# HDFC Bank Ltd                       BOM500180             -2.86209
# ICICI BANK LTD.                     BOM532174            -2.862091
#
#                                                critical value (10%)  \
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715             -2.567063
# DIVI'S LABORATORIES LTD.            BOM532488             -2.567117
# DR.REDDY'S LABORATORIES LTD.        BOM500124             -2.567063
# HDFC Bank Ltd                       BOM500180             -2.567063
# ICICI BANK LTD.                     BOM532174             -2.567063
#
#                                                     Result
# Stock Name                          Stock Code
# SUN PHARMACEUTICAL INDUSTRIES LTD.  BOM524715   Stationary
# DIVI'S LABORATORIES LTD.            BOM532488   Stationary
# DR.REDDY'S LABORATORIES LTD.        BOM500124   Stationary
# HDFC Bank Ltd                       BOM500180   Stationary
# ICICI BANK LTD.                     BOM532174   Stationary

# %% [markdown]
# ### ARIMA for percentage Returns

# %%
try:
    ArimaModelPricesResults_Returns = pd.read_csv('./Outputs/ArimaModelPricesResults_Returns.csv')
except FileNotFoundError:
    ArimaModelPricesResults_Returns = pd.DataFrame(columns=['Stationarity', 'Order', 'RMSE', 'MAPE', 'R2', 'Noise', 'Predictions Mean', 'Actual Mean'], index = stocks)

# %%
for stock in stocks:
    try:
        print("Working for Stock {}".format(stock))
        train_data, test_data = TrainTestSplitByDateRange(ScriptWiseData[stock])
        feature = 'Stock_Returns'
        Order = CalculateAutoArima(stock, train_data, feature, p = 'p Closing Percentage', d = 'd Closing Percentage', q = 'q Closing Percentage')
        ARIMA_Model_Generic(StockCode= stock, data = ScriptWiseData, feature = feature, Results=ArimaModelPricesResults_Returns, Order=Order, train_data=train_data, test_data=test_data)
    except Exception as e:
        print(e)
# Out:
# Working for Stock BOM524715
# Modeling for the Stock: BOM524715
# ADF Test for the given series.
# ADF test statistic                                -50.24951
# p-value                                                 0.0
# # lags used                                             1.0
# #observations                                        4987.0
# Stock Name              SUN PHARMACEUTICAL INDUSTRIES LTD.
# Stock Code                                        BOM524715
# critical value (1%)                               -3.431662
# critical value (5%)                                -2.86212
# critical value (10%)                              -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const                  0.026617
# ar.L1.Stock_Returns    0.854584
# ma.L1.Stock_Returns   -0.823289
# ma.L2.Stock_Returns   -0.043835
# dtype: float64
# Order: (1, 0, 2)
# ---------------------------------------------------------------------------
# RMSE: 2.4181118881512624
# Mape: 1.016610705011499
# R2: -0.005037803417318187
# Noise: 0.0006273865658588914
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.030467
# std      0.016544
# min      0.026617
# 25%      0.026617
# 50%      0.026617
# 75%      0.026622
# max      0.159690
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.205739
# std        2.416625
# min      -11.427009
# 25%       -1.296316
# 50%        0.125770
# 75%        1.433048
# max       10.960362
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM532488
# Modeling for the Stock: BOM532488
# ADF Test for the given series.
# ADF test statistic                     -13.421794
# p-value                                       0.0
# # lags used                                  23.0
# #observations                              4168.0
# Stock Name              DIVI'S LABORATORIES LTD.
# Stock Code                              BOM532488
# critical value (1%)                      -3.43192
# critical value (5%)                     -2.862234
# critical value (10%)                    -2.567139
# dtype: object
# ----------------------------------------------------------------------------
# const                  0.106514
# ar.L1.Stock_Returns    0.542698
# ar.L2.Stock_Returns   -0.001319
# ar.L3.Stock_Returns   -0.014375
# ma.L1.Stock_Returns   -0.487761
# dtype: float64
# Order: (3, 0, 1)
# ---------------------------------------------------------------------------
# RMSE: 2.371791879266092
# Mape: 1.4388219409362384
# R2: -0.002709878238662755
# Noise: 0.0003077647574456291
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.106209
# std      0.004836
# min      0.028138
# 25%      0.106514
# 50%      0.106514
# 75%      0.106514
# max      0.107797
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.220249
# std        2.373084
# min      -10.910909
# 25%       -1.040320
# 50%        0.121169
# 75%        1.471860
# max       11.954745
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM500124
# Modeling for the Stock: BOM500124
# ADF Test for the given series.
# ADF test statistic                         -69.725568
# p-value                                           0.0
# # lags used                                       0.0
# #observations                                  4989.0
# Stock Name              DR.REDDY'S LABORATORIES LTD.
# Stock Code                                  BOM500124
# critical value (1%)                         -3.431661
# critical value (5%)                          -2.86212
# critical value (10%)                        -2.567078
# dtype: object
# ----------------------------------------------------------------------------
# const    0.043645
# dtype: float64
# Order: (0, 0, 0)
# ---------------------------------------------------------------------------
# RMSE: 2.2544614582901135
# Mape: 1.0323544377004528
# R2: -0.003719389307451193
# Noise: 0.0
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#           Predicted
# count  2.640000e+02
# mean   4.364492e-02
# std    8.342488e-17
# min    4.364492e-02
# 25%    4.364492e-02
# 50%    4.364492e-02
# 75%    4.364492e-02
# max    4.364492e-02
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.180882
# std        2.254555
# min       -5.694833
# 25%       -1.058319
# 50%       -0.028303
# 75%        1.162032
# max       13.938883
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM500180
# Modeling for the Stock: BOM500180
# ADF Test for the given series.
# ADF test statistic          -53.248049
# p-value                            0.0
# # lags used                        1.0
# #observations                   4988.0
# Stock Name              HDFC Bank Ltd
# Stock Code                   BOM500180
# critical value (1%)          -3.431662
# critical value (5%)           -2.86212
# critical value (10%)         -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const                  0.070904
# ar.L1.Stock_Returns    0.704652
# ma.L1.Stock_Returns   -0.751081
# dtype: float64
# Order: (1, 0, 1)
# ---------------------------------------------------------------------------
# RMSE: 2.651915179592463
# Mape: 1.0231225845121072
# R2: -0.0008562192426535553
# Noise: 0.00032132915634095524
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.071988
# std      0.007263
# min      0.070904
# 25%      0.070904
# 50%      0.070904
# 75%      0.070904
# max      0.155414
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.125669
# std        2.655815
# min      -12.681324
# 25%       -1.285922
# 50%        0.186571
# 75%        1.512238
# max       11.770854
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM532174
# Modeling for the Stock: BOM532174
# ADF Test for the given series.
# ADF test statistic            -31.308266
# p-value                              0.0
# # lags used                          5.0
# #observations                     4983.0
# Stock Name              ICICI BANK LTD.
# Stock Code                     BOM532174
# critical value (1%)            -3.431663
# critical value (5%)             -2.86212
# critical value (10%)           -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# The computed initial AR coefficients are not stationary
# You should induce stationarity, choose a different model order, or you can
# pass your own start_params.
# Working for Stock BOM500247
# Modeling for the Stock: BOM500247
# ADF Test for the given series.
# ADF test statistic                     -30.817303
# p-value                                       0.0
# # lags used                                   5.0
# #observations                              4983.0
# Stock Name              KOTAK MAHINDRA BANK LTD.
# Stock Code                              BOM500247
# critical value (1%)                     -3.431663
# critical value (5%)                      -2.86212
# critical value (10%)                    -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const                  0.104076
# ma.L1.Stock_Returns    0.040904
# dtype: float64
# Order: (0, 0, 1)
# ---------------------------------------------------------------------------
# RMSE: 2.9141169546677324
# Mape: 1.0627084569026468
# R2: -8.850868569409975e-05
# Noise: 0.00018663592974449712
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.103890
# std      0.003021
# min      0.054991
# 25%      0.104076
# 50%      0.104076
# 75%      0.104076
# max      0.104076
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.090105
# std        2.919523
# min      -12.902204
# 25%       -1.369696
# 50%        0.046612
# 75%        1.576423
# max       12.313920
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM500470
# Modeling for the Stock: BOM500470
# ADF Test for the given series.
# ADF test statistic            -21.472392
# p-value                              0.0
# # lags used                          8.0
# #observations                     4981.0
# Stock Name              TATA STEEL LTD.
# Stock Code                     BOM500470
# critical value (1%)            -3.431664
# critical value (5%)             -2.86212
# critical value (10%)           -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const                  0.057312
# ar.L1.Stock_Returns   -0.731096
# ar.L2.Stock_Returns    0.163577
# ma.L1.Stock_Returns    0.774936
# ma.L2.Stock_Returns   -0.131175
# dtype: float64
# Order: (2, 0, 2)
# ---------------------------------------------------------------------------
# RMSE: 3.110184741793508
# Mape: 1.0106859038342766
# R2: -0.007886769663874027
# Noise: 0.003501333333946175
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.056432
# std      0.012308
# min     -0.109852
# 25%      0.057312
# 50%      0.057312
# 75%      0.057312
# max      0.085425
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.317305
# std        3.103876
# min      -11.015517
# 25%       -1.240802
# 50%        0.260434
# 75%        1.818313
# max       13.476290
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM500228
# Modeling for the Stock: BOM500228
# ADF Test for the given series.
# ADF test statistic           -70.781601
# p-value                             0.0
# # lags used                         0.0
# #observations                    4967.0
# Stock Name              JSW STEEL LTD.
# Stock Code                    BOM500228
# critical value (1%)           -3.431667
# critical value (5%)           -2.862122
# critical value (10%)           -2.56708
# dtype: object
# ----------------------------------------------------------------------------
# const    0.523875
# dtype: float64
# Order: (0, 0, 0)
# ---------------------------------------------------------------------------
# RMSE: 3.11692590400075
# Mape: 1.6278397989659887
# R2: -0.00572148563224073
# Noise: 0.0
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.523875
# std      0.000000
# min      0.523875
# 25%      0.523875
# 50%      0.523875
# 75%      0.523875
# max      0.523875
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.288780
# std        3.113950
# min      -18.192122
# 25%       -0.982224
# 50%        0.431881
# 75%        1.962845
# max       13.035714
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM500440
# Modeling for the Stock: BOM500440
# ADF Test for the given series.
# ADF test statistic                     -68.777542
# p-value                                       0.0
# # lags used                                   0.0
# #observations                              4988.0
# Stock Name              HINDALCO INDUSTRIES LTD.
# Stock Code                              BOM500440
# critical value (1%)                     -3.431662
# critical value (5%)                      -2.86212
# critical value (10%)                    -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const                  0.027606
# ar.L1.Stock_Returns   -0.640629
# ar.L2.Stock_Returns   -0.431907
# ma.L1.Stock_Returns    0.666571
# ma.L2.Stock_Returns    0.461391
# dtype: float64
# Order: (2, 0, 2)
# ---------------------------------------------------------------------------
# RMSE: 3.6821490389496154
# Mape: 0.9859136471715348
# R2: -0.009147148455109333
# Noise: 0.0018166317867787712
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.027244
# std      0.011430
# min     -0.134515
# 25%      0.027606
# 50%      0.027606
# 75%      0.027606
# max      0.095729
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.368711
# std        3.672385
# min      -16.595543
# 25%       -1.506538
# 50%        0.398409
# 75%        2.019727
# max       17.716535
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM532977
# Modeling for the Stock: BOM532977
# ADF Test for the given series.
# ADF test statistic            -50.374218
# p-value                              0.0
# # lags used                          0.0
# #observations                     2885.0
# Stock Name              BAJAJ AUTO LTD.
# Stock Code                     BOM532977
# critical value (1%)            -3.432619
# critical value (5%)            -2.862542
# critical value (10%)           -2.567304
# dtype: object
# ----------------------------------------------------------------------------
# const                  0.086957
# ma.L1.Stock_Returns    0.069712
# dtype: float64
# Order: (0, 0, 1)
# ---------------------------------------------------------------------------
# RMSE: 2.434276173512719
# Mape: 1.173897888235235
# R2: 0.0006579710679214257
# Noise: 0.0008429967914166577
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.086117
# std      0.013645
# min     -0.134751
# 25%      0.086957
# 50%      0.086957
# 75%      0.086957
# max      0.086957
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.133604
# std        2.439702
# min      -13.951991
# 25%       -0.879466
# 50%        0.081191
# 75%        1.047050
# max       12.052430
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM500570
# Modeling for the Stock: BOM500570
# ADF Test for the given series.
# ADF test statistic             -14.921985
# p-value                               0.0
# # lags used                          19.0
# #observations                      4969.0
# Stock Name              TATA MOTORS LTD.
# Stock Code                      BOM500570
# critical value (1%)             -3.431667
# critical value (5%)             -2.862122
# critical value (10%)             -2.56708
# dtype: object
# ----------------------------------------------------------------------------
# const                  0.048284
# ar.L1.Stock_Returns    0.451511
# ar.L2.Stock_Returns    0.325761
# ar.L3.Stock_Returns   -0.900363
# ma.L1.Stock_Returns   -0.381035
# ma.L2.Stock_Returns   -0.368178
# ma.L3.Stock_Returns    0.877029
# ma.L4.Stock_Returns    0.039057
# dtype: float64
# Order: (3, 0, 4)
# ---------------------------------------------------------------------------
# RMSE: 3.852464291327024
# Mape: 0.9806298681645665
# R2: -0.009107829964628111
# Noise: 0.005410465722102507
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.047974
# std      0.008732
# min     -0.002506
# 25%      0.047613
# 50%      0.048244
# 75%      0.048789
# max      0.086524
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.413048
# std        3.842323
# min      -11.111111
# 25%       -1.743510
# 50%        0.371558
# 75%        2.086773
# max       19.129878
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM532500
# Modeling for the Stock: BOM532500
# ADF Test for the given series.
# ADF test statistic                     -61.824492
# p-value                                       0.0
# # lags used                                   0.0
# #observations                              4110.0
# Stock Name              MARUTI SUZUKI INDIA LTD.
# Stock Code                              BOM532500
# critical value (1%)                     -3.431942
# critical value (5%)                     -2.862243
# critical value (10%)                    -2.567144
# dtype: object
# ----------------------------------------------------------------------------
# const                  0.104192
# ar.L1.Stock_Returns    0.655636
# ar.L2.Stock_Returns   -0.058882
# ma.L1.Stock_Returns   -0.619304
# ma.L2.Stock_Returns    0.013855
# dtype: float64
# Order: (2, 0, 2)
# ---------------------------------------------------------------------------
# RMSE: 2.9478275894423964
# Mape: 1.1498394859175196
# R2: 4.873845317998615e-06
# Noise: 0.00013381037743571213
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.104553
# std      0.002914
# min      0.104192
# 25%      0.104192
# 50%      0.104192
# 75%      0.104192
# max      0.139384
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.094427
# std        2.953434
# min      -17.022513
# 25%       -1.032617
# 50%        0.072834
# 75%        1.240719
# max       13.409694
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM500209
# Modeling for the Stock: BOM500209
# ADF Test for the given series.
# ADF test statistic         -42.017994
# p-value                           0.0
# # lags used                       2.0
# #observations                  4987.0
# Stock Name              INFOSYS LTD.
# Stock Code                  BOM500209
# critical value (1%)         -3.431662
# critical value (5%)          -2.86212
# critical value (10%)        -2.567079
# dtype: object
# ----------------------------------------------------------------------------
# const                  0.006359
# ar.L1.Stock_Returns   -0.506842
# ar.L2.Stock_Returns   -0.840412
# ma.L1.Stock_Returns    0.526018
# ma.L2.Stock_Returns    0.839451
# dtype: float64
# Order: (2, 0, 2)
# ---------------------------------------------------------------------------
# RMSE: 2.505932975127475
# Mape: 0.9944169208686222
# R2: -0.010578621651476938
# Noise: 0.002317779984583498
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.006483
# std      0.005850
# min     -0.036431
# 25%      0.006359
# 50%      0.006359
# 75%      0.006359
# max      0.055656
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.262543
# std        2.497517
# min       -9.958116
# 25%       -0.926910
# 50%        0.224821
# 75%        1.242676
# max       12.692235
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM532540
# Modeling for the Stock: BOM532540
# ADF Test for the given series.
# ADF test statistic                           -33.104675
# p-value                                             0.0
# # lags used                                         3.0
# #observations                                    3819.0
# Stock Name              TATA CONSULTANCY SERVICES LTD.
# Stock Code                                    BOM532540
# critical value (1%)                           -3.432063
# critical value (5%)                           -2.862297
# critical value (10%)                          -2.567173
# dtype: object
# ----------------------------------------------------------------------------
# const                  0.050523
# ar.L1.Stock_Returns    0.916363
# ma.L1.Stock_Returns   -0.904796
# ma.L2.Stock_Returns   -0.038662
# dtype: float64
# Order: (1, 0, 2)
# ---------------------------------------------------------------------------
# RMSE: 2.2025979839003607
# Mape: 1.1167582398102223
# R2: -0.00691414625850495
# Noise: 0.0008554032704770944
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean     0.060955
# std      0.033833
# min      0.050523
# 25%      0.050523
# 50%      0.050526
# 75%      0.051264
# max      0.275494
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.195378
# std        2.199192
# min       -9.449745
# 25%       -0.808801
# 50%        0.126692
# 75%        1.215705
# max        9.895483
# Name: Stock_Returns, dtype: float64
# Working for Stock BOM507685
# Modeling for the Stock: BOM507685
# ADF Test for the given series.
# ADF test statistic       -13.611959
# p-value                         0.0
# # lags used                    30.0
# #observations                4959.0
# Stock Name              WIPRO LTD.
# Stock Code                BOM507685
# critical value (1%)       -3.431669
# critical value (5%)       -2.862123
# critical value (10%)       -2.56708
# dtype: object
# ----------------------------------------------------------------------------
# const                 -0.007107
# ar.L1.Stock_Returns    1.935869
# ar.L2.Stock_Returns   -0.964866
# ma.L1.Stock_Returns   -1.941821
# ma.L2.Stock_Returns    0.972111
# dtype: float64
# Order: (2, 0, 2)
# ---------------------------------------------------------------------------
# RMSE: 2.5438797852682327
# Mape: 434979547252.12787
# R2: -0.013258585489479557
# Noise: 0.0037220982981480003
# ---------------------------------------------------------------------------
# Description of the Predicted Data
#         Predicted
# count  264.000000
# mean    -0.009081
# std      0.034421
# min     -0.130238
# 25%     -0.015483
# 50%     -0.006986
# 75%     -0.000732
# max      0.101468
# ---------------------------------------------------------------------------
# Description of the Actual Data
# count    264.000000
# mean       0.271226
# std        2.531981
# min       -8.966565
# 25%       -0.912030
# 50%        0.133240
# 75%        1.196756
# max       16.840702
# Name: Stock_Returns, dtype: float64

# %%
ArimaModelPricesResults_Returns
# Out:
#            Unnamed: 0 Unnamed: 0.1 Stationarity      Order      RMSE  \
# 0                 0.0    BOM524715   Stationary  (1, 0, 2)  2.418112
# 1                 1.0    BOM532488   Stationary  (3, 0, 1)  2.371792
# 2                 2.0    BOM500124   Stationary  (0, 0, 0)  2.254461
# 3                 3.0    BOM500180   Stationary  (1, 0, 1)  2.651915
# 4                 4.0    BOM532174   Stationary        NaN       NaN
# 5                 5.0    BOM500247   Stationary  (0, 0, 1)  2.914117
# 6                 6.0    BOM500470   Stationary  (2, 0, 2)  3.110185
# 7                 7.0    BOM500228   Stationary  (0, 0, 0)  3.116926
# 8                 8.0    BOM500440   Stationary  (2, 0, 2)  3.682149
# 9                 9.0    BOM532977   Stationary  (0, 0, 1)  2.434276
# 10               10.0    BOM500570   Stationary  (3, 0, 4)  3.852464
# 11               11.0    BOM532500   Stationary  (2, 0, 2)  2.947828
# 12               12.0    BOM500209   Stationary  (2, 0, 2)  2.505933
# 13               13.0    BOM532540   Stationary  (1, 0, 2)  2.202598
# 14               14.0    BOM507685   Stationary  (2, 0, 2)  2.543880
# BOM524715         NaN          NaN   Stationary  (1, 0, 2)  2.418112
# BOM532488         NaN          NaN   Stationary  (3, 0, 1)  2.371792
# BOM500124         NaN          NaN   Stationary  (0, 0, 0)  2.254461
# BOM500180         NaN          NaN   Stationary  (1, 0, 1)  2.651915
# BOM532174         NaN          NaN   Stationary        NaN       NaN
# BOM500247         NaN          NaN   Stationary  (0, 0, 1)  2.914117
# BOM500470         NaN          NaN   Stationary  (2, 0, 2)  3.110185
# BOM500228         NaN          NaN   Stationary  (0, 0, 0)  3.116926
# BOM500440         NaN          NaN   Stationary  (2, 0, 2)  3.682149
# BOM532977         NaN          NaN   Stationary  (0, 0, 1)  2.434276
# BOM500570         NaN          NaN   Stationary  (3, 0, 4)  3.852464
# BOM532500         NaN          NaN   Stationary  (2, 0, 2)  2.947828
# BOM500209         NaN          NaN   Stationary  (2, 0, 2)  2.505933
# BOM532540         NaN          NaN   Stationary  (1, 0, 2)  2.202598
# BOM507685         NaN          NaN   Stationary  (2, 0, 2)  2.543880
#
#                    MAPE        R2     Noise       Predictions Mean  \
# 0          1.016611e+00 -0.005038  0.000627               0.030467
# 1          1.438822e+00 -0.002710  0.000308               0.106209
# 2          1.032354e+00 -0.003719  0.000000               0.043645
# 3          1.023123e+00 -0.000856  0.000321               0.071988
# 4                   NaN       NaN       NaN                    NaN
# 5          1.062708e+00 -0.000089  0.000187                0.10389
# 6          1.010686e+00 -0.007887  0.003501               0.056432
# 7          1.627840e+00 -0.005721  0.000000               0.523875
# 8          9.859136e-01 -0.009147  0.001817               0.027244
# 9          1.173898e+00  0.000658  0.000843               0.086117
# 10         9.806299e-01 -0.009108  0.005410               0.047974
# 11         1.149839e+00  0.000005  0.000134               0.104553
# 12         9.944169e-01 -0.010579  0.002318               0.006483
# 13         1.116758e+00 -0.006914  0.000855               0.060955
# 14         4.349795e+11 -0.013259  0.003722              -0.009081
# BOM524715  1.016611e+00 -0.005038  0.000627   0.030466600549421314
# BOM532488  1.438822e+00 -0.002710  0.000308    0.10620860129354863
# BOM500124  1.032354e+00 -0.003719  0.000000    0.04364491996344812
# BOM500180  1.023123e+00 -0.000856  0.000321    0.07198788820942947
# BOM532174           NaN       NaN       NaN                    NaN
# BOM500247  1.062708e+00 -0.000089  0.000187    0.10389020263388045
# BOM500470  1.010686e+00 -0.007887  0.003501   0.056431575740140266
# BOM500228  1.627840e+00 -0.005721  0.000000     0.5238747004730313
# BOM500440  9.859136e-01 -0.009147  0.001817   0.027244112883416386
# BOM532977  1.173898e+00  0.000658  0.000843    0.08611715967783007
# BOM500570  9.806299e-01 -0.009108  0.005410    0.04797370626303102
# BOM532500  1.149839e+00  0.000005  0.000134    0.10455349650463835
# BOM500209  9.944169e-01 -0.010579  0.002318   0.006483249473545437
# BOM532540  1.116758e+00 -0.006914  0.000855    0.06095549567301364
# BOM507685  4.349795e+11 -0.013259  0.003722  -0.009080787981048732
#
#                    Actual Mean  \
# 0                     0.205739
# 1                     0.220249
# 2                     0.180882
# 3                     0.125669
# 4                          NaN
# 5                     0.090105
# 6                     0.317305
# 7                      0.28878
# 8                     0.368711
# 9                     0.133604
# 10                    0.413048
# 11                    0.094427
# 12                    0.262543
# 13                    0.195378
# 14                    0.271226
# BOM524715  0.20573864798210306
# BOM532488  0.22024935679929103
# BOM500124  0.18088231861858162
# BOM500180  0.12566854955618048
# BOM532174                  NaN
# BOM500247   0.0901047802483421
# BOM500470   0.3173045225208098
# BOM500228   0.2887804435159547
# BOM500440  0.36871118873150094
# BOM532977  0.13360405849851478
# BOM500570   0.4130476176710498
# BOM532500  0.09442729096548874
# BOM500209   0.2625434450539418
# BOM532540  0.19537820730039165
# BOM507685   0.2712256591466293
#
#                                                        Model
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
# 5                                                        NaN
# 6                                                        NaN
# 7                                                        NaN
# 8                                                        NaN
# 9                                                        NaN
# 10                                                       NaN
# 11                                                       NaN
# 12                                                       NaN
# 13                                                       NaN
# 14                                                       NaN
# BOM524715  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM532488  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM500124  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM500180  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM532174                                                NaN
# BOM500247  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM500470  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM500228  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM500440  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM532977  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM500570  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM532500  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM500209  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM532540  <statsmodels.tsa.arima_model.ARMA object at 0x...
# BOM507685  <statsmodels.tsa.arima_model.ARMA object at 0x...

# %%
ArimaModelPricesResults_Returns.to_csv('./Outputs/ArimaModelPricesResults_Returns.csv')

# %% [markdown]
# #ARIMAX

# %% [markdown]
# ### AutoARIMA DataFrame

# %%
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima

# %%
try:
    AutoArimaResultsForArimax = pd.read_csv('./Outputs/AutoArimaResultsForArimax.csv')
except FileNotFoundError:
    AutoArimaResultsForArimax = pd.DataFrame(columns=['p Closing Values', 'd Closing Values', 'q Closing Values','p N Closing Values', 'd N Closing Values', 'q N Closing Values','p Closing Percentage', 'd Closing Percentage', 'q Closing Percentage'], index = stocks)

AutoArimaResultsForArimax
# Out:
#    Unnamed: 0  p Closing Values  d Closing Values  q Closing Values  \
# 0   BOM524715               0.0               1.0               1.0
# 1   BOM532488               NaN               NaN               NaN
# 2   BOM500124               NaN               NaN               NaN
# 3   BOM500180               NaN               NaN               NaN
# 4   BOM532174               NaN               NaN               NaN
# 5   BOM500247               NaN               NaN               NaN
# 6   BOM500470               NaN               NaN               NaN
# 7   BOM500228               NaN               NaN               NaN
# 8   BOM500440               NaN               NaN               NaN
# 9   BOM532977               NaN               NaN               NaN
# 10  BOM500570               NaN               NaN               NaN
# 11  BOM532500               NaN               NaN               NaN
# 12  BOM500209               NaN               NaN               NaN
# 13  BOM532540               NaN               NaN               NaN
# 14  BOM507685               NaN               NaN               NaN
#
#     p N Closing Values  d N Closing Values  q N Closing Values  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 NaN                 NaN                 NaN
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
#
#     p Closing Percentage  d Closing Percentage  q Closing Percentage
# 0                      1                     0                     2
# 1                      3                     0                     1
# 2                      0                     0                     0
# 3                      1                     0                     1
# 4                      2                     0                     4
# 5                      0                     0                     1
# 6                      2                     0                     2
# 7                      0                     0                     0
# 8                      2                     0                     2
# 9                      0                     0                     1
# 10                     3                     0                     4
# 11                     2                     0                     2
# 12                     2                     0                     2
# 13                     1                     0                     2
# 14                     2                     0                     2

# %%
def CalculateAutoArimaForArimax(stockcode, data, parameter ,p ,d,q):
    if(AutoArimaResultsForArimax.loc[:, [p, d, q]].isnull().sum(axis=1)[stockcode] > 0):
        params = auto_arima(data[parameter], exog = data[TechnicalIndicators], maxiter = 1000)
        AutoArimaResultsForArimax.loc[stockcode, [p,d,q]] = params.order
        return params.order
    else:
        return tuple(AutoArimaResultsForArimax.loc[stockcode, [p, d, q]])

# %% [markdown]
# ##Generic Function for ARIMAX

# %% [markdown]
# # TAVISH - FIX THIS SHIT - EXOG VARIABLE IS INCORRECT

# %%
def ARIMAX_Model_Generic(StockCode, data, feature, Results, Order, train_data, test_data, extra_indicators):
    print("Modeling for the Stock: {}".format(StockCode))

    start = len(train_data)
    end = len(train_data) + len(test_data) - 1

    print("ADF Test for the given series.")
    adf, Stationarity = adf_test(train_data[feature], title=StockCode)
    print(adf)
    print('----------------------------------------------------------------------------')
    Results.loc[StockCode,'Stationarity'] = Stationarity

    exog_train = train_data[extra_indicators]
    model = ARIMA(endog = train_data[feature], exog = exog_train , order = Order)
    results = model.fit()
    print(results.params)
    print("Order: " + str(Order) )
    print('---------------------------------------------------------------------------')
    Results.loc[StockCode, 'Order'] = str(Order)

    exog_test = test_data[extra_indicators]
    predictions = results.predict(start = start, end = end, typ ='levels', exog=exog_test)
    predictions = modified_prediction_frame(predictions, test_data[feature].index)

    predictions.plot(figsize=(12,8), legend=True)
    test_data[feature].plot(figsize = (12,8), legend=True)

    errorEval = errorEvaluation(test_data[feature], predictions)
    RMSE, MAPE, R2, Noise = errorEval
    Results.loc[StockCode, ['RMSE', 'MAPE', 'R2', 'Noise']] = errorEval

    print("RMSE: {0} \nMape: {1} \nR2: {2} \nNoise: {3}".format(RMSE, MAPE, R2, Noise))
    print('---------------------------------------------------------------------------')

    print('Description of the Predicted Data')
    print(predictions.describe())
    pred_mean = predictions.mean(numeric_only=True)
    Results.loc[StockCode, 'Predictions Mean'] = str(float(pred_mean))
    print('---------------------------------------------------------------------------')
    
    Results.loc[StockCode, 'Model'] = model
    
    print('Description of the Actual Data')
    print(test_data[feature].describe())
    Results.loc[StockCode, 'Actual Mean'] = str(test_data[feature].mean())
    return predictions

# %% [markdown]
# ## ARIMAX for Closing Prices

# %%
try:
    ArimaxModelPricesResults = pd.read_csv('./Outputs/ArimaModelPricesResults.csv')
except FileNotFoundError:
    ArimaxModelPricesResults = pd.DataFrame(columns=['Stationarity', 'Order', 'RMSE', 'MAPE', 'R2', 'Noise', 'Predictions Mean', 'Actual Mean'], index = stocks)

# %%
for stock in stocks:
    print("Working for Stock {}".format(stock))
    train_data, test_data = TrainTestSplitByDateRange(ScriptWiseData[stock])
    feature = 'Close'
    Order = CalculateAutoArimaForArimax(stock, train_data, feature,  p= 'p Closing Values',d = 'd Closing Values', q = 'q Closing Values')
    ARIMAX_Model_Generic(StockCode = stock, data = ScriptWiseData, feature = feature, Results=ArimaxModelPricesResults, Order=Order, train_data=train_data, test_data=test_data,extra_indicators = TechnicalIndicators )
# Out:
# Working for Stock BOM524715
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-205-705f1baac92a> in <module>
#       3     train_data, test_data = TrainTestSplitByDateRange(ScriptWiseData[stock])
#       4     feature = 'Close'
# ----> 5     Order = CalculateAutoArimaForArimax(stock, train_data, feature,  p= 'p Closing Values',d = 'd Closing Values', q = 'q Closing Values')
#       6     ARIMAX_Model_Generic(StockCode = stock, data = ScriptWiseData, feature = feature, Results=ArimaxModelPricesResults, Order=Order, train_data=train_data, test_data=test_data,extra_indicators = TechnicalIndicators )
#
# <ipython-input-202-fdf75509dd6b> in CalculateAutoArimaForArimax(stockcode, data, parameter, p, d, q)
#       1 def CalculateAutoArimaForArimax(stockcode, data, parameter ,p ,d,q):
# ----> 2     if(AutoArimaResultsForArimax.loc[:, [p, d, q]].isnull().sum(axis=1)[stockcode] > 0):
#       3         params = auto_arima(data[parameter], exog = data[TechnicalIndicators], maxiter = 1000)
#       4         AutoArimaResultsForArimax.loc[stockcode, [p,d,q]] = params.order
#       5         return params.order
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#     356
#
# KeyError: 'BOM524715'

# %% [markdown]
# ### Please check this

# %%
ArimaModelPricesResults.to_csv('./Outputs/ArimaModelPricesResults.csv')

# %%
ArimaModelPricesResults

# %% [markdown]
# ## ARIMAX Normalized Closing Prices

# %%
try:
    ArimaxModelPricesResults_Norm = pd.read_csv('./Outputs/ArimaxModelPricesResults_Norm.csv')
except FileNotFoundError:
    ArimaxModelPricesResults_Norm = pd.DataFrame(columns=['Stationarity', 'Order', 'RMSE', 'MAPE', 'R2','Noise', 'Predictions Mean', 'Actual Mean'], index = stocks)

# %%
for stock in stocks:
    print("Working for Stock {}".format(stock))
    train_data, test_data = TrainTestSplitByDateRange(ScriptWiseData[stock])
    feature = 'Normalized Closing'
    Order = CalculateAutoArimaForArimax(stock, train_data, feature,'p N Closing Values', 'd N Closing Values', 'q N Closing Values')
    ARIMAX_Model_Generic(StockCode= stock, data = ScriptWiseData, feature = feature, Results=ArimaxModelPricesResults_Norm, Order=Order, train_data=train_data, test_data=test_data,extra_indicators = normalized_TechnicalIndicators)

# %%
ArimaxModelPricesResults_Norm.to_csv('./Outputs/ArimaxModelPricesResults_Norm.csv')

# %%
ArimaxModelPricesResults_Norm

# %% [markdown]
# ## ARIMAX Returns

# %%
try:
    ArimaxModelPricesResults_Returns = pd.read_csv('./Outputs/ArimaxModelPricesResults_Returns.csv')
except FileNotFoundError:
    ArimaxModelPricesResults_Returns = pd.DataFrame(columns=['Stationarity', 'Order', 'RMSE', 'MAPE', 'R2', 'Noise', 'Predictions Mean', 'Actual Mean'], index = stocks)

# %%
for stock in stocks:
    try:
        print("Working for Stock {}".format(stock))
        train_data, test_data = TrainTestSplitByDateRange(ScriptWiseData[stock])
        feature = 'Stock_Returns'
        Order = CalculateAutoArimaForArimax(stock, train_data, feature, p = 'p Closing Percentage', d = 'd Closing Percentage', q = 'q Closing Percentage')
#         ARIMAX_Model_Generic(StockCode= stock, data = ScriptWiseData, feature = feature, Results=ArimaxModelPricesResults_Returns, Order=Order, train_data=train_data, test_data=test_data, extra_indicators = TechnicalIndicators)
    except Exception as e:
        print(e)

# %%
ArimaxModelPricesResults_Returns.to_csv('./Outputs/ArimaxModelPricesResults_Returns.csv')

# %%
AutoArimaResults.to_csv('./Outputs/AutoArimaResultsForArimax.csv')

# %% [markdown]
# # SARIMAX MODEL

# %%
def SARIMAXProcedure(stockCode):
    # decompose
    data = ScriptWiseData  [stockCode]
    data.index = pd.to_datetime(data.index)
    data=data.asfreq('b')
    data = data.fillna(method='ffill')
    decompose_result = seasonal_decompose(data['Close'], model='add')
    
    r = auto_arima(data['Close'], exogenous=data[TechnicalIndicators], maxiter=1000) #seasonality, m parameters pending
    p, d, q = r.order # define for P, D, Q, S
        
    train, test = TrainTestSplitByDateRange(data)
    
    model = SARIMAX(train['Close'], exog = train[TechnicalIndicators] ,order = (p, d, q), seasonal_order = (1,1,1,2), enforce_invertibility = False)
    results = model.fit()
    predictions = results.predict(start_date, end_date, exog=test[TechnicalIndicators]).rename('SARIMA')
    
    return decompose_result, results, predictions

# %%
decompose_result, model, predictions = SARIMAXProcedure(stocks[2])

# %% [markdown]
# ### VARMAX MODEL

# %%
ScriptWiseData[stocks[0]]
# Out:
#               Close       RSI       ATR       MACD        adx        OBV  \
# Date
# 2000-02-11  2090.00  1.364001  131.2700  97.046900  19.756105   246481.0
# 2000-02-14  2125.00  1.489559  128.1250  92.209986  19.499189   267854.0
# 2000-02-15  2068.90  1.225341  126.1700  83.260861  18.662103   248155.0
# 2000-02-16  2075.00  1.246006  125.6700  75.754360  17.763029   256662.0
# 2000-02-17  2240.95  1.848351  130.8625  81.300839  18.112124   296910.0
# ...             ...       ...       ...        ...        ...        ...
# 2021-03-17   585.20  0.682121   17.9600  -1.488529  16.856154  7598758.0
# 2021-03-18   574.50  0.594893   18.3000  -3.999505  18.296442  7374060.0
# 2021-03-19   578.60  0.647393   18.6500  -5.594151  20.001070  7557363.0
# 2021-03-22   590.95  0.816829   18.3400  -5.794580  20.681635  7804331.0
# 2021-03-23   587.90  0.781779   17.8950  -6.128882  21.210826  7650902.0
#
#             Normalized Closing  Normalized RSI  Normalized ATR  \
# Date
# 2000-02-11           97.431355       81.551223      100.582331
# 2000-02-14           99.062981       89.058167       98.172554
# 2000-02-15           96.447718       73.261033       96.674584
# 2000-02-16           96.732087       74.496555       96.291472
# 2000-02-17          104.468323      110.509724      100.270094
# ...                        ...             ...             ...
# 2021-03-17           27.280779       40.782849       13.761398
# 2021-03-18           26.781968       35.567631       14.021914
# 2021-03-19           26.973101       38.706507       14.290093
# 2021-03-22           27.548832       48.836764       14.052563
# 2021-03-23           27.406648       46.741202       13.711593
#
#             Normalized MACD  Normalized ADX  Normalized OBV  Stock_Returns
# Date
# 2000-02-11        92.376124       98.618868       89.602085      -2.568645
# 2000-02-14        87.772006       97.336389       97.371712       1.674641
# 2000-02-15        79.253593       93.157809       90.210627      -2.640000
# 2000-02-16        72.108373       88.669795       93.303136       0.294843
# 2000-02-17        77.387905       90.412413      107.934304       7.997590
# ...                     ...             ...             ...            ...
# 2021-03-17        -1.416887       84.142844     2762.340958      -2.798771
# 2021-03-18        -3.807013       91.332497     2680.657545      -1.828435
# 2021-03-19        -5.324909       99.841688     2747.292827       0.713664
# 2021-03-22        -5.515693      103.238945     2837.071949       2.134462
# 2021-03-23        -5.833905      105.880572     2781.296622      -0.516118
#
# [5253 rows x 13 columns]

# %%
# Train and fit varmax model
def VARMAXProcedure(stockSymbol):
    data = ScriptWiseData[stockSymbol]
    data.index = pd.to_datetime(data.index)
    data=data.asfreq('D')
    data = data.fillna(method='ffill')
    data = data[['Close']+TechnicalIndicators]
    r = auto_arima(data['Close'], exogenous=data[TechnicalIndicators], maxiter=1000) #seasonality, m parameters pending
    p, d, q = r.order
    if(p==0 and d==0):
        p = 1
    # make data stationary based on auto arima output
    
    # train test split  
    train, test = TrainTestSplitByDateRange(data)
    
    # fit the model based on above parameters
    model = VARMAX(train, order=(p,q))
    results = model.fit(maxiter=1000, disp=False)
    forecasts = results.forecast(len(test))

    return results, forecasts, test

# %%
import datetime
try:
    VarmaxResults = pd.read_csv('./Outputs/VarmaxResults.csv')
except FileNotFoundError:
    VarmaxResults = pd.DataFrame(columns = ['StockName','MAE','MAPE', 'RMSE', 'AdjustedR2', 'Noise', 'Model'], index = stocks)
    
for s in stocks:
    print(getStockNameFromStockCode(s))
    try:
        print(datetime.datetime.now())
        if(np.isnan(VarmaxResults.loc[s, 'MAE'])):
            model, forecasts, test = VARMAXProcedure(s)
            print(f'Model Complete for {getStockNameFromStockCode(s)}')
            VarmaxResults.loc[s, ['Model']] =  model
            VarmaxResults.loc[s, ['StockName']] =  getStockNameFromStockCode(s)
            VarmaxResults.loc[s, ['MAE']] =  mean_absolute_error(forecasts.Close, test.Close)
            VarmaxResults.loc[s, ['RMSE']] = mean_squared_error(forecasts.Close, test.Close, squared=False)
            VarmaxResults.loc[s, ['MAPE']] = mean_absolute_percentage_error(forecasts.Close, test.Close)
            VarmaxResults.loc[s, ['AdjustedR2']] = r2_score(forecasts.Close, test.Close)
            VarmaxResults.loc[s, ['Noise']] = forecasts.Close.diff().abs().mean()
            VarmaxResults.to_csv('./Outputs/VarmaxResults.csv')
            print('Success')
        else:
            print('Already exists')
        print(datetime.datetime.now())
    except:
        print(f"Error Occured {getStockNameFromStockCode(s)}", sys.exc_info())

# %% [markdown]
# ## Prophet models

# %%
from fbprophet.diagnostics import cross_validation, performance_metrics
from fbprophet.plot import plot_cross_validation_metric
from prophet.utilities import regressor_coefficients
df_start_date = pd.to_datetime(start_date)
df_end_date = pd.to_datetime(end_date)

# %%
def ProphetProcedure(stockCode, start_date = start_date, end_date = end_date):
    df = ScriptWiseData[stockCode][['Close']]
    df.index = pd.to_datetime(df.index)
    df = df.reset_index()
    
    df.columns = ['ds', 'y']
    
    test_start_date = pd.to_datetime(start_date)
    test_end_date = pd.to_datetime(end_date)
    
    train = df.loc[df.ds<df_start_date]
    test = df.loc[df.ds>=df_start_date]
    m = Prophet()

    m.fit(train)
    future = m.make_future_dataframe(periods = len(test)-1, freq = "B")
#     test_t = test.set_index('ds')
#     future = future.set_index('ds')
#     future = test_t[].join(future).reset_index()
    forecast = m.predict(future)
    
        # initial
    initial = str(5*365)+' days'

    #period
    period = str(365)+' days'

    #horizon
    horizon = str(365) + ' days'
    df_cv = cross_validation(m, initial = initial, period = period, horizon = horizon)
    
    return m, forecast, df_cv

# %%
def ProphetProcedureWithExogenousVariables(stockCode, start_date = start_date, end_date = end_date):
    df = ScriptWiseData[stockCode][['Close']+TechnicalIndicators]
    df.index = pd.to_datetime(df.index)
    df = df.reset_index()
    
    df.columns = ['ds', 'y'] + TechnicalIndicators
    
    test_start_date = pd.to_datetime(start_date)
    test_end_date = pd.to_datetime(end_date)
    
    train = df.loc[df.ds<df_start_date]
    test = df.loc[df.ds>=df_start_date]
#     return df, 1
    m = Prophet()
    for t in TechnicalIndicators:
        m.add_regressor(t)
    m.fit(train)
    future = m.make_future_dataframe(periods = len(test)-1, freq = "B")
    test_t = test.set_index('ds')
    future = future.set_index('ds')
    future = test_t[TechnicalIndicators].join(future).reset_index()
    forecast = m.predict(future)
    
        # initial
    initial = str(5*365)+' days'

    #period
    period = str(365)+' days'

    #horizon
    horizon = str(365) + ' days'
    df_cv = cross_validation(m, initial = initial, period = period, horizon = horizon)
    
    return m, forecast, df_cv

# %%
# Hyper parameter tuning
# param_grid = {  
#     'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
#     'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
# }

# # Generate all combinations of parameters
# all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
# rmses = []  # Store the RMSEs for each params here

# # Use cross validation to evaluate all parameters
# for params in all_params:
#     m = Prophet(**params).fit(df)  # Fit model with given params
#     df_cv = cross_validation(m, cutoffs=cutoffs, horizon='30 days', parallel="processes")
#     df_p = performance_metrics(df_cv, rolling_window=1)
#     rmses.append(df_p['rmse'].values[0])

# # Find the best parameters
# tuning_results = pd.DataFrame(all_params)
# tuning_results['rmse'] = rmses
# print(tuning_results)

# %%
try:
    ProphetSingleRegressionResults = pd.read_csv('./Outputs/ProphetSingleRegressionResults.csv')
except FileNotFoundError:
    ProphetSingleRegressionResults = pd.DataFrame(columns = ['StockName','MAE','MAPE', 'RMSE', 'AdjustedR2', 'Noise', 'Model'], index = stocks)

# %%
# import json
# from prophet.serialize import model_to_json, model_from_json

# with open('serialized_model.json', 'w') as fout:
#     json.dump(model_to_json(m), fout)  # Save model

# with open('serialized_model.json', 'r') as fin:
#     m = model_from_json(json.load(fin))  # Load model

for s in stocks:
    print(s)
    try:
        m, forecast, df_cv = ProphetProcedure(s)
        val_metrics = performance_metrics(df_cv)
        ProphetSingleRegressionResults.loc[s, ['StockName']] =  getStockNameFromStockCode(s)
        ProphetSingleRegressionResults.loc[s, ['MAE']] =  val_metrics['mae'][0]
        ProphetSingleRegressionResults.loc[s, ['RMSE']] = np.sqrt(val_metrics['mse'][0])
        t = df_cv.dropna()
        ProphetSingleRegressionResults.loc[s, ['MAPE']] = mean_absolute_percentage_error(t.y, t.yhat)
        ProphetSingleRegressionResults.loc[s, ['AdjustedR2']] = r2_score(t.y, t.yhat)
        ProphetSingleRegressionResults.loc[s, ['Noise']] = t.yhat.diff().abs().mean()
        ProphetSingleRegressionResults.loc[s, ['Model']] = m
        print('Success')
    except:
        print("Error Occured", sys.exc_info())
        
ProphetSingleRegressionResults.to_csv('./Outputs/ProphetSingleRegressionResults.csv')
# Out:
# BOM524715
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM532488
# INFO:fbprophet:Making 11 forecasts with cutoffs between 2009-03-02 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/11 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500124
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500180
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM532174
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500247
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500470
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500228
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500440
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM532977
# INFO:fbprophet:Making 6 forecasts with cutoffs between 2014-03-01 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/6 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500570
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM532500
# INFO:fbprophet:Making 11 forecasts with cutoffs between 2009-03-02 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/11 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500209
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM532540
# INFO:fbprophet:Making 10 forecasts with cutoffs between 2010-03-02 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/10 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM507685
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# Success

# %%
try:
    ProphetMultipleRegressionResults = pd.read_csv('./Outputs/ProphetMultipleRegressionResults.csv')
except FileNotFoundError:
    ProphetMultipleRegressionResults = pd.DataFrame(columns = ['StockName','MAE','MAPE', 'RMSE', 'AdjustedR2', 'Noise', 'Model'], index = stocks)

# %%
# initalize result variable

for s in stocks:
    print(s)
    # try:
    m, forecast, df_cv = ProphetProcedureWithExogenousVariables(s)
    val_metrics = performance_metrics(df_cv)
    ProphetMultipleRegressionResults.loc[s, ['StockName']] =  getStockNameFromStockCode(s)
    ProphetMultipleRegressionResults.loc[s, ['MAE']] =  val_metrics['mae'][0]
    ProphetMultipleRegressionResults.loc[s, ['RMSE']] = np.sqrt(val_metrics['mse'][0])
    t = df_cv.dropna()
    ProphetMultipleRegressionResults.loc[s, ['MAPE']] = mean_absolute_percentage_error(t.y, t.yhat)
    ProphetMultipleRegressionResults.loc[s, ['AdjustedR2']] = r2_score(t.y, t.yhat)
    ProphetMultipleRegressionResults.loc[s, ['Noise']] = t.yhat.diff().abs().mean()
    ProphetMultipleRegressionResults.loc[s, ['Model']] = m
    print('Success')
    # except:
    #     print("Error Occured", sys.exc_info())
        
ProphetMultipleRegressionResults.to_csv('./Outputs/ProphetMultipleRegressionResults.csv')
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# BOM524715
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM532488
# INFO:fbprophet:Making 11 forecasts with cutoffs between 2009-03-02 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/11 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500124
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500180
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM532174
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500247
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500470
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500228
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500440
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM532977
# INFO:fbprophet:Making 6 forecasts with cutoffs between 2014-03-01 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/6 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500570
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM532500
# INFO:fbprophet:Making 11 forecasts with cutoffs between 2009-03-02 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/11 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM500209
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM532540
# INFO:fbprophet:Making 10 forecasts with cutoffs between 2010-03-02 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/10 [00:00<?, ?it/s]
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Success
# BOM507685
# INFO:fbprophet:Making 15 forecasts with cutoffs between 2005-03-03 00:00:00 and 2019-02-28 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# Success

# %%
# # for plotting
# df = ScriptWiseData[stocks[1]]
# df.index = pd.to_datetime(df.index)
# df = df.reset_index()
# df.columns = ['ds', 'y'] + TechnicalIndicators
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-6c78c69cb0b7> in <module>
#       3 df.index = pd.to_datetime(df.index)
#       4 df = df.reset_index()
# ----> 5 df.columns = ['ds', 'y'] + TechnicalIndicators
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 14 elements, new values have 7 elements

# %%
results = performance_metrics(df_cv)
results.head(2)

# %%
m.plot_components(forecast);

# %%
ax = forecast.plot(x='ds',y='yhat',label='Predictions',legend=True,figsize=(12,8))

df.plot(x='ds',y='y',label='Actual Price',legend=True,ax=ax) #,xlim=(df_start_date,df_end_date))

# %%
plot_cross_validation_metric(df_cv, metric='rmse');

# %% [markdown]
# ## Neural Prophet and AR-Net

# %%
from neuralprophet import NeuralProphet, set_random_seed , set_log_level
set_random_seed(0)
set_log_level("ERROR")

# %%
df = ScriptWiseData['BOM500180'].reset_index()
df = df[['Date', 'Close']]
df.columns = ['ds', 'y']
df.head()
# Out:
#            ds       y
# 0  2000-02-11  230.95
# 1  2000-02-14  234.00
# 2  2000-02-15  231.00
# 3  2000-02-16  249.45
# 4  2000-02-17  250.00

# %% [markdown]
# ### Basic Model

# %%
def BuildNeuralProphetModels(dataset, start_date = start_date, end_date = end_date, n_forecasts = 1, n_lags = 5, columnName = 'Close'):
    # prepare the dataset
    df = dataset.reset_index()
    df = df[['Date', columnName]]
    df.columns = ['ds', 'y']
    
    # train test splilt
    train = df.loc[(df['ds'] < start_date)]
    df_test = df.loc[(df['ds'] >= start_date) & (df['ds'] <= end_date)]
    
    # initalize the model
    m = NeuralProphet(n_forecasts=n_forecasts,n_lags=n_lags)
    
    # split the training set into train and validation set
    df_train, df_val = m.split_df(train, valid_p=0.2, freq='D')

    # fit and test the model
    train_metrics = m.fit(df_train, freq='D', progress_bar = False)
    val_metrics = m.test(df_val)
    
    # make forecasts
    future = m.make_future_dataframe(df_test, periods=len(df_test), n_historic_predictions=len(df_test))
#     future = m.make_future_dataframe(df_test, n_historic_predictions= True)
    forecast = m.predict(future)
    return (m, forecast,  train_metrics, val_metrics)

# %%
try:
    NPSingleRegressionResults = pd.read_csv('./Outputs/NeuralProphetSingleRegressionResults.csv')
except FileNotFoundError:
    NPSingleRegressionResults = pd.DataFrame(columns = ['StockName','MAE','MAPE', 'RMSE', 'AdjustedR2', 'Noise', 'Model'], index = stocks)

# %%
# initalize result variable
for s in stocks:
    print(s)
    try:
        m, forecast , train_metrics, val_metrics = BuildNeuralProphetModels(ScriptWiseData[s])
        NPSingleRegressionResults.loc[s, ['StockName']] =  getStockNameFromStockCode(s)
        NPSingleRegressionResults.loc[s, ['MAE']] =  val_metrics['MAE'][0]
        NPSingleRegressionResults.loc[s, ['RMSE']] = np.sqrt(val_metrics['MSE'][0])
        t = forecast.dropna()
        NPSingleRegressionResults.loc[s, ['MAPE']] = mean_absolute_percentage_error(t.y, t.yhat1)
        NPSingleRegressionResults.loc[s, ['AdjustedR2']] = r2_score(t.y, t.yhat1)
        NPSingleRegressionResults.loc[s, ['Noise']] = t.yhat1.diff().abs().mean()
        NPSingleRegressionResults.loc[s, ['Model']] = m
        print('Success')
    except:
        print("Error Occured")
        
NPSingleRegressionResults.to_csv('./Outputs/NeuralProphetSingleRegressionResults.csv')
# Out:
#   0%|          | 0/288 [00:00<?, ?it/s]
# BOM524715
#   0%|          | 0/284 [00:00<?, ?it/s]
# Success
# BOM532488
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM500124
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM500180
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM532174
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM500247
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM500470
# Success
# BOM500228
# Error Occured
# BOM500440
#   0%|          | 0/288 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
# Success
# BOM532977
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM500570
#   0%|          | 0/284 [00:00<?, ?it/s]
# Success
# BOM532500
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM500209
# Success
# BOM532540
#   0%|          | 0/282 [00:00<?, ?it/s]
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM507685
# Success

# %%
NPSingleRegressionResults
# Out:
#                                      StockName        MAE      MAPE  \
# BOM524715  SUN PHARMACEUTICAL INDUSTRIES LTD.    6.967936  0.015264
# BOM532488            DIVI'S LABORATORIES LTD.   12.471407  0.012332
# BOM500124        DR.REDDY'S LABORATORIES LTD.   31.186486  0.011435
# BOM500180                       HDFC Bank Ltd   11.412683  0.015701
# BOM532174                     ICICI BANK LTD.    8.220376   0.04107
# BOM500247            KOTAK MAHINDRA BANK LTD.      8.2158  0.014112
# BOM500470                     TATA STEEL LTD.    5.487968  0.015938
# BOM500228                                  NaN        NaN       NaN
# BOM500440            HINDALCO INDUSTRIES LTD.    2.537102  0.019312
# BOM532977                     BAJAJ AUTO LTD.    25.83194   0.01367
# BOM500570                    TATA MOTORS LTD.    4.124944  0.027545
# BOM532500            MARUTI SUZUKI INDIA LTD.   63.910629  0.014403
# BOM500209                        INFOSYS LTD.   27.464542  0.066246
# BOM532540      TATA CONSULTANCY SERVICES LTD.   21.967412  0.013694
# BOM507685                          WIPRO LTD.    9.440373  0.049458
#
#                 RMSE AdjustedR2      Noise  \
# BOM524715   9.349832   0.981051   6.441857
# BOM532488  19.774289   0.993397  32.323097
# BOM500124  40.884414   0.988363  39.957004
# BOM500180  31.773432   0.990267  13.985646
# BOM532174  10.055294   0.963905   6.708942
# BOM500247  12.353465   0.988528  20.171779
# BOM500470   7.967524   0.995923   6.576811
# BOM500228        NaN        NaN        NaN
# BOM500440   3.552581   0.994652   3.264525
# BOM532977  35.852435   0.989586  27.883971
# BOM500570   6.008651   0.995612   2.871548
# BOM532500    91.5731   0.983213  61.095571
# BOM500209  36.467788   0.933459  12.040495
# BOM532540  60.809023   0.991717  19.454148
# BOM507685  12.950222   0.973988   4.922563
#
#                                                        Model
# BOM524715  <neuralprophet.forecaster.NeuralProphet object...
# BOM532488  <neuralprophet.forecaster.NeuralProphet object...
# BOM500124  <neuralprophet.forecaster.NeuralProphet object...
# BOM500180  <neuralprophet.forecaster.NeuralProphet object...
# BOM532174  <neuralprophet.forecaster.NeuralProphet object...
# BOM500247  <neuralprophet.forecaster.NeuralProphet object...
# BOM500470  <neuralprophet.forecaster.NeuralProphet object...
# BOM500228                                                NaN
# BOM500440  <neuralprophet.forecaster.NeuralProphet object...
# BOM532977  <neuralprophet.forecaster.NeuralProphet object...
# BOM500570  <neuralprophet.forecaster.NeuralProphet object...
# BOM532500  <neuralprophet.forecaster.NeuralProphet object...
# BOM500209  <neuralprophet.forecaster.NeuralProphet object...
# BOM532540  <neuralprophet.forecaster.NeuralProphet object...
# BOM507685  <neuralprophet.forecaster.NeuralProphet object...

# %% [markdown]
# #### Plot the forecast

# %%
# forecasts_plot = m.plot(forecast)

# %%
# fig_comp = m.plot_components(forecast);

# %%
# fig_param = m.plot_parameters()

# %% [markdown]
# #### Validating the dataset

# %%
# m = NeuralProphet()
# df_train, df_val = m.split_df(df, valid_p=0.2, freq='D')

# %%
# train_metrics = m.fit(df_train, freq='D')
# val_metrics = m.test(df_val)

# %% [markdown]
# ## Multiple regressors

# %%
def BuildNeuralProphetModelsWithMultipleRegressors(dataset, start_date = start_date, end_date = end_date, n_forecasts = 1, n_lags = 5):
    # prepare the dataset
    df = dataset.reset_index()
    df = df[['Date', 'Close']+TechnicalIndicators]
    df.columns = ['ds', 'y', 'A', 'B', 'C', 'D', 'E']
    
    # train test splilt
    train = df.loc[(df['ds'] < start_date)]
    df_test = df.loc[(df['ds'] >= start_date) & (df['ds'] <= end_date)]
    
    # initalize the model
    m = NeuralProphet(n_forecasts=n_forecasts,n_lags=n_lags)
    # lagged regressors
    m.add_lagged_regressor(name='A')
    m.add_lagged_regressor(name='B')
    m.add_lagged_regressor(name='C')
    m.add_lagged_regressor(name='D')
    m.add_lagged_regressor(name='E')
    
    # split the training set into train and validation set
    df_train, df_val = m.split_df(train, valid_p=0.2, freq='D')

    # fit and test the model
    train_metrics = m.fit(df_train, freq='D',progress_bar = False)
    val_metrics = m.test(df_val)
    
    # make forecasts
    # future = m.make_future_dataframe(df_test, periods=len(df_test), n_historic_predictions=len(df_test))
    future = m.make_future_dataframe(df_test, n_historic_predictions= True)
    forecast = m.predict(future)
    return (m, forecast,  train_metrics, val_metrics)

# %%
try:
    NPExogenousRegressionResults = pd.read_csv('./Outputs/NeuralProphetRegressionWithExogenousVariablesResults.csv')
except FileNotFoundError:
    NPExogenousRegressionResults = pd.DataFrame(columns = ['StockName','MAE','MAPE', 'RMSE', 'AdjustedR2', 'Noise', 'Model'], index = stocks)

# %%
# initalize result variable
NPExogenousRegressionResults = pd.DataFrame(columns = ['StockName','MAE','MAPE', 'RMSE', 'AdjustedR2', 'Noise'], index = stocks)
for s in stocks:
    print(s)
    try:
        m, forecast , train_metrics, val_metrics = BuildNeuralProphetModelsWithMultipleRegressors(ScriptWiseData[s])
        NPExogenousRegressionResults.loc[s, ['StockName']] =  getStockNameFromStockCode(s)
        NPExogenousRegressionResults.loc[s, ['MAE']] =  val_metrics['MAE'][0]
        NPExogenousRegressionResults.loc[s, ['RMSE']] = np.sqrt(val_metrics['MSE'][0])
        t = forecast.dropna()
        NPExogenousRegressionResults.loc[s, ['MAPE']] = mean_absolute_percentage_error(t.y, t.yhat1)
        NPExogenousRegressionResults.loc[s, ['AdjustedR2']] = r2_score(t.y, t.yhat1)
        NPExogenousRegressionResults.loc[s, ['Noise']] = t.yhat1.diff().abs().mean()
        NPExogenousRegressionResults.loc[s, ['Noise']] = m
        print('Success')
    except:
        print("Error Occured")
        
NPExogenousRegressionResults.to_csv('./Outputs/NeuralProphetRegressionWithExogenousVariablesResults.csv')
# Out:
# BOM524715
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM532488
#   0%|          | 0/284 [00:00<?, ?it/s]
# Success
# BOM500124
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM500180
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM532174
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM500247
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM500470
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success
# BOM500228
# Error Occured
# BOM500440
#   0%|          | 0/288 [00:00<?, ?it/s]
#   0%|          | 0/276 [00:00<?, ?it/s]
# Success
# BOM532977
# Success
# BOM500570
#   0%|          | 0/288 [00:00<?, ?it/s]
#   0%|          | 0/284 [00:00<?, ?it/s]
# Success
# BOM532500
# Success
# BOM500209
#   0%|          | 0/288 [00:00<?, ?it/s]
#   0%|          | 0/282 [00:00<?, ?it/s]
# Success
# BOM532540
# Success
# BOM507685
#   0%|          | 0/288 [00:00<?, ?it/s]
# Success

# %%
NPExogenousRegressionResults
# Out:
#                                      StockName        MAE      MAPE  \
# BOM524715  SUN PHARMACEUTICAL INDUSTRIES LTD.    7.687661  0.015471
# BOM532488            DIVI'S LABORATORIES LTD.   23.359259  0.018698
# BOM500124        DR.REDDY'S LABORATORIES LTD.   45.767691  0.015201
# BOM500180                       HDFC Bank Ltd   12.291547  0.017491
# BOM532174                     ICICI BANK LTD.    9.428638  0.045272
# BOM500247            KOTAK MAHINDRA BANK LTD.    8.056787   0.01437
# BOM500470                     TATA STEEL LTD.     6.34917  0.017444
# BOM500228                                  NaN        NaN       NaN
# BOM500440            HINDALCO INDUSTRIES LTD.    4.027395  0.032431
# BOM532977                     BAJAJ AUTO LTD.   22.465128   0.01161
# BOM500570                    TATA MOTORS LTD.    4.067382   0.02714
# BOM532500            MARUTI SUZUKI INDIA LTD.   73.911029  0.017833
# BOM500209                        INFOSYS LTD.   55.186285  0.096944
# BOM532540      TATA CONSULTANCY SERVICES LTD.   21.411753  0.011856
# BOM507685                          WIPRO LTD.   19.235614  0.063047
#
#                  RMSE AdjustedR2  \
# BOM524715   10.598346   0.979083
# BOM532488   29.512802   0.987957
# BOM500124   55.161157   0.983793
# BOM500180   32.449522   0.987982
# BOM532174    11.81925   0.955388
# BOM500247   12.330192   0.987605
# BOM500470    8.682633   0.995097
# BOM500228         NaN        NaN
# BOM500440    5.241284   0.985944
# BOM532977   33.031827   0.991249
# BOM500570    6.101287   0.994681
# BOM532500  103.196782   0.977078
# BOM500209   63.754972   0.860093
# BOM532540   60.023962   0.993311
# BOM507685   25.464443    0.93583
#
#                                                        Noise
# BOM524715  <neuralprophet.forecaster.NeuralProphet object...
# BOM532488  <neuralprophet.forecaster.NeuralProphet object...
# BOM500124  <neuralprophet.forecaster.NeuralProphet object...
# BOM500180  <neuralprophet.forecaster.NeuralProphet object...
# BOM532174  <neuralprophet.forecaster.NeuralProphet object...
# BOM500247  <neuralprophet.forecaster.NeuralProphet object...
# BOM500470  <neuralprophet.forecaster.NeuralProphet object...
# BOM500228                                                NaN
# BOM500440  <neuralprophet.forecaster.NeuralProphet object...
# BOM532977  <neuralprophet.forecaster.NeuralProphet object...
# BOM500570  <neuralprophet.forecaster.NeuralProphet object...
# BOM532500  <neuralprophet.forecaster.NeuralProphet object...
# BOM500209  <neuralprophet.forecaster.NeuralProphet object...
# BOM532540  <neuralprophet.forecaster.NeuralProphet object...
# BOM507685  <neuralprophet.forecaster.NeuralProphet object...

# %%
# # m = NeuralProphet()
# # metrics = m.fit(df, freq="D")
# for s in stocks:
#     print(s)
#     try:
#         m, forecast , train_metrics, val_metrics = BuildNeuralProphetModelsWithMultipleRegressors(ScriptWiseData[s])
# #         m, forecast , train_metrics, val_metrics = BuildNeuralProphetModels(ScriptWiseData[s])
#         print('Succeess')
#     except:
#         print("Error Occured")

# %%
# forecasts_plot = m.plot(forecast)
# fig_comp = m.plot_components(forecast)

# %%
# train_metrics.sort_values(by=['MAE', 'MSE'], ascending = [False, False]).head(3)

# %%
# train_metrics.sort_values(by=['MAE', 'MSE'], ascending = [True, True]).head(3)

# %%
# val_metrics
