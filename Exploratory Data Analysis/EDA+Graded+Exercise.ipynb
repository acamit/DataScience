# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Reading & Data Types

# %%
#Read the data in pandas
inp0= pd.read_csv("Attribute+DataSet.csv")
inp1= pd.read_csv("Dress+Sales.csv")

# %% [markdown]
# You have “Attribute DataSet” which contains a column named “Price”. Choose the correct statement from the following about its data type and variable type.
# - Integer type and numerical variable
# - Object type and categorical ordinal variable
# - Object type and categorical nominal variable
# - Float type and categorical variable.

# %% [markdown]
# There is another column in “Attribute DataSet” named as “Recommendation”, choose the correct statement about its data type and variable type.
# - Integer type and categorical
# - Object type and categorical
# - Integer type and continuous numerical
# - Object type only.

# %% [markdown]
# Which of the following column do you think are of no use in “Attribute DataSet”.
# - Dress_ID
# - Price
# - Size and material
# - NeckLine
# - None of the above

# %%
# Print the information about the attributes of inp0 and inp1.
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
# Dress_ID          479 non-null int64
# Style             479 non-null object
# Price             477 non-null object
# Rating            479 non-null float64
# Size              479 non-null object
# Season            477 non-null object
# NeckLine          476 non-null object
# SleeveLength      477 non-null object
# Material          360 non-null object
# FabricType        223 non-null object
# Decoration        255 non-null object
# Pattern Type      377 non-null object
# Recommendation    479 non-null int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB

# %%
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
# Dress_ID      479 non-null float64
# 29-08-2013    479 non-null int64
# 31-08-2013    479 non-null int64
# 09-02-2013    479 non-null int64
# 09-04-2013    479 non-null int64
# 09-06-2013    479 non-null int64
# 09-08-2013    479 non-null int64
# 09-10-2013    479 non-null int64
# 09-12-2013    479 non-null object
# 14-09-2013    479 non-null object
# 16-09-2013    479 non-null object
# 18-09-2013    479 non-null object
# 20-09-2013    479 non-null object
# 22-09-2013    479 non-null object
# 24-09-2013    479 non-null int64
# 26-09-2013    257 non-null float64
# 28-09-2013    479 non-null int64
# 30-09-2013    222 non-null float64
# 10-02-2013    220 non-null float64
# 10-04-2013    221 non-null float64
# 10-06-2013    479 non-null int64
# 10-08-2013    224 non-null float64
# 10-10-2013    224 non-null float64
# 10-12-2013    479 non-null int64
# ...

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013 09-12-2013 14-09-2013  ... 24-09-2013 26-09-2013  \
# 0        2887        2930       3119       3204  ...       3554     3624.0
# 1        1066        1164       1558       1756  ...       2710     2942.0
# 2           8           9         10         10  ...         11       11.0
# 3        1621        1637       1723       1746  ...       1878     1892.0
# 4        1559        1570       1638       1655  ...       2032     2156.0
#
# ...

# %% [markdown]
# ### Fixing the Rows and Columns

# %% [markdown]
# As you can see, there is a column in “Attribute Dataset” named as ‘Size’. This column contains the values in abbreviation format. Write a code in Python to convert the followings:
#
# - M into  “Medium”
# - L into  “Large”
# - XL into “Extra large”
# - free into “Free”
# - S, s & small into “Small”.
#
# Now once you are done with changes in the dataset, what is the value of the lowest percentage, the highest percentage and the percentage of Small size categories in the column named “Size”?

# %%
# Column fixing, correcting size abbreviation. count the percentage of each size category in "Size" column.
def getSize(size):
    size1 = size
    size = size.lower()
    if size=='m':
        return 'Medium'
    elif size=='l':
        return 'Large'
    elif size=='xl':
        return 'Extra Large'
    elif size == 'free':
        return 'Free'
    elif size=='s' or size=='small':
        return 'Small'
    else:
        return size1
    
inp0.Size = inp0.Size.apply(getSize)

# %%
# Print the value counts of each category in "Size" column.
inp0.Size.value_counts(normalize=True)
# Out:
# Medium         0.356994
# Free           0.344468
# Large          0.194154
# Small          0.075157
# Extra Large    0.029228
# Name: Size, dtype: float64

# %% [markdown]
# ### Impute/Remove Missing values

# %%
# Print the null count of each variables of inp0 and inp1.
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# dtype: int64

# %%
inp1.isnull().sum()
# Out:
# Dress_ID        0
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      0
# 14-09-2013      0
# 16-09-2013      0
# 18-09-2013      0
# 20-09-2013      0
# 22-09-2013      0
# 24-09-2013      0
# 26-09-2013    222
# 28-09-2013      0
# 30-09-2013    257
# 10-02-2013    259
# 10-04-2013    258
# 10-06-2013      0
# 10-08-2013    255
# 10-10-2013    255
# 10-12-2013      0
# dtype: int64

# %% [markdown]
# You are given another dataset named “Dress Sales”. Now if you observe the datatypes of the columns using ‘inp1.info()’ command, you can identify that there are certain columns defined as object data type though they primarily consist of numeric data.
#
# Now if you try and convert these object data type columns into numeric data type(float), you will come across an error message. Try to correct this error.

# %%
# Print the data types information of inp1 i.e. "Dress Sales" data.
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
# Dress_ID      479 non-null float64
# 29-08-2013    479 non-null int64
# 31-08-2013    479 non-null int64
# 09-02-2013    479 non-null int64
# 09-04-2013    479 non-null int64
# 09-06-2013    479 non-null int64
# 09-08-2013    479 non-null int64
# 09-10-2013    479 non-null int64
# 09-12-2013    479 non-null object
# 14-09-2013    479 non-null object
# 16-09-2013    479 non-null object
# 18-09-2013    479 non-null object
# 20-09-2013    479 non-null object
# 22-09-2013    479 non-null object
# 24-09-2013    479 non-null int64
# 26-09-2013    257 non-null float64
# 28-09-2013    479 non-null int64
# 30-09-2013    222 non-null float64
# 10-02-2013    220 non-null float64
# 10-04-2013    221 non-null float64
# 10-06-2013    479 non-null int64
# 10-08-2013    224 non-null float64
# 10-10-2013    224 non-null float64
# 10-12-2013    479 non-null int64
# ...

# %%
inp1['22-09-2013'].unique()
# Out:
# array(['3479', '2454', '11', '1845', '1919', '22', '353', '150', '27',
#        '14', '89', '133', '2284', '3339', '53', '97', '2120', '18', '13',
#        '470', '291', '1388', '233', '1905', '5', '25', '2217', '215',
#        '515', '6926', '1561', '365', '1051', '1402', '2358', '1841',
#        '1817', '93', '907', '724', '181', '2984', '725', '1009', '283',
#        '144', '5349', '28', '1302', '4', '249', '236', '64', '1581',
#        '1060', '460', '723', '628', '428', '33', '12', '77', '2192',
#        '405', '813', '443', '26', '482', '8', '104', '845', '464', '56',
#        '787', '2285', '30', '6', '83', '1584', '506', '614', '21', '296',
#        '430', '374', '338', '24', '778', '143', '176', '2', '47', '0',
#        '452', '881', '590', '268', '735', '1337', '386', '2140', '616',
#        '81', '3443', '254', '1452', '472', '184', '654', '245', '447',
#        'Orders', '1275', '7', '293', '138', '737', '222', '504', '216',
# ...

# %%
# Try to convert the object type into float type of data. YOU GET ERROR MESSAGE.
# inp1['09-12-2013'] = inp1['09-12-2013'].astype(float)
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
# Dress_ID      479 non-null float64
# 29-08-2013    479 non-null int64
# 31-08-2013    479 non-null int64
# 09-02-2013    479 non-null int64
# 09-04-2013    479 non-null int64
# 09-06-2013    479 non-null int64
# 09-08-2013    479 non-null int64
# 09-10-2013    479 non-null int64
# 09-12-2013    479 non-null object
# 14-09-2013    479 non-null object
# 16-09-2013    479 non-null object
# 18-09-2013    479 non-null object
# 20-09-2013    479 non-null object
# 22-09-2013    479 non-null object
# 24-09-2013    479 non-null int64
# 26-09-2013    257 non-null float64
# 28-09-2013    479 non-null int64
# 30-09-2013    222 non-null float64
# 10-02-2013    220 non-null float64
# 10-04-2013    221 non-null float64
# 10-06-2013    479 non-null int64
# 10-08-2013    224 non-null float64
# 10-10-2013    224 non-null float64
# 10-12-2013    479 non-null int64
# ...

# %%
# Do the required changes in the "Dress Sales" data set to get null values on string values.
inp1['09-12-2013'].replace('Removed', np.NaN, inplace=True)
inp1.loc[inp1['14-09-2013']=='removed', '14-09-2013'] = np.NaN
inp1.loc[inp1['16-09-2013']=='removed', '16-09-2013'] = np.NaN
inp1.loc[inp1['18-09-2013']=='removed', '18-09-2013'] = np.NaN
inp1.loc[inp1['20-09-2013']=='removed', '20-09-2013'] = np.NaN
inp1.loc[inp1['22-09-2013']== 'Orders',"22-09-2013"] = np.NaN

# %%
# Convert the object type columns in "Dress Sales" into float type of data type.
inp1['09-12-2013'] = inp1['09-12-2013'].astype(float)
inp1['14-09-2013'] = inp1['14-09-2013'].astype(float)
inp1['16-09-2013'] = inp1['16-09-2013'].astype(float)
inp1['18-09-2013'] = inp1['18-09-2013'].astype(float)
inp1['20-09-2013'] = inp1['20-09-2013'].astype(float)
inp1['22-09-2013'] = inp1['22-09-2013'].astype(float)

# %% [markdown]
# When you see the null counts in “Dress Sales” dataset after performing all the operations that have been mentioned in jupyter notebook, you will find that there are some columns in “Dress Sales” data where there are more than 40% of missing values. Based on your understanding of dealing with missing values do the following steps.

# %%
# Print the null percetange of each column of inp1.

round(100*(inp1.isnull().sum()/len(inp1.index)), 2)
# Out:
# Dress_ID       0.00
# 29-08-2013     0.00
# 31-08-2013     0.00
# 09-02-2013     0.00
# 09-04-2013     0.00
# 09-06-2013     0.00
# 09-08-2013     0.00
# 09-10-2013     0.00
# 09-12-2013     0.21
# 14-09-2013     0.21
# 16-09-2013     0.21
# 18-09-2013     0.21
# 20-09-2013     0.21
# 22-09-2013     0.21
# 24-09-2013     0.00
# 26-09-2013    46.35
# 28-09-2013     0.00
# 30-09-2013    53.65
# 10-02-2013    54.07
# 10-04-2013    53.86
# 10-06-2013     0.00
# 10-08-2013    53.24
# 10-10-2013    53.24
# 10-12-2013     0.00
# dtype: float64

# %%
# Drop the columns in "Dress Sales" which have more than 40% of missing values.
inp1= inp1.drop(["26-09-2013"] , axis= 1)

inp1= inp1.drop(["30-09-2013"] , axis= 1)

inp1= inp1.drop(["10-02-2013"] , axis= 1)

inp1= inp1.drop(["10-04-2013"] , axis= 1)

inp1= inp1.drop(["10-08-2013"] , axis= 1)

inp1= inp1.drop(["10-10-2013"] , axis= 1)
inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  16-09-2013  18-09-2013  \
# 0        2887        2930      3119.0      3204.0      3277.0      3321.0
# 1        1066        1164      1558.0      1756.0      1878.0      1985.0
# 2           8           9        10.0        10.0        10.0        10.0
# 3        1621        1637      1723.0      1746.0      1783.0      1796.0
# 4        1559        1570      1638.0      1655.0      1681.0      1743.0
#
# ...

# %% [markdown]
# You should categorise the dates into seasons in “Dress Sales” data to simplify the analysis according to the following criteria:
# - June, July and August: Summer.
# - September, October and November: Autumn.
# - December, January and February: WInter.
# - March, April and May: Spring.

# %%
# Create the four seasons columns in inp1, according to the above criteria.
def getSeason(month):
    if month in ['June', 'July', 'August']:
        return 'Summer'
    elif month in ['September','October','November']:
        return 'Autumn'
    elif month in ['December','January' ,'February']:
        return 'Winter'
    else:
        return 'Spring'

# %%
cols= inp1.columns.values[1:]

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  16-09-2013  18-09-2013  \
# 0        2887        2930      3119.0      3204.0      3277.0      3321.0
# 1        1066        1164      1558.0      1756.0      1878.0      1985.0
# 2           8           9        10.0        10.0        10.0        10.0
# 3        1621        1637      1723.0      1746.0      1783.0      1796.0
# 4        1559        1570      1638.0      1655.0      1681.0      1743.0
#
# ...

# %%
inp1['Summer'] =0
inp1['Autumn'] =0
inp1['Winter'] =0
inp1['Spring'] =0

# %%
# calculate the sum of sales in each seasons in inp1 i.e. "Dress Sales".

for col in cols:
    dt = datetime.strptime(col, '%d-%m-%Y')
    month = dt.strftime("%B")
    inp1[getSeason(month)] += inp1[col]

inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  ...  20-09-2013  \
# 0        2887        2930      3119.0      3204.0  ...      3386.0
# 1        1066        1164      1558.0      1756.0  ...      2106.0
# 2           8           9        10.0        10.0  ...        10.0
# 3        1621        1637      1723.0      1746.0  ...      1812.0
# 4        1559        1570      1638.0      1655.0  ...      1824.0
#
#    22-09-2013  24-09-2013  28-09-2013  10-06-2013  10-12-2013  Summer  \
# ...

# %% [markdown]
# Now let's merge inp1 with inp0 with left join manner, so that the information of inp0 should remain intact.

# %%
# Merge inp0 with inp1 into inp0. this is also called left merge.
inp0 = pd.merge(left=inp0,right=inp1, how='left', left_on='Dress_ID', right_on='Dress_ID' )
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  ... 20-09-2013 22-09-2013  24-09-2013  \
# 0            NaN    chiffon  ...     3386.0     3479.0        3554
# 1     microfiber        NaN  ...     2106.0     2454.0        2710
# 2       polyster        NaN  ...       10.0       11.0          11
# 3           silk    chiffon  ...     1812.0     1845.0        1878
# 4  chiffonfabric    chiffon  ...     1824.0     1919.0        2032
#
#    28-09-2013  10-06-2013  10-12-2013  Summer   Autumn  Winter  Spring
# ...

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 479 entries, 0 to 478
# Data columns (total 34 columns):
# Dress_ID          479 non-null int64
# Style             479 non-null object
# Price             477 non-null object
# Rating            479 non-null float64
# Size              479 non-null object
# Season            477 non-null object
# NeckLine          476 non-null object
# SleeveLength      477 non-null object
# Material          360 non-null object
# FabricType        223 non-null object
# Decoration        255 non-null object
# Pattern Type      377 non-null object
# Recommendation    479 non-null int64
# 29-08-2013        479 non-null int64
# 31-08-2013        479 non-null int64
# 09-02-2013        479 non-null int64
# 09-04-2013        479 non-null int64
# 09-06-2013        479 non-null int64
# 09-08-2013        479 non-null int64
# 09-10-2013        479 non-null int64
# 09-12-2013        478 non-null float64
# 14-09-2013        478 non-null float64
# ...

# %%
inp0[['Summer', 'Autumn', 'Winter', 'Spring']].sum()
# Out:
# Summer     691907.0
# Autumn    1353543.0
# Winter     473640.0
# Spring     143600.0
# dtype: float64

# %%
# Now Drop the Date columns from inp0 as it is already combined into four seasons.
inp0.drop(inp0.loc[:,'29-08-2013':'10-12-2013'].columns, axis= 1, inplace= True)

# %% [markdown]
# Print the null count of inp0 to get the idea about the missing values in data set.

# %%
# Print the null count of each columns in inp0 dataframe i.e. combined data frame of inp0 and inp1 without date columns.
round(100*inp0.isnull().sum()/len(inp0.index), 2)
# Out:
# Dress_ID           0.00
# Style              0.00
# Price              0.42
# Rating             0.00
# Size               0.00
# Season             0.42
# NeckLine           0.63
# SleeveLength       0.42
# Material          24.84
# FabricType        53.44
# Decoration        46.76
# Pattern Type      21.29
# Recommendation     0.00
# Summer             0.00
# Autumn             0.42
# Winter             0.21
# Spring             0.00
# dtype: float64

# %% [markdown]
# You can see that there are two types of variables one with a large number of missing values and another is very less number of missing values. These two columns can be categorized as:
#
# Type-1: Missing values are very less (around 2 or 3 missing values): Price, Season, NeckLine, SleeveLength, Winter and Autumn.
#
# Type-2: Missing values are large in numbers (more than 15%): Material, FabricType, Decoration and Pattern Type.

# %%
# Deal with the missing values of Type-1 columns: Price, Season, NeckLine, SleeveLength, Winter and Autumn.
inp0 = inp0[~inp0.Price.isnull()]

inp0 = inp0[~inp0.Season.isnull()]

inp0 = inp0[~inp0.NeckLine.isnull()]

inp0 = inp0[~inp0.SleeveLength.isnull()]

inp0 = inp0[~inp0.Winter.isnull()]

inp0 = inp0[~inp0.Autumn.isnull()]

# %%
# Deal with the missing values for Type-2 columns: Material, FabricType, Decoration and Pattern Type.
inp0.Material= inp0.Material.replace(np.nan, "Missing")

inp0.FabricType= inp0.FabricType.replace(np.nan, "Missing")

inp0.Decoration= inp0.Decoration.replace(np.nan, "Missing")

inp0['Pattern Type']= inp0['Pattern Type'].replace(np.nan, "Missing")

# %% [markdown]
# ### Standardise value

# %% [markdown]
# In the given dataset, there are certain discrepancies with the categorical names such as irregular spellings. Choose the correct option of columns with irregular categories and update them.
#
# - Season, NeckLine
# - Price, Material
# - fabricType, Decoration
# - Season, SleeveLength

# %%
#correcting the spellings.
inp0['Season'] = inp0['Season'].str.capitalize()
inp0.Season.unique()
# Out:
# array(['Summer', 'Automn', 'Spring', 'Winter', 'Autumn'], dtype=object)

# %%
#correcting the Spellings.
inp0.Season.replace('Automn','Autumn' , inplace=True)
inp0.Season.unique()
# Out:
# array(['Summer', 'Autumn', 'Spring', 'Winter'], dtype=object)

# %%
inp0.NeckLine.unique()
# Out:
# array(['o-neck', 'v-neck', 'boat-neck', 'peterpan-collor', 'ruffled',
#        'turndowncollor', 'slash-neck', 'mandarin-collor', 'open',
#        'sqare-collor', 'Sweetheart', 'sweetheart', 'Scoop', 'halter',
#        'backless', 'bowneck'], dtype=object)

# %%
inp0['NeckLine'] = inp0['NeckLine'].str.lower()
inp0.NeckLine.unique()
# Out:
# array(['o-neck', 'v-neck', 'boat-neck', 'peterpan-collor', 'ruffled',
#        'turndowncollor', 'slash-neck', 'mandarin-collor', 'open',
#        'sqare-collor', 'sweetheart', 'scoop', 'halter', 'backless',
#        'bowneck'], dtype=object)

# %%
inp0.SleeveLength.unique()
# Out:
# array(['sleevless', 'Petal', 'full', 'butterfly', 'short', 'threequarter',
#        'halfsleeve', 'cap-sleeves', 'turndowncollor', 'threequater',
#        'capsleeves', 'sleeveless', 'sleeevless', 'half', 'urndowncollor',
#        'thressqatar', 'sleveless'], dtype=object)

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Unordered Univariate Analysis

# %% [markdown]
# There is a column named ‘Style’ in ‘Attribute Dataset’ which consists of the different style categories of the women apparels. Certain categories whose total sale is less than 50000 across all the seasons is considered under one single category as ‘Others’.

# %% [markdown]
# Which of the following categories in ‘Style’ column can be grouped into ‘Others’ category? and perform the grouping operation in the notebook for further analysis.
# - Flare, fashion
# - Novelty, bohemian
# - OL, fashion, work
# - Novelty, fashion, Flare

# %%
# Group "Style" categories into "Others" which have less than 50000 sales across all the seasons.
inp0['TotalSales'] = inp0['Summer']+inp0['Winter']+inp0['Autumn']+inp0['Spring']

# %%
inp2 = inp0.groupby('Style', as_index=False).sum()
inp2[inp2['TotalSales']<50000]
# Out:
#      Style    Dress_ID  Rating  Recommendation  Summer  Autumn  Winter  \
# 2    Flare  2011575734     0.0               1     451  1161.0   406.0
# 3  Novelty  6799573268    14.1               3    2866  7353.0  2504.0
# 4       OL  1194626925     0.0               0      63   158.0    53.0
# 8  fashion   836788720     4.0               0      91   211.0    74.0
#
#    Spring  TotalSales
# 2      71      2089.0
# 3     563     13286.0
# 4      15       289.0
# 8      19       395.0

# %%
inp2.loc[(inp2['TotalSales']<50000),'Style'].values
# Out:
# array(['Flare', 'Novelty', 'OL', 'fashion'], dtype=object)

# %%
inp3 = inp0.Style.replace(inp2.loc[(inp2['TotalSales']<50000),'Style'].values,'others', inplace=False)
inp3.value_counts()
# Out:
# Casual      217
# Sexy         65
# party        48
# cute         43
# vintage      25
# bohemian     23
# work         17
# Brief        17
# others       10
# sexy          6
# Name: Style, dtype: int64

# %% [markdown]
# ### Alternate Solution 2

# %%
inp2 = inp0.groupby('Style', as_index=True).sum()
inp2[inp2['TotalSales']<50000]
# Out:
#            Dress_ID  Rating  Recommendation  Summer  Autumn  Winter  Spring  \
# Style
# Flare    2011575734     0.0               1     451  1161.0   406.0      71
# Novelty  6799573268    14.1               3    2866  7353.0  2504.0     563
# OL       1194626925     0.0               0      63   158.0    53.0      15
# fashion   836788720     4.0               0      91   211.0    74.0      19
#
#          TotalSales
# Style
# Flare        2089.0
# Novelty     13286.0
# OL            289.0
# fashion       395.0

# %%
inp2.loc[(inp2['TotalSales']<50000)].index
# inp2.columns.values
# Out:
# Index(['Flare', 'Novelty', 'OL', 'fashion'], dtype='object', name='Style')

# %%
inp3 = inp0.Style.replace(inp2.loc[(inp2['TotalSales']<50000)].index,'others', inplace=False) ## use inplace =True for actual solution
inp3.value_counts()
# Out:
# Casual      217
# Sexy         65
# party        48
# cute         43
# vintage      25
# bohemian     23
# work         17
# Brief        17
# others       10
# sexy          6
# Name: Style, dtype: int64

# %% [markdown]
# ### Alternate Solution

# %%
total_collection=inp0.groupby(['Style'])['Spring','Winter','Autumn', 'Summer'].sum()

total_collection.sum(axis = 1)
# Out:
# Style
# Brief        139628.0
# Casual      1103558.0
# Flare          2089.0
# Novelty       13286.0
# OL              289.0
# Sexy         452355.0
# bohemian      69117.0
# cute         361999.0
# fashion         395.0
# party        142041.0
# sexy          77443.0
# vintage      180574.0
# work          93095.0
# dtype: float64

# %%
total_collection[total_collection.sum(axis= 1)<50000]
# Out:
#          Spring  Winter  Autumn  Summer
# Style
# Flare        71   406.0  1161.0     451
# Novelty     563  2504.0  7353.0    2866
# OL           15    53.0   158.0      63
# fashion      19    74.0   211.0      91

# %%
inp0.replace(total_collection[total_collection.sum(axis=1)<50000].index, 'Others', inplace=True)

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Autumn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation  Summer  \
# 0        Missing    chiffon     ruffles       animal               1   13899
# 1     microfiber    Missing     ruffles       animal               0    6216
# 2       polyster    Missing     Missing        print               0      40
# 3           silk    chiffon  embroidary        print               1    7213
# 4  chiffonfabric    chiffon         bow          dot               0    7706
#
# ...

# %% [markdown]
# What is the percentage of “cute” and “Others” category in “Style” column in “Attribute DataSet” respectively?
# - 46%, 5%
# - 9%, 2.1%
# - 2.1%, 5%
# - 13.8%, 9%

# %%
# Calculate the percentage of each categories in the "Style" variable.
(inp0.groupby('Style')['Style'].count()/len(inp0.index))*100
# Out:
# Style
# Brief        3.609342
# Casual      46.072187
# Others       2.123142
# Sexy        13.800425
# bohemian     4.883227
# cute         9.129512
# party       10.191083
# sexy         1.273885
# vintage      5.307856
# work         3.609342
# Name: Style, dtype: float64

# %%
inp0.Style.value_counts(normalize=True)
# Out:
# Casual      0.460722
# Sexy        0.138004
# party       0.101911
# cute        0.091295
# vintage     0.053079
# bohemian    0.048832
# work        0.036093
# Brief       0.036093
# Others      0.021231
# sexy        0.012739
# Name: Style, dtype: float64

# %%
s = inp0.Autumn.describe()
s
# Out:
# count      471.000000
# mean      2852.849257
# std       5037.033044
# min          1.000000
# 25%        410.500000
# 50%       1334.000000
# 75%       3126.000000
# max      55532.000000
# Name: Autumn, dtype: float64

# %%
t = inp0[['Autumn', 'Summer', 'Spring', 'Winter']].quantile([.99, 1])
t
# Out:
#        Autumn   Summer  Spring   Winter
# 0.99  24134.0  13974.0  2657.2   8985.3
# 1.00  55532.0  35577.0  7374.0  20388.0

# %%
t.diff()
# Out:
#        Autumn   Summer  Spring   Winter
# 0.99      NaN      NaN     NaN      NaN
# 1.00  31398.0  21603.0  4716.8  11402.7

# %%
print(s['max'])
print(s['75%'])
print(s['max']-s['75%'])
# Out:
# 55532.0
# 3126.0
# 52406.0

# %% [markdown]
# #### Similarly Club Neckline, SLeeve length categories into "Others" which have less than 50000 sales across all the seasons.

# %%
# Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.
# inp0.NeckLine.replace(inp0.loc[(inp0['TotalSales']<50000), 'NeckLine'].values,'others', inplace=True)
inp2 = inp0.groupby('NeckLine', as_index=True).sum()
inp2
# Out:
#                      Dress_ID  Rating  Recommendation  Summer    Autumn  \
# NeckLine
# backless            510519284     4.3               0     600    1690.0
# boat-neck         16852320412    49.2              12   13032   27968.0
# bowneck            8931816580    32.6               2    4583   12371.0
# halter              738079582     4.4               1     505    1336.0
# mandarin-collor    1194626925     0.0               0      63     158.0
# o-neck           229481943635   944.7             101  431970  852040.0
# open               2243103950     8.3               1    2040    3621.0
# peterpan-collor    4535220987     9.4               0    5429    9031.0
# ruffled             629131530     4.7               1   35577   55532.0
# scoop              1624762996     8.7               1     657    1802.0
# slash-neck        22355456748    94.9              10   16412   36571.0
# sqare-collor       4374323476    19.3               1    8459   16503.0
# ...

# %%
inp0.NeckLine.replace(inp2.loc[(inp2['TotalSales']<50000)].index,'others', inplace=True) 
inp0.groupby('NeckLine', as_index=True).sum()
# Out:
#                     Dress_ID  Rating  Recommendation  Summer    Autumn  \
# NeckLine
# boat-neck        16852320412    49.2              12   13032   27968.0
# o-neck          229481943635   944.7             101  431970  852040.0
# others           35748617735   139.2              16   25989   56410.0
# ruffled            629131530     4.7               1   35577   55532.0
# slash-neck       22355456748    94.9              10   16412   36571.0
# turndowncollor   11468910753    44.6               3   17825   34629.0
# v-neck          108530428685   367.4              56  141630  280542.0
#
#                   Winter  Spring  TotalSales
# NeckLine
# boat-neck         9265.0    2784     53049.0
# o-neck          299171.0   87921   1671102.0
# others           17649.0    6267    106315.0
# ruffled          20388.0    7374    118871.0
# slash-neck       11547.0    3866     68396.0
# turndowncollor   12548.0    3494     68496.0
# v-neck           97633.0   29835    549640.0

# %%
# Group "Sleeve length" categories into "Others" which have less than 50000 sales across all the seasons.
inp2 = inp0.groupby('SleeveLength', as_index=True).sum()
inp0['SleeveLength'].replace(inp2.loc[(inp2['TotalSales']<50000)].index,'others', inplace=True) 
inp0.groupby('SleeveLength', as_index=True).sum()
# Out:
#                   Dress_ID  Rating  Recommendation  Summer    Autumn  \
# SleeveLength
# full           78278210275   305.9              47  116794  233350.0
# halfsleeve     30659071305    94.0              10   55055  104841.0
# others         23579946227   104.7              10   23480   57924.0
# short          84873111937   314.2              27  186363  347819.0
# sleevless     192164799298   774.0              99  240186  495535.0
# threequarter   15511670456    51.9               6   60557  104223.0
#
#                 Winter  Spring  TotalSales
# SleeveLength
# full           80314.0   25036    455494.0
# halfsleeve     35755.0   11819    207470.0
# others         19116.0    4899    105419.0
# short         124509.0   37439    696130.0
# sleevless     169467.0   50358    955546.0
# threequarter   39040.0   11990    215810.0

# %% [markdown]
# Club material, fabrictype, patterntype and decoration categories into "Others" which have less than 25000 sales across all the seasons

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 471 entries, 0 to 478
# Data columns (total 18 columns):
# Dress_ID          471 non-null int64
# Style             471 non-null object
# Price             471 non-null object
# Rating            471 non-null float64
# Size              471 non-null object
# Season            471 non-null object
# NeckLine          471 non-null object
# SleeveLength      471 non-null object
# Material          471 non-null object
# FabricType        471 non-null object
# Decoration        471 non-null object
# Pattern Type      471 non-null object
# Recommendation    471 non-null int64
# Summer            471 non-null int64
# Autumn            471 non-null float64
# Winter            471 non-null float64
# Spring            471 non-null int64
# TotalSales        471 non-null float64
# dtypes: float64(4), int64(4), object(10)
# memory usage: 69.9+ KB

# %%
# Group "material" categories into "Others" which have less than 25000 sales across all the seasons.
inp2 = inp0.groupby('Material', as_index=True).sum()
inp0['Material'].replace(inp2.loc[(inp2['TotalSales']<25000)].index,'others', inplace=True) 
inp0.groupby('Material', as_index=True).sum()
# Out:
#                    Dress_ID  Rating  Recommendation  Summer    Autumn  \
# Material
# Missing        105338504945   411.5              60  172775  336779.0
# chiffonfabric   17948806105   102.6               8   92292  163959.0
# cotton         128560412651   490.8              62  186262  372874.0
# microfiber       2997379445     9.8               1    6454   17967.0
# milksilk         4546405506    23.4               1    8772   17107.0
# mix             11049018612    37.4               4   17684   34817.0
# nylon            9454126012    24.1               5    6576   16421.0
# others          26270692374    97.6               9   25371   52826.0
# polyster        87940733494   321.3              30  125980  248502.0
# rayon            8452858710    36.5               7   17819   32311.0
# silk            22507871644    89.7              12   22450   50129.0
#
#                  Winter  Spring  TotalSales
# Material
# Missing        118652.0   35006    663212.0
# ...

# %%
# Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.
inp2 = inp0.groupby('FabricType', as_index=True).sum()
inp0['FabricType'].replace(inp2.loc[(inp2['TotalSales']<25000)].index,'others', inplace=True) 
inp0.groupby('FabricType', as_index=True).sum()
# Out:
#                 Dress_ID  Rating  Recommendation  Summer    Autumn    Winter  \
# FabricType
# Missing     224470957478   878.4              99  310173  626217.0  216901.0
# broadcloth   28842656751    90.9              10   30718   61546.0   21585.0
# chiffon     115034158001   462.3              56  265067  502947.0  176263.0
# jersey       10611115087    47.5               7   32635   59360.0   21500.0
# others       24557854129    68.1              14   16623   37973.0   13084.0
# shiffon       7101760882    33.3               4    6170   15304.0    4324.0
# worsted      14448307170    64.2               9   21049   40345.0   14544.0
#
#             Spring  TotalSales
# FabricType
# Missing      64656   1217947.0
# broadcloth    6149    119998.0
# chiffon      54883    999160.0
# jersey        6457    119952.0
# others        3553     71233.0
# shiffon       1688     27486.0
# worsted       4155     80093.0

# %%
# Group "patern type" categories into "Others" which have less than 25000 sales across all the seasons.
inp2 = inp0.groupby('Pattern Type', as_index=True).sum()
inp0['Pattern Type'].replace(inp2.loc[(inp2['TotalSales']<25000)].index,'others', inplace=True) 
inp0.groupby('Pattern Type', as_index=True).sum()
# Out:
#                   Dress_ID  Rating  Recommendation  Summer    Autumn  \
# Pattern Type
# Missing        88873852043   333.2              55   58662  133793.0
# animal         18257540948    69.6               7   53975  107604.0
# dot            11455417298    46.7               7   70367  117370.0
# geometric       4086022768    24.1               1   33000   54131.0
# leopard         2746564241     9.0               1    6912   12169.0
# others          7567585996    28.0               2    7102   15966.0
# patchwork      42288001444   155.4              19   48402   98233.0
# print          62399699609   247.3              25  105061  204370.0
# solid         173432410356   671.3              77  283496  567694.0
# striped        13959714795    60.1               5   15458   32362.0
#
#                 Winter  Spring  TotalSales
# Pattern Type
# Missing        40719.0   14508    247682.0
# animal         39725.0    9969    211273.0
# dot            43181.0   14173    245091.0
# ...

# %%
# Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.
inp2 = inp0.groupby('Decoration', as_index=True).sum()
inp0['Decoration'].replace(inp2.loc[(inp2['TotalSales']<25000)].index,'others', inplace=True) 
inp0.groupby('Decoration', as_index=True).sum()
# Out:
#                 Dress_ID  Rating  Recommendation  Summer    Autumn    Winter  \
# Decoration
# Missing     198932001462   772.5              93  277261  557288.0  191284.0
# applique     18574030705    51.7               9   17207   34862.0   12448.0
# beading      18043106530    75.7              12   11737   25910.0    8839.0
# bow          11125940035    60.4               5   72872  122906.0   44467.0
# embroidary    3825909560    14.2               2   10485   21692.0    7803.0
# hollowout    20665583318    58.3               5   16397   35807.0   12287.0
# lace         60236189929   213.0              30  112519  212914.0   76116.0
# others       28017183084   129.6              15   28917   63520.0   19954.0
# ruffles      17341637610    51.7               7   48245   97978.0   36152.0
# sashes       35998737853   175.9              14   74451  145771.0   50077.0
# sequined     12306489412    41.7               7   12344   25044.0    8774.0
#
#             Spring  TotalSales
# ...

# %% [markdown]
# ### Caregorical Ordered Univariate Analysis

# %% [markdown]
# Which of the following is an unordered variable in “Attribute DataSet”.
# - Style
# - Price
# - Season
# - Size

# %% [markdown]
# ### Numerical variable Univariate analysis:

# %% [markdown]
# What is the approximate difference between the maximum value and 75th percentile in “Autumn” column.
# - Approx 54000
# - Approx 55000
# - Approx 52000
# - Approx 50000

# %%
# Describe the numerical variale: "Autumn".
inp0['Autumn'].describe()
# Out:
# count      471.000000
# mean      2852.849257
# std       5037.033044
# min          1.000000
# 25%        410.500000
# 50%       1334.000000
# 75%       3126.000000
# max      55532.000000
# Name: Autumn, dtype: float64

# %%
# plot the boxplot of "Autumn" column.
sns.boxplot(data = inp0, x='Autumn', y='TotalSales')
plt.show()

# %% [markdown]
# Which of the following season has the highest difference between the maximum value and 99th quantile of sales?
# - Winter
# - Summer
# - Spring
# - Autumn

# %%
# Find the maximum and 99th percentile of Winter season.
t = inp0[['Autumn', 'Summer', 'Spring', 'Winter']].quantile([.99, 1])
t
# Out:
#        Autumn   Summer  Spring   Winter
# 0.99  24134.0  13974.0  2657.2   8985.3
# 1.00  55532.0  35577.0  7374.0  20388.0

# %%
# Find the maximum and 99th percentile of Summer season.

# %%
# Find the maximum and 99th percentile of Spring season.

# %%
# Find the maximum and 99th percentile of Autumn season.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical- Categorical analysis

# %% [markdown]
# Which of the following “Price” category has the lowest average value of rating?
# - very-high
# - Medium
# - Low
# - High

# %%
# Find the Mean of Ratings for each Price category.
inp0.groupby('Price').mean()
# Out:
#                Dress_ID    Rating  Recommendation       Summer       Autumn  \
# Price
# Average    9.259981e+08  3.454430        0.362869  1429.852321  2829.569620
# High       8.964353e+08  2.914286        0.428571   803.809524  1498.428571
# Low        8.832568e+08  3.731481        0.425926  1835.524691  3601.333333
# Medium     8.713896e+08  3.156667        0.633333   842.866667  1597.233333
# very-high  8.357539e+08  3.123810        0.761905   192.333333   489.714286
#
#                 Winter      Spring   TotalSales
# Price
# Average     991.506329  293.189873  5544.118143
# High        513.047619  180.714286  2996.000000
# Low        1254.765432  380.259259  7071.882716
# Medium      544.966667  182.566667  3167.633333
# very-high   134.238095   56.238095   872.523810

# %% [markdown]
# What is the median of the rating of “vintage” category in Style column?
# - 4.6
# - 4.7
# - 4.55
# - 0.00

# %%
# Find the median of Ratings for each Style category.
inp0.groupby('Style').median()
# Out:
#               Dress_ID  Rating  Recommendation  Summer  Autumn  Winter  \
# Style
# Brief     8.712196e+08    4.60             0.0   460.0  1415.0   384.0
# Casual    8.911033e+08    4.60             0.0   585.0  1397.0   442.0
# Others    1.114583e+09    0.00             0.0   279.5   741.5   240.0
# Sexy      9.409186e+08    4.60             0.0   607.0  1635.0   482.0
# bohemian  9.110851e+08    4.60             1.0   430.0  1154.0   420.0
# cute      8.865011e+08    4.60             1.0   569.0  1587.0   368.0
# party     8.282912e+08    4.70             1.0   280.0   686.0   206.5
# sexy      9.791085e+08    4.55             0.5  2518.0  5391.5  2279.5
# vintage   1.016251e+09    4.60             0.0  1021.0  2152.0   774.0
# work      9.364258e+08    4.70             0.0   554.0  1403.0   502.0
#
#           Spring  TotalSales
# Style
# Brief      107.0      2399.0
# Casual     132.0      2539.0
# Others      54.5      1315.5
# Sexy        98.0      2928.0
# ...

# %% [markdown]
# Which of the following season has the highest average value of sale for “Recommendation” value equals to 1.
# - Summer
# - Spring
# - Autumn
# - Winter

# %%
# Summer sale vs Recommendation.
inp0.groupby('Recommendation')['Summer'].mean().plot.barh()
plt.show()

# %%
# Spring sale vs Recommendation.
inp0.groupby('Recommendation')['Spring'].mean().plot.barh()
plt.show()

# %%
# Autumn sale vs Recommendation.
inp0.groupby('Recommendation')['Autumn'].mean().plot.barh()
plt.show()
sns.boxplot(data=inp0, x='Recommendation', y='Autumn')
plt.show()

# %%
# Winter sale vs Recommendation.
inp0.groupby('Recommendation')['Winter'].mean().plot.barh()
plt.show()

# %% [markdown]
# ### Categorical categorical bivariate analysis

# %% [markdown]
# Which of the following size categories has the highest positive recommendations?
# - Medium and extra large
# - Extra large and small
# - Free and small
# - Free and medium

# %%
# Size vs Recommendation.
inp0.groupby('Size')['Recommendation'].mean()
# Out:
# Size
# Extra Large    0.285714
# Free           0.456790
# Large          0.359551
# Medium         0.447059
# Small          0.361111
# Name: Recommendation, dtype: float64

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# Which of the following pair of “Style” and “Price” category has the highest average of positive recommendations?
# - Price: medium and style: vintage
# - Price: medium and style: cute
# - Price: very high and style: party
# - Price: low and style: sexy

# %%
# plot the heat map of Style, price and Recommendation.
res = pd.pivot_table(data = inp0, index='Style', columns='Price', values='Recommendation')
sns.heatmap(res, annot=True, cmap='RdYlGn')
plt.show()

# %% [markdown]
# Which of the following material type has no recommendation in summer and winter seasons?
# - Mix and Milksilk
# - Nylon and Rayon
# - Microfiber and Silk
# - Milksilk and Microfiber

# %%
# plot the heat map of Season, material and Recommendation.
res = pd.pivot_table(data = inp0, index='Season', columns='Material', values='Recommendation')
sns.heatmap(res, annot=True, cmap='RdYlGn')
plt.show()
