# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv('Movie+Assignment+Data.csv')# Write your code for importing the csv file here
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
# list of columns
print(list(movies.columns.values))
# print(movies.axes[1])
# Out:
# ['color', 'director_name', 'num_critic_for_reviews', 'duration', 'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name', 'movie_title', 'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name', 'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link', 'num_user_for_reviews', 'language', 'country', 'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score', 'aspect_ratio', 'movie_facebook_likes']

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# code for inspection
print(movies.size)

print(movies.shape)

movies.info()
# Out:
# 141204
# (5043, 28)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %%
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %% [markdown]
# #### Observations
# 1. num_critic_for_review -
#     - The values range from 1 to 813 but mean is 140.19.
#     - 195 is the third quartile therefore majority, therefore there should be some outliers.
# 2. director_facebook_likes, actor_3_facebook_likes , actor_1_facebook_likes, cast_total_facebook_likes -
#     - Again there is a significant difference in mean value and the max value.
#     - 75 percentile number is very less than max, there are a few outlier here as well
# 3. Intersetingly the pattern mentioned in point 2 is observed in most of the columns except - title_year, imdb_score
# 4. title_year
#     - Mean value is of no significance here since we are considering the time range. However, it is clear that we are analyzing data for movies between 1916, 2016

# %%
numofRows = len(movies.index)
numofRows
# Out:
# 5043

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here
row_wise_null = movies.isnull().sum(axis=1)
print(row_wise_null)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# print rows with null values
movies.iloc[row_wise_null.nonzero()]
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4       NaN       Doug Walker                     NaN       NaN
# 55    Color        Peter Sohn                   298.0      93.0
# 84    Color      Roland Joffé                    10.0     109.0
# 98    Color      Hideaki Anno                     1.0     120.0
# 99    Color     Peter Jackson                   645.0     182.0
# ...     ...               ...                     ...       ...
# 5037  Color      Edward Burns                    14.0      95.0
# 5038  Color       Scott Smith                     1.0      87.0
# 5039  Color               NaN                    43.0      43.0
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 4                       131.0                     NaN          Rob Walker
# ...

# %% [markdown]
# ### Observation
# - 1287 rows have null values

# %%
# Write your code for column-wise null percentages here
res = round(100*(movies.isnull().sum()/len(movies.index)), 2)
res.sort_values(ascending=False)
# Out:
# gross                        17.53
# budget                        9.76
# aspect_ratio                  6.52
# content_rating                6.01
# plot_keywords                 3.03
# title_year                    2.14
# director_name                 2.06
# director_facebook_likes       2.06
# num_critic_for_reviews        0.99
# actor_3_name                  0.46
# actor_3_facebook_likes        0.46
# num_user_for_reviews          0.42
# color                         0.38
# duration                      0.30
# facenumber_in_poster          0.26
# actor_2_name                  0.26
# actor_2_facebook_likes        0.26
# language                      0.24
# actor_1_name                  0.14
# actor_1_facebook_likes        0.14
# country                       0.10
# movie_facebook_likes          0.00
# genres                        0.00
# movie_title                   0.00
# num_voted_users               0.00
# movie_imdb_link               0.00
# imdb_score                    0.00
# ...

# %% [markdown]
# ### Observation
# - maximum null values are present in gross column followed by budget and aspect_ration and content rating

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
print(movies.color.unique())
# drop color column
movies = movies.drop('color', axis=1)
# verify column is not in columns list
print('color' in movies.columns)
movies.head()
# Out:
# ['Color' nan ' Black and White']
# False
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 4        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
movies = movies.drop('director_facebook_likes', axis=1)
# verify column is not in columns list
print('director_facebook_likes' in movies.columns)
movies.head()
# Out:
# False
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 4        Doug Walker                     NaN       NaN
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
# 2                   161.0      Rory Kinnear                 11000.0
# 3                 23000.0    Christian Bale                 27000.0
# 4                     NaN        Rob Walker                   131.0
#
#          gross                           genres     actor_1_name  \
# 0  760505847.0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1  309404152.0         Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
# drop remaining columns at once
movies = movies.drop(['actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','actor_2_name','cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating','country',
'movie_imdb_link','aspect_ratio','plot_keywords'], axis=1)

# %%
# verify column is not in columns list
print('actor_2_facebook_likes' in movies.columns)
print(movies.shape)
movies.head()
# Out:
# False
# (5043, 13)
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4        Doug Walker                     NaN          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# ...

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# column-wise null percentages
res = round(100*(movies.isnull().sum()/len(movies.index)), 2)
res.sort_values(ascending=False)
# Out:
# gross                     17.53
# budget                     9.76
# title_year                 2.14
# director_name              2.06
# num_critic_for_reviews     0.99
# num_user_for_reviews       0.42
# language                   0.24
# actor_1_name               0.14
# movie_facebook_likes       0.00
# imdb_score                 0.00
# num_voted_users            0.00
# movie_title                0.00
# genres                     0.00
# dtype: float64

# %%
# Write your code for dropping the rows here
# movies.isnull().all(axis=1)
# movies.isnull().all(axis=1).sum()
movies = movies.loc[movies.gross.notnull()]
print(movies.shape)
movies.head()
# Out:
# (4159, 13)
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 5     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# ...

# %%
# lets review column-wise null percentages
res = round(100*(movies.isnull().sum()/len(movies.index)), 2)
res.sort_values(ascending=False)
# Out:
# budget                    6.44
# actor_1_name              0.10
# title_year                0.07
# language                  0.07
# num_critic_for_reviews    0.07
# director_name             0.07
# num_user_for_reviews      0.02
# movie_facebook_likes      0.00
# imdb_score                0.00
# num_voted_users           0.00
# movie_title               0.00
# genres                    0.00
# gross                     0.00
# dtype: float64

# %% [markdown]
# ### Observation
# - Gross column does not have any null values now
# - Budget has 6.44% null values

# %%
# remove rows for which budget is null. 
movies = movies.loc[movies.budget.notnull()]
print(movies.shape)
movies.head()
# Out:
# (3891, 13)
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 5     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# ...

# %%
# lets review column-wise null percentages
res = round(100*(movies.isnull().sum()/len(movies.index)), 2)
res.sort_values(ascending=False)
# Out:
# language                  0.08
# actor_1_name              0.08
# num_critic_for_reviews    0.03
# movie_facebook_likes      0.00
# imdb_score                0.00
# title_year                0.00
# budget                    0.00
# num_user_for_reviews      0.00
# num_voted_users           0.00
# movie_title               0.00
# genres                    0.00
# gross                     0.00
# director_name             0.00
# dtype: float64

# %% [markdown]
# ### Observation
# - The data now has negligible null values. Original data had 5043 rows. Now we have 3891 rows

# %%
movies.describe()
# Out:
#        num_critic_for_reviews         gross  num_voted_users  \
# count             3890.000000  3.891000e+03     3.891000e+03
# mean               163.234704  5.105500e+07     1.025834e+05
# std                124.053735  6.980248e+07     1.507162e+05
# min                  1.000000  1.620000e+02     5.000000e+00
# 25%                 72.250000  6.836508e+06     1.731400e+04
# 50%                134.000000  2.797940e+07     5.041500e+04
# 75%                221.750000  6.536066e+07     1.242035e+05
# max                813.000000  7.605058e+08     1.689764e+06
#
#        num_user_for_reviews        budget   title_year   imdb_score  \
# count           3891.000000  3.891000e+03  3891.000000  3891.000000
# mean             327.309946  4.521028e+07  2003.081470     6.463506
# std              408.006292  2.223895e+08    10.001352     1.056080
# min                1.000000  2.180000e+02  1920.000000     1.600000
# 25%              102.000000  1.000000e+07  1999.000000     5.900000
# ...

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Inspect values 
print(movies.language.value_counts())
# Out:
# English       3707
# French          37
# Spanish         26
# Mandarin        15
# German          13
# Japanese        12
# Hindi           10
# Cantonese        8
# Italian          7
# Korean           5
# Portuguese       5
# Norwegian        4
# Thai             3
# Dutch            3
# Danish           3
# Hebrew           3
# Persian          3
# Indonesian       2
# Aboriginal       2
# Dari             2
# None             1
# Russian          1
# Arabic           1
# Swedish          1
# Dzongkha         1
# Vietnamese       1
# Bosnian          1
# Hungarian        1
# Zulu             1
# Mongolian        1
# Czech            1
# Romanian         1
# Icelandic        1
# Maya             1
# Filipino         1
# Aramaic          1
# Telugu           1
# Kazakh           1
# Name: language, dtype: int64

# %%
movies[movies.language=='None']
# Out:
#      director_name  num_critic_for_reviews      gross             genres  \
# 3931    Ron Fricke                   115.0  2601847.0  Documentary|Music
#
#                 actor_1_name movie_title  num_voted_users  \
# 3931  Collin Alfredo St. Dic    Samsara             22457
#
#       num_user_for_reviews language     budget  title_year  imdb_score  \
# 3931                  69.0     None  4000000.0      2011.0         8.5
#
#       movie_facebook_likes
# 3931                 26000

# %%
# unique list of languages
len(movies.language.unique())
# Out:
# 39

# %%
# Write your code for filling the NaN values in the 'language' column here
movies.loc[(movies.language.isnull()) | (movies.language=='None'), ['language']]='English'

#inspect values
print(movies.language.value_counts())
# Out:
# English       3711
# French          37
# Spanish         26
# Mandarin        15
# German          13
# Japanese        12
# Hindi           10
# Cantonese        8
# Italian          7
# Korean           5
# Portuguese       5
# Norwegian        4
# Thai             3
# Dutch            3
# Danish           3
# Hebrew           3
# Persian          3
# Indonesian       2
# Aboriginal       2
# Dari             2
# Mongolian        1
# Hungarian        1
# Arabic           1
# Swedish          1
# Dzongkha         1
# Vietnamese       1
# Bosnian          1
# Zulu             1
# Russian          1
# Telugu           1
# Czech            1
# Romanian         1
# Icelandic        1
# Maya             1
# Filipino         1
# Aramaic          1
# Kazakh           1
# Name: language, dtype: int64

# %%
# lets review column-wise null percentages
res = round(100*(movies.isnull().sum()/len(movies.index)), 2)
res.sort_values(ascending=False)
# Out:
# actor_1_name              0.08
# num_critic_for_reviews    0.03
# movie_facebook_likes      0.00
# imdb_score                0.00
# title_year                0.00
# budget                    0.00
# language                  0.00
# num_user_for_reviews      0.00
# num_voted_users           0.00
# movie_title               0.00
# genres                    0.00
# gross                     0.00
# director_name             0.00
# dtype: float64

# %%
len(movies.language.unique())
# Out:
# 37

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
rowsRetained = round(100*(len(movies.index)/numofRows), 2)
print(rowsRetained)
# Out:
# 77.16

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
sortedbyBudget = movies.sort_values(by='budget', inplace=False)
sortedbyBudget['budget'].head()
# Out:
# 4799     218.0
# 5042    1100.0
# 5026    4500.0
# 5035    7000.0
# 5034    7000.0
# Name: budget, dtype: float64

# %%
sortedbyBudget['budget'].tail()
# Out:
# 2334    2.127520e+09
# 2323    2.400000e+09
# 3005    2.500000e+09
# 3859    4.200000e+09
# 2988    1.221550e+10
# Name: budget, dtype: float64

# %%
movies.sort_values(by='budget', ascending=False,inplace=False)['budget'].head()
# Out:
# 2988    1.221550e+10
# 3859    4.200000e+09
# 3005    2.500000e+09
# 2323    2.400000e+09
# 2334    2.127520e+09
# Name: budget, dtype: float64

# %%
# Write your code for unit conversion here
movies['budget'] = movies['budget']/1000000
movies['gross'] = movies['gross']/1000000
movies.sort_values(by=['budget', 'gross'], inplace=True)
movies.head()
# Out:
#           director_name  num_critic_for_reviews     gross  \
# 4799  Jonathan Caouette                    72.0  0.592014
# 5042           Jon Gunn                    43.0  0.085222
# 5026    Olivier Assayas                    81.0  0.136007
# 5034   Neill Dela Llana                    35.0  0.070071
# 5033      Shane Carruth                   143.0  0.424760
#
#                      genres   actor_1_name         movie_title  \
# 4799  Biography|Documentary     Greg Ayres          Tarnation
# 5042            Documentary    John August  My Date with Drew
# 5026    Drama|Music|Romance  Maggie Cheung              Clean
# 5034               Thriller    Ian Gamazon             Cavite
# 5033  Drama|Sci-Fi|Thriller  Shane Carruth             Primer
#
#       num_voted_users  num_user_for_reviews language    budget  title_year  \
# 4799             5709                 114.0  English  0.000218      2003.0
# 5042             4285                  84.0  English  0.001100      2004.0
# ...

# %%
sortedbyBudget = movies.sort_values(by='budget', inplace=False)
sortedbyBudget['budget'].head()
# Out:
# 4799    0.000218
# 5042    0.001100
# 5026    0.004500
# 5034    0.007000
# 5033    0.007000
# Name: budget, dtype: float64

# %%
sortedbyBudget['budget'].tail()
# Out:
# 2334     2127.519898
# 2323     2400.000000
# 3005     2500.000000
# 3859     4200.000000
# 2988    12215.500000
# Name: budget, dtype: float64

# %%
movies.sort_values(by='gross', ascending=True).head()
# Out:
#               director_name  num_critic_for_reviews     gross  \
# 3330    Ekachai Uekrongtham                    66.0  0.000162
# 4607           Frank Whaley                     9.0  0.000703
# 4606  Brian Trenchard-Smith                     8.0  0.000721
# 4915            Ricki Stern                    11.0  0.001111
# 4758        Alex Craig Mann                    29.0  0.001332
#
#                      genres       actor_1_name                 movie_title  \
# 3330  Action|Crime|Thriller  Michael Jai White                 Skin Trade
# 4607           Comedy|Drama         Lynn Cohen             The Jimmy Show
# 4606           Action|Drama        David Keith        In Her Line of Fire
# 4915      Crime|Documentary        Darryl Hunt  The Trials of Darryl Hunt
# 4758          Comedy|Horror        Justin Chon      Detention of the Dead
#
#       num_voted_users  num_user_for_reviews language  budget  title_year  \
# ...

# %% [markdown]
# ### Observation
# - Looking at the maximum and minimum values of budget and gross we can round off the values to min 4 decimal places if required

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
movies['profit'] = movies['gross']-movies['budget']

# %%
# Write your code for sorting the dataframe here
movies.sort_values(by='profit', ascending=True, inplace=True)
movies.head(10)
# Out:
#         director_name  num_critic_for_reviews      gross  \
# 2988     Joon-ho Bong                   363.0   2.201412
# 3859   Chan-wook Park                   202.0   0.211667
# 3005     Lajos Koltai                    73.0   0.195888
# 2323   Hayao Miyazaki                   174.0   2.298191
# 2334  Katsuhiro Ôtomo                   105.0   0.410388
# 3423  Katsuhiro Ôtomo                   150.0   0.439162
# 4542    Takao Okawara                   107.0  10.037390
# 3851     Carlos Saura                    35.0   1.687311
# 3075      Karan Johar                    20.0   3.275443
# 3273      Anurag Basu                    41.0   1.602466
#
#                                                  genres      actor_1_name  \
# 2988                         Comedy|Drama|Horror|Sci-Fi         Doona Bae
# 3859                                        Crime|Drama      Min-sik Choi
# 3005                                  Drama|Romance|War      Marcell Nagy
# ...

# %%
# Write your code to get the top 10 profiting movies here

#since data is already sorted in ascending order by profit, we can extract the last 10 rows. These rows will be in asceding order of profit

top10 = movies[-10:].sort_values(by='profit', ascending=False)
top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 794         Joss Whedon                   703.0  623.279547
# 17          Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %%
plt.boxplot(movies['profit'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2622100be88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26221011cc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2622100b708>],
#  'medians': [<matplotlib.lines.Line2D at 0x26221011e88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2622101bf88>],
#  'means': []}

# %%
# Write code for profit vs budget plot here
plt.xlabel('budget')
plt.ylabel('Profit')
plt.scatter(movies['budget'], movies['profit'])

# %% [markdown]
# ### Observation
# - As mentioned earlier for different columns, we see we have some outliers here as well.
# - We are inspecting the data here but not removing them for the purpose of further questions. We might remove these later and see clearer picture.

# %%
# remove the outliers
profitableMovies = movies[(movies['profit']>0)]

movies1000 = movies[(movies['profit']>-1000)]

movies3000 = movies[(movies['profit']>-3000)]

movies5000 = movies[(movies['profit']>-5000)]

# %%
# Write code for profit vs budget plot here
plt.figure(figsize =(16,16))
plt.subplot(221)
plt.xlabel('budget')
plt.ylabel('Profit')
plt.title('Profitable Movies')
plt.scatter(profitableMovies['budget'], profitableMovies['profit'])


plt.subplot(222)
plt.xlabel('budget')
plt.ylabel('Profit')
plt.title('Profitable or not exceeding loss of 1000')
plt.scatter(movies1000['budget'], movies1000['profit'])


plt.subplot(223)
plt.xlabel('budget')
plt.ylabel('Profit')
plt.title('Profitable or not exceeding loss of 3000')
plt.scatter(movies3000['budget'], movies3000['profit'])


plt.subplot(224)
plt.xlabel('budget')
plt.ylabel('Profit')
plt.title('Profitable or not exceeding loss of 5000')
plt.scatter(movies5000['budget'], movies5000['profit'])

plt.show()

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
# number of rows and columns after removing duplicates
print(movies.shape)
# Out:
# (3891, 14)

# %%
# Write your code for dropping duplicate values here
movies.drop_duplicates(inplace=True)

# number of rows and columns after removing duplicates
print(movies.shape)
# Out:
# (3856, 14)

# %%
# Write code for repeating subtask 2 here

top10 = movies[-10:].sort_values(by='profit', ascending=False)
top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 794         Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
# 439           Gary Ross                   673.0  407.999255
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %%
# Write code for profit vs budget plot here
plt.xlabel('Budget')
plt.ylabel('Profit')
plt.scatter(movies['budget'], movies['profit'])

# %%
# Write code for profit vs budget plot here
plt.figure(figsize =(20,20))
plt.subplot(221)
plt.xlabel('Budget')
plt.ylabel('Profit')
plt.title('Profitable Movies')
plt.scatter(profitableMovies['budget'], profitableMovies['profit'])


plt.subplot(222)
plt.xlabel('Budget')
plt.ylabel('Profit')
plt.title('Profitable or not exceeding loss of 1000')
plt.scatter(movies1000['budget'], movies1000['profit'])


plt.subplot(223)
plt.xlabel('Budget')
plt.ylabel('Profit')
plt.title('Profitable or not exceeding loss of 3000')
plt.scatter(movies3000['budget'], movies3000['profit'])


plt.subplot(224)
plt.xlabel('Budget')
plt.ylabel('Profit')
plt.title('Profitable or not exceeding loss of 5000')
plt.scatter(movies5000['budget'], movies5000['profit'])

plt.show()

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
IMDb_Top_250 = movies[(movies['num_voted_users']>25000)].sort_values(by='imdb_score', ascending=False)[:250]

IMDb_Top_250['rank'] = range(1, 251)
# or we can use rank function as shown below

# IMDb_Top_250['rank'] = IMDb_Top_250['imdb_score'].rank(ascending=False, method='first')

IMDb_Top_250[IMDb_Top_250.imdb_score==7.9]
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 3193           Paul Haggis                   287.0   54.557348
# 2487          George Cukor                    82.0   72.000000
# 3264        Michael Haneke                   447.0    0.225377
# 23           Peter Jackson                   509.0  258.355354
# 162           Dean DeBlois                   292.0  176.997107
# 3029      David O. Russell                   410.0   93.571803
# 89                Don Hall                   384.0  222.487711
# 2177            Tim Burton                   111.0   56.362352
# 2493           Yimou Zhang                   283.0    0.084961
# 2666           James Ivory                    58.0   22.954968
# 3595      Darren Aronofsky                   391.0   26.236603
# 845        Paul Greengrass                   491.0  107.100855
# 2863        Clint Eastwood                   251.0   13.753931
# 1813        Philip Kaufman                    80.0   21.500000
# ...

# %% [markdown]
# ### Observation
# - Although as required by the task we are selecting first 250 rows from the data sorted by imdb_score, it is seen that there are 6 more movies that have 7.9 rating and logically should be the part of top 250 list. Following code includes those movies and ranks the movies with same imdb score at same level

# %%
# Write your code to extract top foreign language films from 'IMDb_Top_250' here
Top_Foreign_Lang_Film = IMDb_Top_250[IMDb_Top_250.language!='English']
Top_Foreign_Lang_Film
# Out:
#                          director_name  num_critic_for_reviews       gross  \
# 4498                      Sergio Leone                   181.0    6.100000
# 4029                Fernando Meirelles                   214.0    7.563397
# 4747                    Akira Kurosawa                   153.0    0.269061
# 2373                    Hayao Miyazaki                   246.0   10.049886
# 4259  Florian Henckel von Donnersmarck                   215.0   11.284657
# 4921                      Majid Majidi                    46.0    0.925402
# 4659                    Asghar Farhadi                   354.0    7.098492
# 2970                 Wolfgang Petersen                    96.0   11.433134
# 2323                    Hayao Miyazaki                   174.0    2.298191
# 4105                    Chan-wook Park                   305.0    2.181290
# 1329                    S.S. Rajamouli                    44.0    6.498000
# ...

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'

# Just for experiment and showcasing

IMDb_Top_250A = movies[(movies['num_voted_users']>25000)].sort_values(by='imdb_score', ascending=False)

#.nlargest(250, 'imdb_score')
IMDb_Top_250A['rank'] = IMDb_Top_250A['imdb_score'].rank(ascending=False, method='min')

IMDb_Top_250A = IMDb_Top_250A[(IMDb_Top_250A['rank']<=250)]
print(IMDb_Top_250A.shape)
IMDb_Top_250A
# Out:
# (256, 15)
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 2837  Francis Ford Coppola                   149.0   57.300000
# 66       Christopher Nolan                   645.0  533.316061
# 339          Peter Jackson                   328.0  377.019252
# ...                    ...                     ...         ...
# 4640       Cristian Mungiu                   233.0    1.185783
# 3768          Duncan Jones                   415.0    5.009677
# 927         Andrew Adamson                   212.0  267.652016
# 3510           Yash Chopra                    29.0    2.921738
# 75              Doug Liman                   585.0  100.189501
#
#                                          genres      actor_1_name  \
# 1937                                Crime|Drama    Morgan Freeman
# ...

# %%
# inspecting hindi language movies as result differs from the checkpoint
movies[movies.language=='Hindi'].sort_values(by='imdb_score', ascending=False)

# veer-zaara is rated lower than my name is khan and is not part of Top_Foreign_Lang_Film due to reason mentioned above
# Out:
#         director_name  num_critic_for_reviews      gross  \
# 3344      Karan Johar                   210.0   4.018695
# 3510      Yash Chopra                    29.0   2.921738
# 4385     Ritesh Batra                   195.0   4.231500
# 4490        Mira Nair                   137.0  13.876974
# 3877         R. Balki                    12.0   0.199228
# 3276      Yash Chopra                    50.0   3.047539
# 4572   Khalid Mohamed                     1.0   0.610991
# 3075      Karan Johar                    20.0   3.275443
# 3455  Siddharth Anand                    16.0   0.872643
# 4593  Vivek Agnihotri                     4.0   0.049000
#
#                         genres         actor_1_name  \
# 3344  Adventure|Drama|Thriller       Shah Rukh Khan
# 3510     Drama|Musical|Romance       Shah Rukh Khan
# 4385             Drama|Romance  Nawazuddin Siddiqui
# 4490      Comedy|Drama|Romance     Naseeruddin Shah
# 3877              Comedy|Drama          Vidya Balan
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# ### Observations
# - Veer-Zara is not in frame.
# - My Name Is Khan is the highest rated hindi movie

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
# Write your code for extracting the top 10 directors here
directoreWiseMean = movies.groupby(['director_name'])['imdb_score'].mean()

top10director = directoreWiseMean[np.lexsort((directoreWiseMean.index, -directoreWiseMean.values))].head(10)
print(top10director)
# Out:
# director_name
# Charles Chaplin          8.600000
# Tony Kaye                8.600000
# Alfred Hitchcock         8.500000
# Damien Chazelle          8.500000
# Majid Majidi             8.500000
# Ron Fricke               8.500000
# Sergio Leone             8.433333
# Christopher Nolan        8.425000
# Asghar Farhadi           8.400000
# Marius A. Markevicius    8.400000
# Name: imdb_score, dtype: float64

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
def get_genre1(genres):
    genreList = genres.split('|') 
    return genreList[0]

def get_genre2(genres):
    genreList = genres.split('|') 
    if len(genreList)>1:
        return genreList[1]
    return genreList[0]

movies['genre_1'] = movies['genres'].apply(get_genre1)
movies['genre_2'] = movies['genres'].apply(get_genre2)
movies[['genres', 'genre_1', 'genre_2']]
# Out:
#                                                  genres    genre_1    genre_2
# 2988                         Comedy|Drama|Horror|Sci-Fi     Comedy      Drama
# 3859                                        Crime|Drama      Crime      Drama
# 3005                                  Drama|Romance|War      Drama    Romance
# 2323                        Adventure|Animation|Fantasy  Adventure  Animation
# 2334  Action|Adventure|Animation|Family|Sci-Fi|Thriller     Action  Adventure
# ...                                                 ...        ...        ...
# 3080                                      Family|Sci-Fi     Family     Sci-Fi
# 3024                    Action|Adventure|Fantasy|Sci-Fi     Action  Adventure
# 26                                        Drama|Romance      Drama    Romance
# 29                     Action|Adventure|Sci-Fi|Thriller     Action  Adventure
# 0                       Action|Adventure|Fantasy|Sci-Fi     Action  Adventure
#
# [3856 rows x 3 columns]

# %%
movies_by_segment = movies.groupby(by=['genre_1', 'genre_2']) # Write your code for grouping the dataframe here
movies_by_segment

# %%
PopGenre = movies_by_segment['gross'].mean().nlargest(5)# Write your code for getting the 5 most popular combo of genres here
PopGenre
# Out:
# genre_1    genre_2
# Family     Sci-Fi       434.949459
# Adventure  Sci-Fi       228.627758
#            Family       118.919540
#            Animation    116.998550
# Action     Adventure    109.595465
# Name: gross, dtype: float64

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
# Write your code for creating three new dataframes here
Meryl_Streep = movies.loc[movies['actor_1_name']=='Meryl Streep']# Include all movies in which Meryl_Streep is the lead
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 1483  Robert Redford                   227.0   14.998070
# 1674   Carl Franklin                    64.0   23.209440
# 1106   Curtis Hanson                    42.0   46.815748
# 3135   Robert Altman                   211.0   20.338609
# 1925  Stephen Daldry                   174.0   41.597830
# 2781  Phyllida Lloyd                   331.0   29.959436
# 410     Nancy Meyers                   187.0  112.703470
# 1618   David Frankel                   234.0   63.536011
# 1204     Nora Ephron                   252.0   94.125426
# 1575  Sydney Pollack                    66.0   87.100000
# 1408   David Frankel                   208.0  124.732962
#
#                                genres  actor_1_name  \
# 1483               Drama|Thriller|War  Meryl Streep
# 1674                            Drama  Meryl Streep
# 1106  Action|Adventure|Crime|Thriller  Meryl Streep
# 3135               Comedy|Drama|Music  Meryl Streep
# ...

# %%
Leo_Caprio = movies.loc[movies['actor_1_name']=='Leonardo DiCaprio'] # Include all movies in which Leo_Caprio is the lead
Leo_Caprio
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 307            Edward Zwick                   166.0   57.366262
# 641            Ridley Scott                   238.0   39.380442
# 326         Martin Scorsese                   233.0   77.679638
# 1560              Sam Raimi                    63.0   18.636537
# 1114             Sam Mendes                   323.0   22.877808
# 990             Danny Boyle                   118.0   39.778599
# 2067             Jerry Zaks                    45.0   12.782508
# 257         Martin Scorsese                   267.0  102.608827
# 1453         Clint Eastwood                   392.0   37.304950
# 308         Martin Scorsese                   606.0  116.866727
# 1422        Randall Wallace                    83.0   56.876365
# 2757           Baz Luhrmann                   106.0   46.338728
# 3476           Baz Luhrmann                   490.0  144.812796
# 50             Baz Luhrmann                   490.0  144.812796
# ...

# %%
Brad_Pitt =  movies.loc[movies['actor_1_name']=='Brad Pitt'] # Include all movies in which Brad_Pitt is the lead
Brad_Pitt
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 382              Tony Scott                   142.0    0.026871
# 147       Wolfgang Petersen                   220.0  133.228348
# 792         Patrick Gilmore                    98.0   26.288320
# 611     Jean-Jacques Annaud                    76.0   37.901509
# 1722         Andrew Dominik                   273.0    3.904982
# 683           David Fincher                   315.0   37.023395
# 101           David Fincher                   362.0  127.490802
# 1490        Terrence Malick                   584.0   13.303319
# 2333    Angelina Jolie Pitt                   131.0    0.531009
# 2898             Tony Scott                   122.0   12.281500
# 2682         Andrew Dominik                   414.0   14.938570
# 2204  Alejandro G. Iñárritu                   285.0   34.300771
# 254       Steven Soderbergh                   198.0  125.531634
# 470              David Ayer                   406.0   85.707116
# ...

# %%
# Write your code for combining the three dataframes here
Combined = Meryl_Streep.append(Leo_Caprio, ignore_index= True).append(Brad_Pitt, ignore_index= True)
Combined
# Out:
#             director_name  num_critic_for_reviews       gross  \
# 0          Robert Redford                   227.0   14.998070
# 1           Carl Franklin                    64.0   23.209440
# 2           Curtis Hanson                    42.0   46.815748
# 3           Robert Altman                   211.0   20.338609
# 4          Stephen Daldry                   174.0   41.597830
# 5          Phyllida Lloyd                   331.0   29.959436
# 6            Nancy Meyers                   187.0  112.703470
# 7           David Frankel                   234.0   63.536011
# 8             Nora Ephron                   252.0   94.125426
# 9          Sydney Pollack                    66.0   87.100000
# 10          David Frankel                   208.0  124.732962
# 11           Edward Zwick                   166.0   57.366262
# 12           Ridley Scott                   238.0   39.380442
# 13        Martin Scorsese                   233.0   77.679638
# ...

# %%
# Write your code for grouping the combined dataframe here
groupedCombinedData = Combined.groupby('actor_1_name')
groupedCombinedData

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
MeanData = groupedCombinedData[['num_critic_for_reviews', 'num_user_for_reviews']].mean()

# Highest Mean Number Of Critic Reviews
print(MeanData['num_critic_for_reviews'].idxmax())

# Highest Mean Number Of User Reviews
print(MeanData['num_user_for_reviews'].idxmax())
# Out:
# Leonardo DiCaprio
# Leonardo DiCaprio

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
# Write the code for calculating decade here
movies['decade'] = (movies['title_year']//10)*10
movies['decade'] = movies['decade'].astype(int)
print(movies['decade'].head(10))
movies.sort_values(by='decade', inplace=True)
print(movies['decade'].head(10))
# Out:
# 2988    2000
# 3859    2000
# 3005    2000
# 2323    1990
# 2334    2000
# 3423    1980
# 4542    1990
# 3851    1990
# 3075    2000
# 3273    2010
# Name: decade, dtype: int32
# 4812    1920
# 2734    1920
# 4958    1920
# 4786    1930
# 4449    1930
# 4157    1930
# 4706    1930
# 4427    1930
# 3970    1930
# 4225    1940
# Name: decade, dtype: int32

# %%
movies.head()
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 4812     Harry Beaumont                    36.0    2.808000
# 2734         Fritz Lang                   260.0    0.026435
# 4958  Harry F. Millarde                     1.0    3.000000
# 4786        Lloyd Bacon                    65.0    2.300000
# 4449   William Cottrell                   145.0  184.925485
#
#                                 genres       actor_1_name  \
# 4812                   Musical|Romance         Anita Page
# 2734                      Drama|Sci-Fi      Brigitte Helm
# 4958                       Crime|Drama       Stephen Carr
# 4786            Comedy|Musical|Romance      Ginger Rogers
# 4449  Animation|Family|Fantasy|Musical  Adriana Caselotti
#
#                            movie_title  num_voted_users  num_user_for_reviews  \
# 4812              The Broadway Melody              4546                  71.0
# 2734                       Metropolis            111841                 413.0
# ...

# %%
# Write your code for creating the data frame df_by_decade here 
df_by_decade = pd.DataFrame(movies.groupby('decade')['num_voted_users'].sum())
df_by_decade
# Out:
#         num_voted_users
# decade
# 1920             116392
# 1930             804839
# 1940             230838
# 1950             678336
# 1960            2983442
# 1970            8524102
# 1980           19987476
# 1990           69735679
# 2000          170908676
# 2010          120640994

# %%
# Write your code for plotting number of voted users vs decade
sns.barplot(df_by_decade.index, df_by_decade['num_voted_users'], data = df_by_decade)

# %%
data1 = pd.read_csv('wine.data')
data1
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...
